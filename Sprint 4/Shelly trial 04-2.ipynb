# %% [markdown]
# # Ground Zero

# %% [markdown]
# ## Packages and Datasets

# %%
import pkg_resources
import pip
installedPackages = {pkg.key for pkg in pkg_resources.working_set}
required = {'researchpy', 'missingno', 'folium', 'pydotplus' }
missing = required - installedPackages
if missing:
    # !pip install researchpy
    # !pip install missingno
    # !pip install folium
    # !pip install pydotplus

# %%
#Disable the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
import timeit
start_time = timeit.default_timer()  #timestamp to calculate total runtime

import pandas as pd
import numpy as np

import researchpy as rp
import missingno as msno

import seaborn as sns
import matplotlib.pyplot as plt

import itertools
import scipy.stats as ss

import folium
from folium import plugins

from sklearn.model_selection import train_test_split
from sklearn import feature_selection
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report, confusion_matrix

# %matplotlib inline
pd.set_option('display.max_columns', None)  # prevent column output trancation
sns.set()  # change plot styling from Matlab's 90s feel to today's Seaborn.

# %%
# File Directories
path_crashes = '../crashes.sample2020.csv'
path_vehicles = '../vehicles.sample.csv'
path_people = '../people.sample.csv'

# Import samples
crashes = pd.read_csv(
    path_crashes,
    parse_dates=["CRASH_DATE", "CRASH_DATE_EST_I", "DATE_POLICE_NOTIFIED"],
    low_memory=False,
    dtype=object)

vehicles = pd.read_csv(path_vehicles,
                       parse_dates=["CRASH_DATE"],
                       low_memory=False,
                       dtype=object)

people = pd.read_csv(path_people,
                     parse_dates=["CRASH_DATE"],
                     low_memory=False,
                     dtype=object)

# %% [markdown]
# ## Overview of Sprint 2
# - Understanding of Feature Processes
# - Data Merge & Split
# - Feature Reduction & Missing Value Treatment
# - Outliers
# - Feature Engineering
# - Baseline Model

# %% [markdown]
# ## Our Understanding

# %% [markdown]
# ### Feature Engineering Process
#
# [Source](https://en.wikipedia.org/wiki/Feature_engineering)
#
# The feature engineering process is:
# - Brainstorming or testing features;
# - Deciding what features to create;
# - Creating features;
# - Checking how the features work with your model;
# - **Improving your features if needed;**
# - Go back to brainstorming/creating more features until the work is done.

# %% [markdown]
# ### Some Terms
#
# [Source](https://datascience.stackexchange.com/questions/29006/feature-selection-vs-feature-extraction-which-to-use-when)
#
# **Feature Extraction and Feature Engineering:** transformation of raw data into features suitable for modeling;
#
# - Texts(ngrams, word2vec, tf-idf etc)
# - Geospatial data(lat, long)
# - Date and time(day, month, week, year, rolling based)
# - Time series, web, etc
# - Dimensional Reduction Techniques (PCA, SVD, Eigen-Faces etc)
# - Clustering (DBSCAN etc)
# - And others.
#
# ---
#
# **Feature / Data Transformation:** transformation of data to improve the accuracy of the algorithm;
# - Normalization and changing distribution(Scaling)
# - Interactions
# - Handling missing Values
# - Handling outliers
# - Handling time-date / mixed variables
# - Encoding categorical features
# - Variable types
# - And others.
#
# ---
#
# **Feature Selection:** removing unnecessary features.
#
# - Statistical approaches
# - Selection by modeling
# - Grid search
# - Cross Validation
# - And others
#
# ---
#
# For the purpose of workflow, we will split **Feature Selection** into;
# - **feature reduction** to remove unnecessary features,
# - and **feature selection** to select features by their importance scores through ML/statistical techniques.

# %% [markdown]
# # Data Merge & Split

# %% [markdown]
# ## Merging datasets
#
# The goal is to successfully merge all datasets by increasing crash records as little as possible.

# %%
print("Here is the initial shape of the three datasets:")
print("Crashes", crashes.shape)
print("Vehicles", vehicles.shape)
print("People", people.shape)
# Out:
# Here is the initial shape of the three datasets:
# Crashes (33408, 49)
# Vehicles (75673, 72)
# People (82049, 30)

# %% [markdown]
# **Data Merge Strategy**
#
# - Filter out passengers from **`people`**, and left-join it to **`vehicles`** on `CRASH_RECORD_ID`, `RD_NO`, `CRASH_DATE`, `VEHICLE_ID`.
#
# - Then inner-join this dataset to **`crashes`** on `CRASH_RECORD_ID`, `RD_NO`, `CRASH_DATE`.
#
# ---
#
# **Reasoning**
#
# - `people` has **many-to-one relationship** with `vehicles` but a pedestrian in `vehicles` has **one-to-one** with `people`,
#
# - Passengers don't have <u>a trajectory separate from the unit</u> they belong to and they don't contribute to accidents with their existence but they are involved if they got harmed through `injuries` features,
#
# - This method increases `crashes` records **only per active parties involved**.

# %%
# Filter only non-pessenger people (drivers, pedestrian, cyclist, etc.)
# non_passengers = people[people.PERSON_ID.str.contains('^O')]

# %%
# Left join non-peseenger people with vehicles
vehicles_with_people = vehicles.merge(#non_passengers, 
                                      people, how='left', 
                                      on=['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE', 'VEHICLE_ID'])
vehicles_with_people.head()
# Out:
#   CRASH_UNIT_ID                                    CRASH_RECORD_ID     RD_NO  \
# 0        228894  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 1        228895  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 2        228896  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 3        228905  f7210aec9ac43a7b36c30b49033adebcb3060b96580341...  JA453640
# 4        228906  f7210aec9ac43a7b36c30b49033adebcb3060b96580341...  JA453640
#
#            CRASH_DATE UNIT_NO   UNIT_TYPE NUM_PASSENGERS VEHICLE_ID  \
# 0 2017-10-01 02:20:00       1      DRIVER            NaN     224185
# 1 2017-10-01 02:20:00       2      PARKED            NaN     224187
# 2 2017-10-01 02:20:00       3      PARKED            NaN     224191
# 3 2017-10-01 02:41:00       1      DRIVER            NaN     224199
# 4 2017-10-01 02:41:00       2  DRIVERLESS            NaN     224203
#
#   CMRC_VEH_I                  MAKE     MODEL LIC_PLATE_STATE VEHICLE_YEAR  \
# 0        NaN                 DODGE   CHARGER              IL         2012
# 1        NaN  GENERAL MOTORS CORP.     YUKON              IL         2003
# 2        NaN                SATURN   UNKNOWN              IL         2000
# 3        NaN                  FORD  WINDSTAR              IL         2007
# 4        NaN             CHEVROLET     CRUZE              IL         2012
#
#   VEHICLE_DEFECT  VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION        MANEUVER  \
# 0        UNKNOWN     PASSENGER    PERSONAL                N  STRAIGHT AHEAD
# 1        UNKNOWN     PASSENGER    PERSONAL                N          PARKED
# 2        UNKNOWN     PASSENGER    PERSONAL                N          PARKED
# 3           NONE  VAN/MINI-VAN    PERSONAL                E  STRAIGHT AHEAD
# 4           NONE     PASSENGER  NOT IN USE          UNKNOWN          PARKED
#
#   TOWED_I FIRE_I OCCUPANT_CNT EXCEED_SPEED_LIMIT_I     TOWED_BY TOWED_TO  \
# 0       Y    NaN            1                  NaN  PRIVATE TOW  UNKNOWN
# 1       Y    NaN            0                  NaN  PRIVATE TOW  UNKNOWN
# 2     NaN    NaN            0                  NaN          NaN      NaN
# 3       Y    NaN            1                  NaN          NaN      NaN
# 4       Y    NaN            0                  NaN          NaN      NaN
#
#   AREA_00_I AREA_01_I AREA_02_I AREA_03_I AREA_04_I AREA_05_I AREA_06_I  \
# 0       NaN         Y         Y       NaN       NaN       NaN       NaN
# 1         N       NaN       NaN       NaN       NaN       NaN         Y
# 2       NaN       NaN         Y         Y         Y       NaN       NaN
# 3       NaN         Y         Y         Y         Y       NaN         N
# 4       NaN         Y         Y       NaN       NaN       NaN         Y
#
#   AREA_07_I AREA_08_I AREA_09_I AREA_10_I AREA_11_I AREA_12_I AREA_99_I  \
# 0       NaN         Y       NaN       NaN       NaN       NaN       NaN
# 1         Y         Y       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         N         N       NaN       NaN         Y       NaN       NaN
# 4         Y         Y       NaN       NaN         Y       NaN       NaN
#
#   FIRST_CONTACT_POINT CMV_ID USDOT_NO CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR  \
# 0               FRONT    NaN      NaN     NaN     NaN            NaN  NaN
# 1           REAR-LEFT    NaN      NaN     NaN     NaN            NaN  NaN
# 2          REAR-RIGHT    NaN      NaN     NaN     NaN            NaN  NaN
# 3   TOTAL (ALL AREAS)    NaN      NaN     NaN     NaN            NaN  NaN
# 4           REAR-LEFT    NaN      NaN     NaN     NaN            NaN  NaN
#
#   CARRIER_NAME CARRIER_STATE CARRIER_CITY HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO  \
# 0          NaN           NaN          NaN               NaN         NaN   NaN
# 1          NaN           NaN          NaN               NaN         NaN   NaN
# 2          NaN           NaN          NaN               NaN         NaN   NaN
# 3          NaN           NaN          NaN               NaN         NaN   NaN
# 4          NaN           NaN          NaN               NaN         NaN   NaN
#
#   HAZMAT_PRESENT_I HAZMAT_REPORT_I HAZMAT_REPORT_NO MCS_REPORT_I  \
# 0              NaN             NaN              NaN          NaN
# 1              NaN             NaN              NaN          NaN
# 2              NaN             NaN              NaN          NaN
# 3              NaN             NaN              NaN          NaN
# 4              NaN             NaN              NaN          NaN
#
#   MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO  \
# 0           NaN                      NaN                   NaN            NaN
# 1           NaN                      NaN                   NaN            NaN
# 2           NaN                      NaN                   NaN            NaN
# 3           NaN                      NaN                   NaN            NaN
# 4           NaN                      NaN                   NaN            NaN
#
#   WIDE_LOAD_I TRAILER1_WIDTH TRAILER2_WIDTH TRAILER1_LENGTH TRAILER2_LENGTH  \
# 0         NaN            NaN            NaN             NaN             NaN
# 1         NaN            NaN            NaN             NaN             NaN
# 2         NaN            NaN            NaN             NaN             NaN
# 3         NaN            NaN            NaN             NaN             NaN
# 4         NaN            NaN            NaN             NaN             NaN
#
#   TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE  \
# 0                  NaN      NaN            NaN             NaN       NaN
# 1                  NaN      NaN            NaN             NaN       NaN
# 2                  NaN      NaN            NaN             NaN       NaN
# 3                  NaN      NaN            NaN             NaN       NaN
# 4                  NaN      NaN            NaN             NaN       NaN
#
#   HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I HAZMAT_CLASS PERSON_ID  \
# 0                     NaN                  NaN          NaN   O228894
# 1                     NaN                  NaN          NaN       NaN
# 2                     NaN                  NaN          NaN       NaN
# 3                     NaN                  NaN          NaN   O228905
# 4                     NaN                  NaN          NaN       NaN
#
#   PERSON_TYPE SEAT_NO      CITY STATE ZIPCODE  SEX  AGE DRIVERS_LICENSE_STATE  \
# 0      DRIVER     NaN  KANKAKKE    IL   60901    M   18                    IL
# 1         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
# 2         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
# 3      DRIVER     NaN   CHICAGO    IL   60632    M   43                    IL
# 4         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
#
#   DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT  AIRBAG_DEPLOYED EJECTION  \
# 0                     D  SAFETY BELT USED  DEPLOYED, FRONT     NONE
# 1                   NaN               NaN              NaN      NaN
# 2                   NaN               NaN              NaN      NaN
# 3                     D  SAFETY BELT USED   DID NOT DEPLOY     NONE
# 4                   NaN               NaN              NaN      NaN
#
#       INJURY_CLASSIFICATION HOSPITAL EMS_AGENCY EMS_RUN_NO  \
# 0  NONINCAPACITATING INJURY      NaN        NaN        NaN
# 1                       NaN      NaN        NaN        NaN
# 2                       NaN      NaN        NaN        NaN
# 3   NO INDICATION OF INJURY      NaN        NaN        NaN
# 4                       NaN      NaN        NaN        NaN
#
#           DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION  \
# 0               UNKNOWN  NOT OBSCURED             NORMAL             NaN
# 1                   NaN           NaN                NaN             NaN
# 2                   NaN           NaN                NaN             NaN
# 3  IMPROPER LANE CHANGE  NOT OBSCURED             NORMAL             NaN
# 4                   NaN           NaN                NaN             NaN
#
#   PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE  \
# 0                 NaN               NaN  TEST NOT OFFERED              NaN
# 1                 NaN               NaN               NaN              NaN
# 2                 NaN               NaN               NaN              NaN
# 3                 NaN               NaN  TEST NOT OFFERED              NaN
# 4                 NaN               NaN               NaN              NaN
#
#   CELL_PHONE_USE
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print("Shape of vehicles with people", vehicles_with_people.shape)
# Out:
# Shape of vehicles with people (92227, 98)

# %%
merged_data = crashes.merge(vehicles_with_people, 
                            how='inner', 
                            on=['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE'])

print('Dimensions of the data after merging', merged_data.shape)
# Out:
# Dimensions of the data after merging (83489, 144)

# %% [markdown]
# **Inspection 1**

# %%
merged_data.groupby('CRASH_RECORD_ID').head()
# Out:
#                                          CRASH_RECORD_ID     RD_NO  \
# 0      0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 1      0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 2      0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 3      02e2ed3606a50dda185f5e97c57a45552087d6fbea1c4b...  JB256393
# 4      02e2ed3606a50dda185f5e97c57a45552087d6fbea1c4b...  JB256393
# ...                                                  ...       ...
# 83484  2a82ef3a871842cf16a0c04108aff04f7926308b399d1d...  JD314360
# 83485  2a82ef3a871842cf16a0c04108aff04f7926308b399d1d...  JD314360
# 83486  4e5a88b3896b2e88779ecd6f3a12e13fc335b94f4a6e8b...  JD313988
# 83487  4e5a88b3896b2e88779ecd6f3a12e13fc335b94f4a6e8b...  JD313988
# 83488  4e5a88b3896b2e88779ecd6f3a12e13fc335b94f4a6e8b...  JD313988
#
#       CRASH_DATE_EST_I          CRASH_DATE POSTED_SPEED_LIMIT  \
# 0                  NaN 2019-06-11 08:40:00                 30
# 1                  NaN 2019-06-11 08:40:00                 30
# 2                  NaN 2019-06-11 08:40:00                 30
# 3                  NaN 2018-05-09 11:30:00                 25
# 4                  NaN 2018-05-09 11:30:00                 25
# ...                ...                 ...                ...
# 83484              NaN 2020-07-29 17:17:00                 30
# 83485              NaN 2020-07-29 17:17:00                 30
# 83486              NaN 2020-07-29 12:55:00                 30
# 83487              NaN 2020-07-29 12:55:00                 30
# 83488              NaN 2020-07-29 12:55:00                 30
#
#       TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0             TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1             TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2             TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 3                NO CONTROLS           NO CONTROLS              RAIN
# 4                NO CONTROLS           NO CONTROLS              RAIN
# ...                      ...                   ...               ...
# 83484            NO CONTROLS           NO CONTROLS             CLEAR
# 83485            NO CONTROLS           NO CONTROLS             CLEAR
# 83486                  OTHER  FUNCTIONING PROPERLY             CLEAR
# 83487                  OTHER  FUNCTIONING PROPERLY             CLEAR
# 83488                  OTHER  FUNCTIONING PROPERLY             CLEAR
#
#       LIGHTING_CONDITION          FIRST_CRASH_TYPE  \
# 0               DAYLIGHT                  REAR END
# 1               DAYLIGHT                  REAR END
# 2               DAYLIGHT                  REAR END
# 3               DAYLIGHT                     ANGLE
# 4               DAYLIGHT                     ANGLE
# ...                  ...                       ...
# 83484           DAYLIGHT                   TURNING
# 83485           DAYLIGHT                   TURNING
# 83486           DAYLIGHT  SIDESWIPE SAME DIRECTION
# 83487           DAYLIGHT  SIDESWIPE SAME DIRECTION
# 83488           DAYLIGHT  SIDESWIPE SAME DIRECTION
#
#                   TRAFFICWAY_TYPE LANE_CNT           ALIGNMENT  \
# 0      DIVIDED - W/MEDIAN BARRIER      NaN  STRAIGHT AND LEVEL
# 1      DIVIDED - W/MEDIAN BARRIER      NaN  STRAIGHT AND LEVEL
# 2      DIVIDED - W/MEDIAN BARRIER      NaN  STRAIGHT AND LEVEL
# 3                     NOT DIVIDED        2  STRAIGHT AND LEVEL
# 4                     NOT DIVIDED        2  STRAIGHT AND LEVEL
# ...                           ...      ...                 ...
# 83484                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 83485                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 83486                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 83487                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 83488                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
#
#       ROADWAY_SURFACE_COND ROAD_DEFECT                 REPORT_TYPE  \
# 0                      DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 1                      DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 2                      DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 3                      WET  NO DEFECTS                    ON SCENE
# 4                      WET  NO DEFECTS                    ON SCENE
# ...                    ...         ...                         ...
# 83484                  DRY  NO DEFECTS                    ON SCENE
# 83485                  DRY  NO DEFECTS                    ON SCENE
# 83486                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 83487                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 83488                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
#
#                    CRASH_TYPE INTERSECTION_RELATED_I NOT_RIGHT_OF_WAY_I  \
# 0      NO INJURY / DRIVE AWAY                      Y                NaN
# 1      NO INJURY / DRIVE AWAY                      Y                NaN
# 2      NO INJURY / DRIVE AWAY                      Y                NaN
# 3      NO INJURY / DRIVE AWAY                    NaN                NaN
# 4      NO INJURY / DRIVE AWAY                    NaN                NaN
# ...                       ...                    ...                ...
# 83484  NO INJURY / DRIVE AWAY                    NaN                NaN
# 83485  NO INJURY / DRIVE AWAY                    NaN                NaN
# 83486  NO INJURY / DRIVE AWAY                      Y                NaN
# 83487  NO INJURY / DRIVE AWAY                      Y                NaN
# 83488  NO INJURY / DRIVE AWAY                      Y                NaN
#
#       HIT_AND_RUN_I         DAMAGE DATE_POLICE_NOTIFIED  \
# 0               NaN  $501 - $1,500  2019-06-11 09:05:00
# 1               NaN  $501 - $1,500  2019-06-11 09:05:00
# 2               NaN  $501 - $1,500  2019-06-11 09:05:00
# 3               NaN    OVER $1,500  2018-05-09 11:35:00
# 4               NaN    OVER $1,500  2018-05-09 11:35:00
# ...             ...            ...                  ...
# 83484           NaN    OVER $1,500  2020-07-29 17:21:00
# 83485           NaN    OVER $1,500  2020-07-29 17:21:00
# 83486           NaN    OVER $1,500  2020-07-29 13:05:00
# 83487           NaN    OVER $1,500  2020-07-29 13:05:00
# 83488           NaN    OVER $1,500  2020-07-29 13:05:00
#
#              PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_NO  \
# 0                UNABLE TO DETERMINE         NOT APPLICABLE        50
# 1                UNABLE TO DETERMINE         NOT APPLICABLE        50
# 2                UNABLE TO DETERMINE         NOT APPLICABLE        50
# 3      FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      9511
# 4      FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      9511
# ...                              ...                    ...       ...
# 83484  FAILING TO YIELD RIGHT-OF-WAY         NOT APPLICABLE      1035
# 83485  FAILING TO YIELD RIGHT-OF-WAY         NOT APPLICABLE      1035
# 83486  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5210
# 83487  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5210
# 83488  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5210
#
#       STREET_DIRECTION    STREET_NAME BEAT_OF_OCCURRENCE PHOTOS_TAKEN_I  \
# 0                    E  GARFIELD BLVD                225            NaN
# 1                    E  GARFIELD BLVD                225            NaN
# 2                    E  GARFIELD BLVD                225            NaN
# 3                    S  WENTWORTH AVE                511            NaN
# 4                    S  WENTWORTH AVE                511            NaN
# ...                ...            ...                ...            ...
# 83484                S    AUSTIN BLVD               1513            NaN
# 83485                S    AUSTIN BLVD               1513            NaN
# 83486                N    LINCOLN AVE               2011            NaN
# 83487                N    LINCOLN AVE               2011            NaN
# 83488                N    LINCOLN AVE               2011            NaN
#
#       STATEMENTS_TAKEN_I DOORING_I WORK_ZONE_I WORK_ZONE_TYPE  \
# 0                    NaN       NaN         NaN            NaN
# 1                    NaN       NaN         NaN            NaN
# 2                    NaN       NaN         NaN            NaN
# 3                    NaN       NaN         NaN            NaN
# 4                    NaN       NaN         NaN            NaN
# ...                  ...       ...         ...            ...
# 83484                NaN       NaN         NaN            NaN
# 83485                NaN       NaN         NaN            NaN
# 83486                NaN       NaN         NaN            NaN
# 83487                NaN       NaN         NaN            NaN
# 83488                NaN       NaN         NaN            NaN
#
#       WORKERS_PRESENT_I NUM_UNITS       MOST_SEVERE_INJURY INJURIES_TOTAL  \
# 0                   NaN         2  NO INDICATION OF INJURY              0
# 1                   NaN         2  NO INDICATION OF INJURY              0
# 2                   NaN         2  NO INDICATION OF INJURY              0
# 3                   NaN         2  NO INDICATION OF INJURY              0
# 4                   NaN         2  NO INDICATION OF INJURY              0
# ...                 ...       ...                      ...            ...
# 83484               NaN         2  NO INDICATION OF INJURY              0
# 83485               NaN         2  NO INDICATION OF INJURY              0
# 83486               NaN         2  NO INDICATION OF INJURY              0
# 83487               NaN         2  NO INDICATION OF INJURY              0
# 83488               NaN         2  NO INDICATION OF INJURY              0
#
#       INJURIES_FATAL INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 0                  0                       0                           0
# 1                  0                       0                           0
# 2                  0                       0                           0
# 3                  0                       0                           0
# 4                  0                       0                           0
# ...              ...                     ...                         ...
# 83484              0                       0                           0
# 83485              0                       0                           0
# 83486              0                       0                           0
# 83487              0                       0                           0
# 83488              0                       0                           0
#
#       INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                                 0                      3                0
# 1                                 0                      3                0
# 2                                 0                      3                0
# 3                                 0                      2                0
# 4                                 0                      2                0
# ...                             ...                    ...              ...
# 83484                             0                      2                0
# 83485                             0                      2                0
# 83486                             0                      3                0
# 83487                             0                      3                0
# 83488                             0                      3                0
#
#       CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH      LATITUDE      LONGITUDE  \
# 0              8                 3           6  41.794778764  -87.623828038
# 1              8                 3           6  41.794778764  -87.623828038
# 2              8                 3           6  41.794778764  -87.623828038
# 3             11                 4           5   41.72128957  -87.628509594
# 4             11                 4           5   41.72128957  -87.628509594
# ...          ...               ...         ...           ...            ...
# 83484         17                 4           7  41.868063122  -87.774077299
# 83485         17                 4           7  41.868063122  -87.774077299
# 83486         12                 4           7  41.976225187  -87.692503665
# 83487         12                 4           7  41.976225187  -87.692503665
# 83488         12                 4           7  41.976225187  -87.692503665
#
#                                        LOCATION CRASH_UNIT_ID UNIT_NO  \
# 0      POINT (-87.623828038036 41.794778764028)        667550       1
# 1      POINT (-87.623828038036 41.794778764028)        667551       2
# 2      POINT (-87.623828038036 41.794778764028)        667551       2
# 3       POINT (-87.628509593966 41.72128957001)        381841       1
# 4       POINT (-87.628509593966 41.72128957001)        381842       2
# ...                                         ...           ...     ...
# 83484  POINT (-87.774077298863 41.868063121814)        927948       1
# 83485  POINT (-87.774077298863 41.868063121814)        927949       2
# 83486  POINT (-87.692503665448 41.976225186967)        927624       1
# 83487  POINT (-87.692503665448 41.976225186967)        927625       2
# 83488  POINT (-87.692503665448 41.976225186967)        927625       2
#
#       UNIT_TYPE NUM_PASSENGERS VEHICLE_ID CMRC_VEH_I  \
# 0        DRIVER            NaN     635502        NaN
# 1        DRIVER              1     635496        NaN
# 2        DRIVER              1     635496        NaN
# 3        DRIVER            NaN     367786        NaN
# 4        DRIVER            NaN     367788        NaN
# ...         ...            ...        ...        ...
# 83484    DRIVER            NaN     879756        NaN
# 83485    DRIVER            NaN     879766        NaN
# 83486    DRIVER            NaN     879442        NaN
# 83487    DRIVER              1     879449        NaN
# 83488    DRIVER              1     879449        NaN
#
#                              MAKE                                   MODEL  \
# 0                       CHEVROLET                                 EQUINOX
# 1                       CHEVROLET                               SILVERADO
# 2                       CHEVROLET                               SILVERADO
# 3                          NISSAN  SENTRA (DATSUN AND NISSAN HAVE MERGED)
# 4      TOYOTA MOTOR COMPANY, LTD.                                   YARIS
# ...                           ...                                     ...
# 83484                      TOYOTA                                  AVALON
# 83485                       DODGE                              CHALLENGER
# 83486                      NISSAN                                    JUKE
# 83487                      SUBARU                                FORESTER
# 83488                      SUBARU                                FORESTER
#
#       LIC_PLATE_STATE VEHICLE_YEAR VEHICLE_DEFECT  \
# 0                  IL         2017        UNKNOWN
# 1                  IL         2016           NONE
# 2                  IL         2016           NONE
# 3                  IL         1997           NONE
# 4                  IL         2015           NONE
# ...               ...          ...            ...
# 83484             NaN         1999           NONE
# 83485              IL         2016           NONE
# 83486              IL         2011           NONE
# 83487              IL         2009           NONE
# 83488              IL         2009           NONE
#
#                       VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION  \
# 0      SPORT UTILITY VEHICLE (SUV)  UNKNOWN/NA                W
# 1                           PICKUP    PERSONAL                W
# 2                           PICKUP    PERSONAL                W
# 3                        PASSENGER    PERSONAL                W
# 4                        PASSENGER    PERSONAL                N
# ...                            ...         ...              ...
# 83484                    PASSENGER    PERSONAL                S
# 83485                    PASSENGER    PERSONAL                N
# 83486                    PASSENGER    PERSONAL                S
# 83487                    PASSENGER    PERSONAL                S
# 83488                    PASSENGER    PERSONAL                S
#
#                   MANEUVER TOWED_I FIRE_I OCCUPANT_CNT EXCEED_SPEED_LIMIT_I  \
# 0           STRAIGHT AHEAD     NaN    NaN            1                  NaN
# 1      STARTING IN TRAFFIC     NaN    NaN            2                  NaN
# 2      STARTING IN TRAFFIC     NaN    NaN            2                  NaN
# 3           STRAIGHT AHEAD     NaN    NaN            1                  NaN
# 4           STRAIGHT AHEAD     NaN    NaN            1                  NaN
# ...                    ...     ...    ...          ...                  ...
# 83484               U-TURN     NaN    NaN            1                  NaN
# 83485       STRAIGHT AHEAD     NaN    NaN            1                  NaN
# 83486       CHANGING LANES     NaN    NaN            1                  NaN
# 83487       STRAIGHT AHEAD     NaN    NaN            2                  NaN
# 83488       STRAIGHT AHEAD     NaN    NaN            2                  NaN
#
#       TOWED_BY TOWED_TO AREA_00_I AREA_01_I AREA_02_I AREA_03_I AREA_04_I  \
# 0          NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 1          NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 2          NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 3          NaN      NaN       NaN         Y         Y       NaN       NaN
# 4          NaN      NaN       NaN         Y         Y       NaN       NaN
# ...        ...      ...       ...       ...       ...       ...       ...
# 83484      NaN      NaN       NaN         Y       NaN       NaN       NaN
# 83485      NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 83486      NaN      NaN       NaN       NaN       NaN       NaN       NaN
# 83487      NaN      NaN       NaN       NaN         Y         Y       NaN
# 83488      NaN      NaN       NaN       NaN         Y         Y       NaN
#
#       AREA_05_I AREA_06_I AREA_07_I AREA_08_I AREA_09_I AREA_10_I AREA_11_I  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN         Y       NaN       NaN       NaN       NaN       NaN
# 2           NaN         Y       NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN         Y       NaN       NaN       NaN
# 4           NaN       NaN       NaN         Y       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 83484       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 83485       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 83486       NaN       NaN       NaN         Y         Y       NaN       NaN
# 83487       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 83488       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#       AREA_12_I AREA_99_I FIRST_CONTACT_POINT CMV_ID USDOT_NO CCMC_NO ILCC_NO  \
# 0             Y       NaN               OTHER    NaN      NaN     NaN     NaN
# 1           NaN       NaN           REAR-LEFT    NaN      NaN     NaN     NaN
# 2           NaN       NaN           REAR-LEFT    NaN      NaN     NaN     NaN
# 3           NaN       NaN          FRONT-LEFT    NaN      NaN     NaN     NaN
# 4           NaN       NaN         FRONT-RIGHT    NaN      NaN     NaN     NaN
# ...         ...       ...                 ...    ...      ...     ...     ...
# 83484         N       NaN               FRONT    NaN      NaN     NaN     NaN
# 83485         Y       NaN               OTHER    NaN      NaN     NaN     NaN
# 83486       NaN       NaN          FRONT-LEFT    NaN      NaN     NaN     NaN
# 83487       NaN       NaN               FRONT    NaN      NaN     NaN     NaN
# 83488       NaN       NaN               FRONT    NaN      NaN     NaN     NaN
#
#       COMMERCIAL_SRC GVWR CARRIER_NAME CARRIER_STATE CARRIER_CITY  \
# 0                NaN  NaN          NaN           NaN          NaN
# 1                NaN  NaN          NaN           NaN          NaN
# 2                NaN  NaN          NaN           NaN          NaN
# 3                NaN  NaN          NaN           NaN          NaN
# 4                NaN  NaN          NaN           NaN          NaN
# ...              ...  ...          ...           ...          ...
# 83484            NaN  NaN          NaN           NaN          NaN
# 83485            NaN  NaN          NaN           NaN          NaN
# 83486            NaN  NaN          NaN           NaN          NaN
# 83487            NaN  NaN          NaN           NaN          NaN
# 83488            NaN  NaN          NaN           NaN          NaN
#
#       HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO HAZMAT_PRESENT_I HAZMAT_REPORT_I  \
# 0                   NaN         NaN   NaN              NaN             NaN
# 1                   NaN         NaN   NaN              NaN             NaN
# 2                   NaN         NaN   NaN              NaN             NaN
# 3                   NaN         NaN   NaN              NaN             NaN
# 4                   NaN         NaN   NaN              NaN             NaN
# ...                 ...         ...   ...              ...             ...
# 83484               NaN         NaN   NaN              NaN             NaN
# 83485               NaN         NaN   NaN              NaN             NaN
# 83486               NaN         NaN   NaN              NaN             NaN
# 83487               NaN         NaN   NaN              NaN             NaN
# 83488               NaN         NaN   NaN              NaN             NaN
#
#       HAZMAT_REPORT_NO MCS_REPORT_I MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I  \
# 0                  NaN          NaN           NaN                      NaN
# 1                  NaN          NaN           NaN                      NaN
# 2                  NaN          NaN           NaN                      NaN
# 3                  NaN          NaN           NaN                      NaN
# 4                  NaN          NaN           NaN                      NaN
# ...                ...          ...           ...                      ...
# 83484              NaN          NaN           NaN                      NaN
# 83485              NaN          NaN           NaN                      NaN
# 83486              NaN          NaN           NaN                      NaN
# 83487              NaN          NaN           NaN                      NaN
# 83488              NaN          NaN           NaN                      NaN
#
#       MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO WIDE_LOAD_I TRAILER1_WIDTH  \
# 0                       NaN            NaN         NaN            NaN
# 1                       NaN            NaN         NaN            NaN
# 2                       NaN            NaN         NaN            NaN
# 3                       NaN            NaN         NaN            NaN
# 4                       NaN            NaN         NaN            NaN
# ...                     ...            ...         ...            ...
# 83484                   NaN            NaN         NaN            NaN
# 83485                   NaN            NaN         NaN            NaN
# 83486                   NaN            NaN         NaN            NaN
# 83487                   NaN            NaN         NaN            NaN
# 83488                   NaN            NaN         NaN            NaN
#
#       TRAILER2_WIDTH TRAILER1_LENGTH TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH  \
# 0                NaN             NaN             NaN                  NaN
# 1                NaN             NaN             NaN                  NaN
# 2                NaN             NaN             NaN                  NaN
# 3                NaN             NaN             NaN                  NaN
# 4                NaN             NaN             NaN                  NaN
# ...              ...             ...             ...                  ...
# 83484            NaN             NaN             NaN                  NaN
# 83485            NaN             NaN             NaN                  NaN
# 83486            NaN             NaN             NaN                  NaN
# 83487            NaN             NaN             NaN                  NaN
# 83488            NaN             NaN             NaN                  NaN
#
#       AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE  \
# 0          NaN            NaN             NaN       NaN
# 1          NaN            NaN             NaN       NaN
# 2          NaN            NaN             NaN       NaN
# 3          NaN            NaN             NaN       NaN
# 4          NaN            NaN             NaN       NaN
# ...        ...            ...             ...       ...
# 83484      NaN            NaN             NaN       NaN
# 83485      NaN            NaN             NaN       NaN
# 83486      NaN            NaN             NaN       NaN
# 83487      NaN            NaN             NaN       NaN
# 83488      NaN            NaN             NaN       NaN
#
#       HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I HAZMAT_CLASS PERSON_ID  \
# 0                         NaN                  NaN          NaN   O667550
# 1                         NaN                  NaN          NaN   O667551
# 2                         NaN                  NaN          NaN   P151614
# 3                         NaN                  NaN          NaN   O381841
# 4                         NaN                  NaN          NaN   O381842
# ...                       ...                  ...          ...       ...
# 83484                     NaN                  NaN          NaN   O927948
# 83485                     NaN                  NaN          NaN   O927949
# 83486                     NaN                  NaN          NaN   O927624
# 83487                     NaN                  NaN          NaN   O927625
# 83488                     NaN                  NaN          NaN   P211857
#
#       PERSON_TYPE SEAT_NO          CITY STATE ZIPCODE SEX AGE  \
# 0          DRIVER     NaN      HOMEWOOD    IL   60430   F  56
# 1          DRIVER     NaN   PALOS HILLS    IL   60465   M  51
# 2       PASSENGER       3       CHICAGO    IL   60620   M  21
# 3          DRIVER     NaN       CHICAGO    IL   60620   F  45
# 4          DRIVER     NaN       CHICAGO    IL   60628   F  35
# ...           ...     ...           ...   ...     ...  ..  ..
# 83484      DRIVER     NaN       CHICAGO    IL   60644   M  25
# 83485      DRIVER     NaN  ELMWOOD PARK    IL   60706   M  51
# 83486      DRIVER     NaN  LINCOLNSHIRE    IL   60069   F  68
# 83487      DRIVER     NaN       CHICAGO    IL   60640   F  71
# 83488   PASSENGER       3       CHICAGO    IL   60640   F  76
#
#       DRIVERS_LICENSE_STATE DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT  \
# 0                        IL                     D     USAGE UNKNOWN
# 1                        IL                     D  SAFETY BELT USED
# 2                       NaN                   NaN  SAFETY BELT USED
# 3                        IL                    DM  SAFETY BELT USED
# 4                        IL                     D  SAFETY BELT USED
# ...                     ...                   ...               ...
# 83484                    IL                     D     USAGE UNKNOWN
# 83485                    IL                    BM     USAGE UNKNOWN
# 83486                    IL                     D  SAFETY BELT USED
# 83487                    IL                     D  SAFETY BELT USED
# 83488                   NaN                   NaN  SAFETY BELT USED
#
#       AIRBAG_DEPLOYED EJECTION    INJURY_CLASSIFICATION HOSPITAL EMS_AGENCY  \
# 0      DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 1      DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 2      DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 3      DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 4      DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# ...               ...      ...                      ...      ...        ...
# 83484  DID NOT DEPLOY     NONE  NO INDICATION OF INJURY  REFUSED        NaN
# 83485  NOT APPLICABLE     NONE  NO INDICATION OF INJURY  REFUSED        NaN
# 83486  DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 83487  DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN        NaN
# 83488  NOT APPLICABLE     NONE  NO INDICATION OF INJURY      NaN        NaN
#
#       EMS_RUN_NO         DRIVER_ACTION    DRIVER_VISION PHYSICAL_CONDITION  \
# 0            NaN               UNKNOWN          UNKNOWN             NORMAL
# 1            NaN                  NONE     NOT OBSCURED             NORMAL
# 2            NaN                   NaN              NaN                NaN
# 3            NaN       FAILED TO YIELD  PARKED VEHICLES             NORMAL
# 4            NaN                  NONE     NOT OBSCURED             NORMAL
# ...          ...                   ...              ...                ...
# 83484        NaN       FAILED TO YIELD          UNKNOWN             NORMAL
# 83485        NaN                  NONE     NOT OBSCURED             NORMAL
# 83486        NaN  IMPROPER LANE CHANGE     NOT OBSCURED             NORMAL
# 83487        NaN                  NONE     NOT OBSCURED             NORMAL
# 83488        NaN                   NaN              NaN                NaN
#
#       PEDPEDAL_ACTION PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT  \
# 0                 NaN                 NaN               NaN  TEST NOT OFFERED
# 1                 NaN                 NaN               NaN  TEST NOT OFFERED
# 2                 NaN                 NaN               NaN               NaN
# 3                 NaN                 NaN               NaN  TEST NOT OFFERED
# 4                 NaN                 NaN               NaN  TEST NOT OFFERED
# ...               ...                 ...               ...               ...
# 83484             NaN                 NaN               NaN  TEST NOT OFFERED
# 83485             NaN                 NaN               NaN  TEST NOT OFFERED
# 83486             NaN                 NaN               NaN  TEST NOT OFFERED
# 83487             NaN                 NaN               NaN  TEST NOT OFFERED
# 83488             NaN                 NaN               NaN               NaN
#
#       BAC_RESULT VALUE CELL_PHONE_USE
# 0                  NaN            NaN
# 1                  NaN            NaN
# 2                  NaN            NaN
# 3                  NaN            NaN
# 4                  NaN            NaN
# ...                ...            ...
# 83484              NaN            NaN
# 83485              NaN            NaN
# 83486              NaN            NaN
# 83487              NaN            NaN
# 83488              NaN            NaN
#
# [81594 rows x 144 columns]

# %% [markdown]
# **Inspection 2**

# %%
merged_data.groupby(['STREET_NAME']).size().reset_index(name='count').sort_values(['count'], ascending=False).head(20)
# Out:
#          STREET_NAME  count
# 1078     WESTERN AVE   2352
# 928       PULASKI RD   2095
# 350       CICERO AVE   1964
# 235      ASHLAND AVE   1937
# 528       HALSTED ST   1593
# 613       KEDZIE AVE   1367
# 782     MICHIGAN AVE   1042
# 840        NORTH AVE    987
# 1007        STATE ST    977
# 310   CALIFORNIA AVE    971
# 511        GRAND AVE    919
# 594   IRVING PARK RD    886
# 392        DAMEN AVE    880
# 143          63RD ST    877
# 328      CENTRAL AVE    822
# 353         CLARK ST    820
# 187          87TH ST    818
# 226       ARCHER AVE    805
# 487    FULLERTON AVE    804
# 266      BELMONT AVE    803

# %%
print("Wrong joins could have resulted in 6 rows. Here we see 2 rows, meaning the join was successful.")
merged_data[merged_data.RD_NO=='JC301403'] #Wrong joins could result in 6 rows
# Out:
# Wrong joins could have resulted in 6 rows. Here we see 2 rows, meaning the join was successful.
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 1  0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 2  0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
#
#   CRASH_DATE_EST_I          CRASH_DATE POSTED_SPEED_LIMIT  \
# 0              NaN 2019-06-11 08:40:00                 30
# 1              NaN 2019-06-11 08:40:00                 30
# 2              NaN 2019-06-11 08:40:00                 30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#   LIGHTING_CONDITION FIRST_CRASH_TYPE             TRAFFICWAY_TYPE LANE_CNT  \
# 0           DAYLIGHT         REAR END  DIVIDED - W/MEDIAN BARRIER      NaN
# 1           DAYLIGHT         REAR END  DIVIDED - W/MEDIAN BARRIER      NaN
# 2           DAYLIGHT         REAR END  DIVIDED - W/MEDIAN BARRIER      NaN
#
#             ALIGNMENT ROADWAY_SURFACE_COND ROAD_DEFECT  \
# 0  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
# 1  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
# 2  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
#
#                   REPORT_TYPE              CRASH_TYPE INTERSECTION_RELATED_I  \
# 0  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                      Y
# 1  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                      Y
# 2  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                      Y
#
#   NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I         DAMAGE DATE_POLICE_NOTIFIED  \
# 0                NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
# 1                NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
# 2                NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
#
#   PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_NO STREET_DIRECTION  \
# 0     UNABLE TO DETERMINE         NOT APPLICABLE        50                E
# 1     UNABLE TO DETERMINE         NOT APPLICABLE        50                E
# 2     UNABLE TO DETERMINE         NOT APPLICABLE        50                E
#
#      STREET_NAME BEAT_OF_OCCURRENCE PHOTOS_TAKEN_I STATEMENTS_TAKEN_I  \
# 0  GARFIELD BLVD                225            NaN                NaN
# 1  GARFIELD BLVD                225            NaN                NaN
# 2  GARFIELD BLVD                225            NaN                NaN
#
#   DOORING_I WORK_ZONE_I WORK_ZONE_TYPE WORKERS_PRESENT_I NUM_UNITS  \
# 0       NaN         NaN            NaN               NaN         2
# 1       NaN         NaN            NaN               NaN         2
# 2       NaN         NaN            NaN               NaN         2
#
#         MOST_SEVERE_INJURY INJURIES_TOTAL INJURIES_FATAL  \
# 0  NO INDICATION OF INJURY              0              0
# 1  NO INDICATION OF INJURY              0              0
# 2  NO INDICATION OF INJURY              0              0
#
#   INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 0                       0                           0
# 1                       0                           0
# 2                       0                           0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                             0                      3                0
# 1                             0                      3                0
# 2                             0                      3                0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH      LATITUDE      LONGITUDE  \
# 0          8                 3           6  41.794778764  -87.623828038
# 1          8                 3           6  41.794778764  -87.623828038
# 2          8                 3           6  41.794778764  -87.623828038
#
#                                    LOCATION CRASH_UNIT_ID UNIT_NO UNIT_TYPE  \
# 0  POINT (-87.623828038036 41.794778764028)        667550       1    DRIVER
# 1  POINT (-87.623828038036 41.794778764028)        667551       2    DRIVER
# 2  POINT (-87.623828038036 41.794778764028)        667551       2    DRIVER
#
#   NUM_PASSENGERS VEHICLE_ID CMRC_VEH_I       MAKE      MODEL LIC_PLATE_STATE  \
# 0            NaN     635502        NaN  CHEVROLET    EQUINOX              IL
# 1              1     635496        NaN  CHEVROLET  SILVERADO              IL
# 2              1     635496        NaN  CHEVROLET  SILVERADO              IL
#
#   VEHICLE_YEAR VEHICLE_DEFECT                 VEHICLE_TYPE VEHICLE_USE  \
# 0         2017        UNKNOWN  SPORT UTILITY VEHICLE (SUV)  UNKNOWN/NA
# 1         2016           NONE                       PICKUP    PERSONAL
# 2         2016           NONE                       PICKUP    PERSONAL
#
#   TRAVEL_DIRECTION             MANEUVER TOWED_I FIRE_I OCCUPANT_CNT  \
# 0                W       STRAIGHT AHEAD     NaN    NaN            1
# 1                W  STARTING IN TRAFFIC     NaN    NaN            2
# 2                W  STARTING IN TRAFFIC     NaN    NaN            2
#
#   EXCEED_SPEED_LIMIT_I TOWED_BY TOWED_TO AREA_00_I AREA_01_I AREA_02_I  \
# 0                  NaN      NaN      NaN       NaN       NaN       NaN
# 1                  NaN      NaN      NaN       NaN       NaN       NaN
# 2                  NaN      NaN      NaN       NaN       NaN       NaN
#
#   AREA_03_I AREA_04_I AREA_05_I AREA_06_I AREA_07_I AREA_08_I AREA_09_I  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN         Y       NaN       NaN       NaN
# 2       NaN       NaN       NaN         Y       NaN       NaN       NaN
#
#   AREA_10_I AREA_11_I AREA_12_I AREA_99_I FIRST_CONTACT_POINT CMV_ID USDOT_NO  \
# 0       NaN       NaN         Y       NaN               OTHER    NaN      NaN
# 1       NaN       NaN       NaN       NaN           REAR-LEFT    NaN      NaN
# 2       NaN       NaN       NaN       NaN           REAR-LEFT    NaN      NaN
#
#   CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR CARRIER_NAME CARRIER_STATE CARRIER_CITY  \
# 0     NaN     NaN            NaN  NaN          NaN           NaN          NaN
# 1     NaN     NaN            NaN  NaN          NaN           NaN          NaN
# 2     NaN     NaN            NaN  NaN          NaN           NaN          NaN
#
#   HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO HAZMAT_PRESENT_I HAZMAT_REPORT_I  \
# 0               NaN         NaN   NaN              NaN             NaN
# 1               NaN         NaN   NaN              NaN             NaN
# 2               NaN         NaN   NaN              NaN             NaN
#
#   HAZMAT_REPORT_NO MCS_REPORT_I MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I  \
# 0              NaN          NaN           NaN                      NaN
# 1              NaN          NaN           NaN                      NaN
# 2              NaN          NaN           NaN                      NaN
#
#   MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO WIDE_LOAD_I TRAILER1_WIDTH  \
# 0                   NaN            NaN         NaN            NaN
# 1                   NaN            NaN         NaN            NaN
# 2                   NaN            NaN         NaN            NaN
#
#   TRAILER2_WIDTH TRAILER1_LENGTH TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH  \
# 0            NaN             NaN             NaN                  NaN
# 1            NaN             NaN             NaN                  NaN
# 2            NaN             NaN             NaN                  NaN
#
#   AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I  \
# 0      NaN            NaN             NaN       NaN                     NaN
# 1      NaN            NaN             NaN       NaN                     NaN
# 2      NaN            NaN             NaN       NaN                     NaN
#
#   MCS_OUT_OF_SERVICE_I HAZMAT_CLASS PERSON_ID PERSON_TYPE SEAT_NO  \
# 0                  NaN          NaN   O667550      DRIVER     NaN
# 1                  NaN          NaN   O667551      DRIVER     NaN
# 2                  NaN          NaN   P151614   PASSENGER       3
#
#           CITY STATE ZIPCODE SEX AGE DRIVERS_LICENSE_STATE  \
# 0     HOMEWOOD    IL   60430   F  56                    IL
# 1  PALOS HILLS    IL   60465   M  51                    IL
# 2      CHICAGO    IL   60620   M  21                   NaN
#
#   DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT AIRBAG_DEPLOYED EJECTION  \
# 0                     D     USAGE UNKNOWN  DID NOT DEPLOY     NONE
# 1                     D  SAFETY BELT USED  DID NOT DEPLOY     NONE
# 2                   NaN  SAFETY BELT USED  DID NOT DEPLOY     NONE
#
#      INJURY_CLASSIFICATION HOSPITAL EMS_AGENCY EMS_RUN_NO DRIVER_ACTION  \
# 0  NO INDICATION OF INJURY      NaN        NaN        NaN       UNKNOWN
# 1  NO INDICATION OF INJURY      NaN        NaN        NaN          NONE
# 2  NO INDICATION OF INJURY      NaN        NaN        NaN           NaN
#
#   DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION PEDPEDAL_VISIBILITY  \
# 0       UNKNOWN             NORMAL             NaN                 NaN
# 1  NOT OBSCURED             NORMAL             NaN                 NaN
# 2           NaN                NaN             NaN                 NaN
#
#   PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE CELL_PHONE_USE
# 0               NaN  TEST NOT OFFERED              NaN            NaN
# 1               NaN  TEST NOT OFFERED              NaN            NaN
# 2               NaN               NaN              NaN            NaN

# %% [markdown]
# ## Splitting the data

# %%
# Alternative: X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
raw_train, raw_test = train_test_split(merged_data, test_size=0.20, random_state=42, shuffle=True)

# %%
print("Train shape", raw_train.shape)
print("Test shape", raw_test.shape)
# Out:
# Train shape (66791, 144)
# Test shape (16698, 144)

# %% [markdown]
# **Write datasets as csv**

# %%
# save the train and test file
#train.to_csv('~/repos/vision_zero_chicago_project/sprint 2/raw_train.csv')
#test.to_csv('~/repos/vision_zero_chicago_project/sprint 2/raw_test.csv')

# %% [markdown]
# # Feature Reduction

# %% [markdown]
# ## Detailed look at all features

# %%
raw_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66791 entries, 904 to 15795
# Columns: 144 entries, CRASH_RECORD_ID to CELL_PHONE_USE
# dtypes: datetime64[ns](2), object(142)
# memory usage: 73.9+ MB

# %% [markdown]
# | **Feature** | **Description** | **Decision to drop** |
# |:-----|:----:|----:|
# | CRASH_RECORD_ID | This number can be used to link to the same crash in the Vehicles and People datasets. This number also serves as a unique ID in this dataset. | NO |
# | RD_NO | Chicago Police Department report number. For privacy reasons, this column is blank for recent crashes. | YES |
# | CRASH_DATE_EST_I | Crash date estimated by desk officer or reporting party (only used in cases where crash is reported at police station days after the crash) | YES |
# | CRASH_DATE | Date and time of crash as entered by the reporting officer | NO |
# | POSTED_SPEED_LIMIT | Posted speed limit, as determined by reporting officer | NO |
# | TRAFFIC_CONTROL_DEVICE | Traffic control device present at crash location, as determined by reporting officer | NO |
# | DEVICE_CONDITION | Condition of traffic control device, as determined by reporting officer | NO |
# | WEATHER_CONDITION | Weather condition at time of crash, as determined by reporting officer | NO |
# | LIGHTING_CONDITION | Light condition at time of crash, as determined by reporting officer | NO |
# | FIRST_CRASH_TYPE | Type of first collision in crash | NO |
# | TRAFFICWAY_TYPE | Trafficway type, as determined by reporting officer | NO |
# | LANE_CNT | Total number of through lanes in either direction, excluding turn lanes, as determined by reporting officer (0 = intersection) | NO |
# | ALIGNMENT | Street alignment at crash location, as determined by reporting officer | NO |
# | ROADWAY_SURFACE_COND | Road surface condition, as determined by reporting officer | NO |
# | ROAD_DEFECT | Road defects, as determined by reporting officer | NO |
# | REPORT_TYPE | Administrative report type (at scene, at desk, amended) | YES |
# | CRASH_TYPE | A general severity classification for the crash. Can be either Injury and/or Tow Due to Crash or No Injury / Drive Away | NO |
# | INTERSECTION_RELATED_I |A field observation by the police officer whether an intersection played a role in the crash. Does not represent whether or not the crash occurred within the intersection. | NO |
# | NOT_RIGHT_OF_WAY_I | Whether the crash begun or first contact was made outside of the public right-of-way. | NO |
# | HIT_AND_RUN_I | Crash did/did not involve a driver who caused the crash and fled the scene without exchanging information and/or rendering aid | NO |
# | DAMAGE | A field observation of estimated damage. | NO |
# | DATE_POLICE_NOTIFIED | Calendar date on which police were notified of the crash | YES |
# | PRIM_CONTRIBUTORY_CAUSE | The factor which was most significant in causing the crash, as determined by officer judgment | NO |
# | SEC_CONTRIBUTORY_CAUSE | The factor which was second most significant in causing the crash, as determined by officer judgment | NO |
# | STREET_NO | Street address number of crash location, as determined by reporting officer | NO |
# | STREET_DIRECTION | Street address direction (N,E,S,W) of crash location, as determined by reporting officer | NO |
# | STREET_NAME | Street address name of crash location, as determined by reporting officer | NO |
# | BEAT_OF_OCCURRENCE | Chicago Police Department Beat ID | YES |
# | PHOTOS_TAKEN_I | Whether the Chicago Police Department took photos at the location of the crash | YES |
# | STATEMENTS_TAKEN_I | Whether statements were taken from unit(s) involved in crash | YES |
# | DOORING_I | Whether crash involved a motor vehicle occupant opening a door into the travel path of a bicyclist, causing a crash | NO |
# | WORK_ZONE_I | Whether the crash occurred in an active work zone | NO |
# | WORK_ZONE_TYPE | The type of work zone, if any | YES |
# | WORKERS_PRESENT_I | Whether construction workers were present in an active work zone at crash location | YES |
# | NUM_UNITS | Number of units involved in the crash. A unit can be a motor vehicle, a pedestrian, a bicyclist, or another non-passenger roadway user. Each unit represents a mode of traffic with an independent trajectory. | NO |
# | MOST_SEVERE_INJURY | Most severe injury sustained by any person involved in the crash | NO |
# | INJURIES_TOTAL | Total persons sustaining fatal, incapacitating, non-incapacitating, and possible injuries as determined by the reporting officer | NO |
# | INJURIES_FATAL | Total persons sustaining fatal injuries in the crash | NO |
# | INJURIES_INCAPACITATING | Total persons sustaining incapacitating/serious injuries in the crash as determined by the reporting officer. Any injury other than fatal injury, which prevents the injured person from walking, driving, or normally continuing the activities they were capable of performing before the injury occurred. Includes severe lacerations, broken limbs, skull or chest injuries, and abdominal injuries. | NO |
# | INJURIES_NON_INCAPACITATING | Total persons sustaining non-incapacitating injuries in the crash as determined by the reporting officer. Any injury, other than fatal or incapacitating injury, which is evident to observers at the scene of the crash. Includes lump on head, abrasions, bruises, and minor lacerations. | NO |
# | INJURIES_REPORTED_NOT_EVIDENT | Total persons sustaining possible injuries in the crash as determined by the reporting officer. Includes momentary unconsciousness, claims of injuries not evident, limping, complaint of pain, nausea, and hysteria. | NO |
# | INJURIES_NO_INDICATION | Total persons sustaining no injuries in the crash as determined by the reporting officer | YES |
# | INJURIES_UNKNOWN | Total persons for whom injuries sustained, if any, are unknown | YES |
# | CRASH_HOUR | The hour of the day component of CRASH_DATE. | NO |
# | CRASH_DAY_OF_WEEK | The day of the week component of CRASH_DATE. Sunday=1 | YES |
# | CRASH_MONTH | The month component of CRASH_DATE. | YES |
# | LATITUDE | The latitude of the crash location, as determined by reporting officer, as derived from the reported address of crash | NO |
# | LONGITUDE | The longitude of the crash location, as determined by reporting officer, as derived from the reported address of crash | NO |
# | LOCATION | The crash location, as determined by reporting officer, as derived from the reported address of crash, in a column type that allows for mapping and other geographic analysis in the data portal software | YES || PERSON_ID | A unique identifier for each person record. IDs starting with P indicate passengers. IDs starting with O indicate a person who was not a passenger in the vehicle (e.g., driver, pedestrian, cyclist, etc.). | NO |
# | PERSON_TYPE | Type of roadway user involved in crash | NO |
# | CRASH_RECORD_ID | This number can be used to link to the same crash in the Crashes and Vehicles datasets. This number also serves as a unique ID in the Crashes dataset. | NO |
# | RD_NO | Chicago Police Department report number. For privacy reasons, this column is blank for recent crashes. | YES |
# | VEHICLE_ID | The corresponding CRASH_UNIT_ID from the Vehicles dataset. | YES |
# | CRASH_DATE | Date and time of crash as entered by the reporting officer | YES |
# | SEAT_NO | Code for seating position of motor vehicle occupant: 1= driver, 2= center front, 3 = front passenger, 4 = second row left, 5 = second row center, 6 = second row right, 7 = enclosed passengers, 8 = exposed passengers, 9= unknown position, 10 = third row left, 11 = third row center, 12 = third row right | YES |
# | CITY | City of residence of person involved in crash | NO |
# | STATE | State of residence of person involved in crash | YES |
# | ZIPCODE | ZIP Code of residence of person involved in crash | YES |
# | SEX | Gender of person involved in crash, as determined by reporting officer | NO |
# | AGE | Age of person involved in crash | NO |
# | DRIVERS_LICENSE_STATE | State issuing driver's license of person involved in crash | YES |
# | DRIVERS_LICENSE_CLASS| Class of driver's license of person involved in crash | YES |
# | SAFETY_EQUIPMENT | Safety equipment used by vehicle occupant in crash, if any | NO |
# | AIRBAG_DEPLOYED | Whether vehicle occupant airbag deployed as result of crash | NO |
# | EJECTION | Whether vehicle occupant was ejected or extricated from the vehicle as a result of crash | NO |
# | INJURY_CLASSIFICATION | Severity of injury person sustained in the crash | YES |
# | HOSPITAL | Hospital to which person injured in the crash was taken | YES |
# | EMS_AGENCY | EMS agency who transported person injured in crash to the hospital | YES |
# | EMS_RUN_NO | EMS agency run number | YES |
# | DRIVER_ACTION | Driver action that contributed to the crash, as determined by reporting officer | NO |
# | DRIVER_VISION | What, if any, objects obscured the driver’s vision at time of crash | NO |
# | PHYSICAL_CONDITION | Driver’s apparent physical condition at time of crash, as observed by the reporting officer | NO |
# | PEDPEDAL_ACTION | Action of pedestrian or cyclist at the time of crash | NO |
# | PEDPEDAL_VISIBILITY | Visibility of pedestrian of cyclist safety equipment in use at time of crash | NO |
# | PEDPEDAL_LOCATION | Location of pedestrian or cyclist at the time of crash | YES |
# | BAC_RESULT | Status of blood alcohol concentration testing for driver or other person involved in crash | YES |
# | BAC_RESULT VALUE | Driver’s blood alcohol concentration test result | NO |
# | CELL_PHONE_USE | Whether person was/was not using cellphone at the time of the crash, as determined by the reporting officer | NO |
# |CRASH_UNIT_ID | A unique identifier for each vehicle record | YES |
# |CRASH_RECORD_ID | This number can be used to link to the same crash in the Crashes and People datasets. This number also serves as a unique ID in the Crashes dataset | NO |
# |RD_NO | Chicago Police Department report number. For privacy reasons, this column is blank for recent crashes | Yes |
# |CRASH_DATE| Date and time of crash as entered by the reporting officer | No |
# |UNIT_NO| A unique ID for each unit within a specific crash report | Yes |
# |UNIT_TYPE| Type of unit | Yes |
# |NUM_PASSENGERS| Number of passengers in the vehicle. The driver is not included. More information on passengers is in the People dataset | No |
# |VEHICLE_ID| No definition | Yes |
# |CMRC_VEH_I| No definition | Yes |
# |MAKE| The make (brand) of the vehicle, if relevant | YES |
# |MODEL| The model of the vehicle, if relevant| NO |
# |LIC_PLATE_STATE| The state issuing the license plate of the vehicle, if relevant | No |
# |VEHICLE_YEAR| The model year of the vehicle, if relevant | No |
# |VEHICLE_DEFECT| No definition | No |
# |VEHICLE_TYPE| The type of vehicle, if relevant | No |
# |TRAVEL_DIRECTION| The direction in which the unit was traveling prior to the crash, as determined by the reporting officer | No |
# |MANEUVER| The action the unit was taking prior to the crash, as determined by the reporting officer | NO |
# |TOWED_I| Indicator of whether the vehicle was towed | Yes |
# |FIRE_I| No definition | Yes |
# |OCCUPANT_COUNT| The number of people in the unit, as determined by the reporting officer | No |
# |EXCEED_SPEED_LIMIT_I| Indicator of whether the unit was speeding, as determined by the reporting officer | No |
# |TOWED_BY| No definition | Yes |
# |TOWED_TO| No definition | Yes |
# |AREA_00_I:AREA_99_I| No definition | Yes |
# |FIRST_CONTACT_POINT| No definition | No |
# |CMV_ID:HAZMAT_CLASS| No definition | Yes |
#
#
# **Features to be excluded are**
# - `RD_NO`
# - `CRASH_DATE_EST_I`
# - `REPORT_TYPE`
# - `CRASH_DATE_EST_I`
# - `REPORT_TYPE`
# - `CRASH_TYPE`
# - `NOT_RIGHT_OF_WAY_I`
# - `DATE_POLICE_NOTIFIED`
# - `STREET_DIRECTION`
# - `ALIGNMENT`
# - `BEAT_OF_OCCURRENCE`
# - `PHOTOS_TAKEN_I`
# - `STATEMENTS_TAKEN_I`
# - `DOORING_I`
# - `WORK_ZONE_I`
# - `WORK_ZONE_TYPE`
# - `WORKERS_PRESENT_I`
# - `MOST_SEVERE_INJURY`
# - `INJURIES_NO_INDICATION`
# - `INJURIES_UNKNOWN`
# - `CRASH_DAY_OF_WEEK`
# - `CRASH_MONTH`
# - `LATITUDE`
# - `LONGITUDE`
# - `RD_NO`
# - `VEHICLE_ID`
# - `CRASH_DATE`
# - `SEAT_NO`
# - `CITY`
# - `STATE`
# - `ZIPCODE`
# - `DRIVERS_LICENSE_STATE`
# - `DRIVERS_LICENSE_CLASS`
# - `INJURY_CLASSIFICATION`
# - `HOSPITAL`
# - `EMS_AGENCY`
# - `EMS_RUN_NO`
# - `PEDPEDAL_ACTION`
# - `PEDPEDAL_VISIBILITY`
# - `PEDPEDAL_LOCATION`
# - `BAC_RESULT`
# - `BAC_RESULT VALUE`
# - `CRASH_UNIT_ID`
# - `RD_NO`
# - `UNIT_NO`
# - `UNIT_TYPE`
# - `VEHICLE_ID`
# - `CMRC_VEH_I`
# - `MAKE`
# - `MODEL`
# - `TOWED_I`
# - `FIRE_I`
# - `TOWED_BY`
# - `TOWED_TO`
# - `AREA_00_I`
# - `AREA_01_I`
# - `AREA_02_I`
# - `AREA_03_I`
# - `AREA_04_I`
# - `AREA_05_I`
# - `AREA_06_I`
# - `AREA_07_I`
# - `AREA_08_I`
# - `AREA_09_I`
# - `AREA_10_I`
# - `AREA_11_I`
# - `AREA_12_I`
# - `AREA_99_I`
# - `CMV_ID:HAZMAT_CLASS`
#
#
#
#
# **Due to the reasons**
# - Redundant information
# - Non value information (at least for our baseline model)

# %% [markdown]
# Do not drop "SEAT_NO"

# %%
# Drop the features that are not needed
# Do not drop "SEAT_NO", 
feature_drop_train = ["CRASH_DATE_EST_I", "REPORT_TYPE", "CRASH_DATE_EST_I", "REPORT_TYPE", 
                      "DATE_POLICE_NOTIFIED","BEAT_OF_OCCURRENCE", "PHOTOS_TAKEN_I", "STATEMENTS_TAKEN_I", 
                      "WORK_ZONE_TYPE", "WORKERS_PRESENT_I","INJURIES_NO_INDICATION", "INJURIES_UNKNOWN",
                      "CRASH_DAY_OF_WEEK", "CRASH_MONTH", "RD_NO", "VEHICLE_ID", "CRASH_RECORD_ID",
                      "STATE", "ZIPCODE", "DRIVERS_LICENSE_STATE", "PERSON_ID",
                      "DRIVERS_LICENSE_CLASS", "INJURY_CLASSIFICATION", "HOSPITAL", "EMS_AGENCY", 
                      "EMS_RUN_NO", "PEDPEDAL_LOCATION", "LOCATION","DAMAGE","CRASH_TYPE","MODEL",
                      "BAC_RESULT", "CRASH_UNIT_ID", "RD_NO", "UNIT_NO", "UNIT_TYPE", "VEHICLE_ID", 
                      "CMRC_VEH_I", "MAKE", "TOWED_I", "FIRE_I", "TOWED_BY", "STREET_NO","STREET_NAME",
                      "TOWED_TO", "AREA_00_I", "AREA_01_I", "AREA_02_I", "AREA_03_I", "AREA_04_I", 
                      "AREA_05_I", "AREA_06_I", "AREA_07_I", "AREA_08_I", "AREA_09_I", "AREA_10_I", 
                      "AREA_11_I", "AREA_12_I", "AREA_99_I", "CMV_ID", "USDOT_NO", "CCMC_NO", 
                      "ILCC_NO", "COMMERCIAL_SRC", "GVWR", "CARRIER_NAME", "CARRIER_STATE", "CARRIER_CITY",
                      "HAZMAT_PLACARDS_I", "HAZMAT_NAME", "UN_NO", "HAZMAT_PRESENT_I", "HAZMAT_REPORT_I",
                      "HAZMAT_REPORT_NO", "MCS_REPORT_I", "MCS_REPORT_NO", "HAZMAT_VIO_CAUSE_CRASH_I", 
                      "MCS_VIO_CAUSE_CRASH_I", "IDOT_PERMIT_NO", "WIDE_LOAD_I", "TRAILER1_WIDTH", 
                      "TRAILER2_WIDTH", "TRAILER1_LENGTH", "TRAILER2_LENGTH", "TOTAL_VEHICLE_LENGTH",
                      "AXLE_CNT", "VEHICLE_CONFIG", "CARGO_BODY_TYPE", "LOAD_TYPE", "HAZMAT_OUT_OF_SERVICE_I",
                      "INJURIES_FATAL","INJURIES_INCAPACITATING","INJURIES_NON_INCAPACITATING","INJURIES_REPORTED_NOT_EVIDENT",
                      "MCS_OUT_OF_SERVICE_I", "HAZMAT_CLASS"]

train = raw_train.loc[:, ~raw_train.columns.isin(feature_drop_train)]
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66791 entries, 904 to 15795
# Data columns (total 52 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CRASH_DATE               66791 non-null  datetime64[ns]
#  1   POSTED_SPEED_LIMIT       66791 non-null  object
#  2   TRAFFIC_CONTROL_DEVICE   66791 non-null  object
#  3   DEVICE_CONDITION         66791 non-null  object
#  4   WEATHER_CONDITION        66791 non-null  object
#  5   LIGHTING_CONDITION       66791 non-null  object
#  6   FIRST_CRASH_TYPE         66791 non-null  object
#  7   TRAFFICWAY_TYPE          66791 non-null  object
#  8   LANE_CNT                 22188 non-null  object
#  9   ALIGNMENT                66791 non-null  object
#  10  ROADWAY_SURFACE_COND     66791 non-null  object
#  11  ROAD_DEFECT              66791 non-null  object
#  12  INTERSECTION_RELATED_I   17201 non-null  object
#  13  NOT_RIGHT_OF_WAY_I       2753 non-null   object
#  14  HIT_AND_RUN_I            18778 non-null  object
#  15  PRIM_CONTRIBUTORY_CAUSE  66791 non-null  object
#  16  SEC_CONTRIBUTORY_CAUSE   66791 non-null  object
#  17  STREET_DIRECTION         66791 non-null  object
#  18  DOORING_I                195 non-null    object
#  19  WORK_ZONE_I              371 non-null    object
#  20  NUM_UNITS                66791 non-null  object
#  21  MOST_SEVERE_INJURY       66678 non-null  object
#  22  INJURIES_TOTAL           66679 non-null  object
#  23  CRASH_HOUR               66791 non-null  object
#  24  LATITUDE                 66426 non-null  object
#  25  LONGITUDE                66426 non-null  object
#  26  NUM_PASSENGERS           20455 non-null  object
#  27  LIC_PLATE_STATE          60714 non-null  object
#  28  VEHICLE_YEAR             56056 non-null  object
#  29  VEHICLE_DEFECT           65335 non-null  object
#  30  VEHICLE_TYPE             65335 non-null  object
#  31  VEHICLE_USE              65335 non-null  object
#  32  TRAVEL_DIRECTION         65335 non-null  object
#  33  MANEUVER                 65335 non-null  object
#  34  OCCUPANT_CNT             65335 non-null  object
#  35  EXCEED_SPEED_LIMIT_I     231 non-null    object
#  36  FIRST_CONTACT_POINT      64814 non-null  object
#  37  PERSON_TYPE              59757 non-null  object
#  38  SEAT_NO                  12613 non-null  object
#  39  CITY                     44454 non-null  object
#  40  SEX                      58822 non-null  object
#  41  AGE                      43284 non-null  object
#  42  SAFETY_EQUIPMENT         59538 non-null  object
#  43  AIRBAG_DEPLOYED          58442 non-null  object
#  44  EJECTION                 58849 non-null  object
#  45  DRIVER_ACTION            46995 non-null  object
#  46  DRIVER_VISION            46989 non-null  object
#  47  PHYSICAL_CONDITION       47041 non-null  object
#  48  PEDPEDAL_ACTION          1289 non-null   object
#  49  PEDPEDAL_VISIBILITY      1288 non-null   object
#  50  BAC_RESULT VALUE         104 non-null    object
#  51  CELL_PHONE_USE           52 non-null     object
# dtypes: datetime64[ns](1), object(51)
# memory usage: 27.0+ MB

# %%
train['SEAT_NO'].value_counts()
# Code for seating position of motor vehicle occupant: 1= driver, 2= center front, 
# 3 = front passenger, 4 = second row left, 5 = second row center, 
# 6 = second row right, 7 = enclosed passengers, 8 = exposed passengers, 
# 9= unknown position, 10 = third row left, 11 = third row center, 12 = third row right
# Out:
# 3     5983
# 6     2179
# 4     1728
# 5      626
# 1      548
# 2      519
# 12     335
# 10     286
# 7      261
# 11     130
# 8       18
# Name: SEAT_NO, dtype: int64

# %%
#train["PERSON_ID"].value_counts()

# %% [markdown]
# TRAFFIC_CONTROL_DEVICE- UNKNOWN, OTHER
# DEVICE_CONDITION - UNKNOWN, OTHER
# WEATHER_CONDITION - UNKNOWN, OTHER
# LIGHTING_CONDITION - UNKNOWN
# TRAFFICWAY_TYPE - UNKNOWN, OTHER
# ROADWAY_SURFACE_COND - UNKNOWN, OTHER
# ROAD_DEFECT - UNKNOWN, OTHER
# PRIM_CONTRIBUTORY_CAUSE- UNABLE TO DETERMINE
# SEC_CONTRIBUTORY_CAUSE - UNABLE TO DETERMINE
# MODEL - UNKNOWN
# VEHICLE_DEFECT - UNKNOWN, OTHER
# VEHICLE_TYPE - UNKNOWN/NA
# TRAVEL_DIRECTION - UNKNOWN
# MANEUVER - UNKNOWN/NA
# SEX - X
# SAFETY_EQUIPMENT - USAGE UNKNOWN
# AIRBAG_DEPLOYED - DEPLOYMENT UNKNOWN
# EJECTION - UNKNOWN
# DRIVER_ACTION - UNKNOWN
# DRIVER_VISION - UNKNOWN
# PHYSICAL_CONDITION - UNKNOWN
# PEDPEDAL_ACTION - UNKNOWN/NA

# %%
train.loc[train["TRAFFIC_CONTROL_DEVICE"]=="UNKNOWN","TRAFFIC_CONTROL_DEVICE"]=np.nan
train.loc[train["DEVICE_CONDITION"]=="UNKNOWN","DEVICE_CONDITION"]=np.nan
train.loc[train["WEATHER_CONDITION"]=="UNKNOWN","WEATHER_CONDITION"]=np.nan
train.loc[train["LIGHTING_CONDITION"]=="UNKNOWN","LIGHTING_CONDITION"]=np.nan
train.loc[train["TRAFFICWAY_TYPE"]=="UNKNOWN","TRAFFICWAY_TYPE"]=np.nan
train.loc[train["ROADWAY_SURFACE_COND"]=="UNKNOWN","ROADWAY_SURFACE_COND"]=np.nan
train.loc[train["ROAD_DEFECT"]=="UNKNOWN","ROAD_DEFECT"]=np.nan

train.loc[train["VEHICLE_DEFECT"]=="UNKNOWN","VEHICLE_DEFECT"]=np.nan
train.loc[train["VEHICLE_TYPE"]=="UNKNOWN/NA","VEHICLE_TYPE"]=np.nan
train.loc[train["TRAVEL_DIRECTION"]=="UNKNOWN","TRAVEL_DIRECTION"]=np.nan
train.loc[train["MANEUVER"]=="UNKNOWN/NA","MANEUVER"]=np.nan

train.loc[train["SAFETY_EQUIPMENT"]=="USAGE UNKNOWN","SAFETY_EQUIPMENT"]=np.nan
train.loc[train["AIRBAG_DEPLOYED"]=="DEPLOYMENT UNKNOWN","AIRBAG_DEPLOYED"]=np.nan
train.loc[train["EJECTION"]=="UNKNOWN","EJECTION"]=np.nan
train.loc[train["DRIVER_ACTION"]=="UNKNOWN","DRIVER_ACTION"]=np.nan
train.loc[train["DRIVER_VISION"]=="UNKNOWN","DRIVER_VISION"]=np.nan
train.loc[train["PHYSICAL_CONDITION"]=="UNKNOWN","PHYSICAL_CONDITION"]=np.nan
train.loc[train["PEDPEDAL_ACTION"]=="UNKNOWN/NA","PEDPEDAL_ACTION"]=np.nan

# %%
train.isnull().sum()
# Out:
# CRASH_DATE                     0
# POSTED_SPEED_LIMIT             0
# TRAFFIC_CONTROL_DEVICE      1871
# DEVICE_CONDITION            3451
# WEATHER_CONDITION           2353
# LIGHTING_CONDITION          1948
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE              577
# LANE_CNT                   44603
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND        3910
# ROAD_DEFECT                 9248
# INTERSECTION_RELATED_I     49590
# NOT_RIGHT_OF_WAY_I         64038
# HIT_AND_RUN_I              48013
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# DOORING_I                  66596
# WORK_ZONE_I                66420
# NUM_UNITS                      0
# MOST_SEVERE_INJURY           113
# INJURIES_TOTAL               112
# CRASH_HOUR                     0
# LATITUDE                     365
# LONGITUDE                    365
# NUM_PASSENGERS             46336
# LIC_PLATE_STATE             6077
# VEHICLE_YEAR               10735
# VEHICLE_DEFECT             27497
# VEHICLE_TYPE                6549
# VEHICLE_USE                 1456
# TRAVEL_DIRECTION            5515
# MANEUVER                    5770
# OCCUPANT_CNT                1456
# EXCEED_SPEED_LIMIT_I       66560
# FIRST_CONTACT_POINT         1977
# PERSON_TYPE                 7034
# SEAT_NO                    54178
# CITY                       22337
# SEX                         7969
# AGE                        23507
# SAFETY_EQUIPMENT           33910
# AIRBAG_DEPLOYED            19282
# EJECTION                   10950
# DRIVER_ACTION              30843
# DRIVER_VISION              39747
# PHYSICAL_CONDITION         33783
# PEDPEDAL_ACTION            65656
# PEDPEDAL_VISIBILITY        65503
# BAC_RESULT VALUE           66687
# CELL_PHONE_USE             66739
# dtype: int64

# %%
msno.matrix(train)

# %%
train.groupby(['PERSON_TYPE']).size()
# Out:
# PERSON_TYPE
# BICYCLE                  416
# DRIVER                 45803
# NON-CONTACT VEHICLE       13
# NON-MOTOR VEHICLE         57
# PASSENGER              12613
# PEDESTRIAN               855
# dtype: int64

# %% [markdown]
# ## Missing value overview on train data

# %%
print('\033[1m', 'All 50 columns', '\033[0m')
print('\033[1m', 'These', sum(train.isnull().mean().round(5) > 0.5),
      'columns have > 50% missing values', '\033[0m')
print(train.columns[train.isnull().mean().round(5) > 0.5].tolist())
print('')
raw_null_above50 = train[train.columns[train.isnull().mean().round(5) > 0.5].tolist()]
print(raw_null_above50.isnull().mean().round(5))
print('')
# Subset the data to include the columns only with nulls in the output
train_with_null = train[train.columns[train.isnull().any()].tolist()]
print('\033[1m', 'These', len(train_with_null.columns),
      'columns have any missing values', '\033[0m')
train_with_null.isnull().mean().round(5)
# Out:
#  All 50 columns
#  These 16 columns have > 50% missing values
# ['LANE_CNT', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 'DOORING_I', 'WORK_ZONE_I', 'NUM_PASSENGERS', 'EXCEED_SPEED_LIMIT_I', 'SEAT_NO', 'SAFETY_EQUIPMENT', 'DRIVER_VISION', 'PHYSICAL_CONDITION', 'PEDPEDAL_ACTION', 'PEDPEDAL_VISIBILITY', 'BAC_RESULT VALUE', 'CELL_PHONE_USE']
#
# LANE_CNT                  0.66780
# INTERSECTION_RELATED_I    0.74247
# NOT_RIGHT_OF_WAY_I        0.95878
# HIT_AND_RUN_I             0.71885
# DOORING_I                 0.99708
# WORK_ZONE_I               0.99445
# NUM_PASSENGERS            0.69375
# EXCEED_SPEED_LIMIT_I      0.99654
# SEAT_NO                   0.81116
# SAFETY_EQUIPMENT          0.50770
# DRIVER_VISION             0.59510
# PHYSICAL_CONDITION        0.50580
# PEDPEDAL_ACTION           0.98301
# PEDPEDAL_VISIBILITY       0.98072
# BAC_RESULT VALUE          0.99844
# CELL_PHONE_USE            0.99922
# dtype: float64
#
#  These 43 columns have any missing values
# TRAFFIC_CONTROL_DEVICE    0.02801
# DEVICE_CONDITION          0.05167
# WEATHER_CONDITION         0.03523
# LIGHTING_CONDITION        0.02917
# TRAFFICWAY_TYPE           0.00864
# LANE_CNT                  0.66780
# ROADWAY_SURFACE_COND      0.05854
# ROAD_DEFECT               0.13846
# INTERSECTION_RELATED_I    0.74247
# NOT_RIGHT_OF_WAY_I        0.95878
# HIT_AND_RUN_I             0.71885
# DOORING_I                 0.99708
# WORK_ZONE_I               0.99445
# MOST_SEVERE_INJURY        0.00169
# INJURIES_TOTAL            0.00168
# LATITUDE                  0.00546
# LONGITUDE                 0.00546
# NUM_PASSENGERS            0.69375
# LIC_PLATE_STATE           0.09099
# VEHICLE_YEAR              0.16073
# VEHICLE_DEFECT            0.41169
# VEHICLE_TYPE              0.09805
# VEHICLE_USE               0.02180
# TRAVEL_DIRECTION          0.08257
# MANEUVER                  0.08639
# OCCUPANT_CNT              0.02180
# EXCEED_SPEED_LIMIT_I      0.99654
# FIRST_CONTACT_POINT       0.02960
# PERSON_TYPE               0.10531
# SEAT_NO                   0.81116
# CITY                      0.33443
# SEX                       0.11931
# AGE                       0.35195
# SAFETY_EQUIPMENT          0.50770
# AIRBAG_DEPLOYED           0.28869
# EJECTION                  0.16394
# DRIVER_ACTION             0.46178
# DRIVER_VISION             0.59510
# PHYSICAL_CONDITION        0.50580
# PEDPEDAL_ACTION           0.98301
# PEDPEDAL_VISIBILITY       0.98072
# BAC_RESULT VALUE          0.99844
# CELL_PHONE_USE            0.99922
# dtype: float64

# %%
train["PEDPEDAL_VISIBILITY"].value_counts()
# Out:
# NO CONTRASTING CLOTHING    1028
# CONTRASTING CLOTHING        168
# OTHER LIGHT SOURCE USED      63
# REFLECTIVE MATERIAL          29
# Name: PEDPEDAL_VISIBILITY, dtype: int64

# %%
# replacing TRAFFIC_CONTROL_DEVICE with No Controls 
# replacing DEVICE_CONDITION with No Controls 
# replace SEAT_NO with 0

train.fillna({
    'TRAFFIC_CONTROL_DEVICE': 'NO CONTROLS',
    'DEVICE_CONDITION': 'NO CONTROLS',
    'WEATHER_CONDITION': 'CLEAR',
    'LIGHTING_CONDITION': 'DAYLIGHT',
    'TRAFFICWAY_TYPE': 'NOT DIVIDED',
    'ROADWAY_SURFACE_COND': 'NO DEFECTS',
    'ROAD_DEFECT': 'CLEAR',
    'INTERSECTION_RELATED_I': 'N',
    
    'NOT_RIGHT_OF_WAY_I': 'N',
    'HIT_AND_RUN_I': 'N',
    'DOORING_I': 'N',
    'WORK_ZONE_I': 'N',
    'NUM_PASSENGERS': 0,
    'LIC_PLATE_STATE': 'IL',
    'VEHICLE_DEFECT': 'UNABLE TO DETERMINE',
    'VEHICLE_TYPE': 'OTHER',
    
    'VEHICLE_USE': 'OTHER',
    'TRAVEL_DIRECTION': 'N',
    'MANEUVER': 'OTHER',
    'OCCUPANT_CNT': 0,
    'EXCEED_SPEED_LIMIT_I': 'N',
    'FIRST_CONTACT_POINT': 'OTHER',
    'PERSON_TYPE': 'UNABLE TO DETERMINE',
    'CITY': 'OTHER',
    
    'SEX': 'UNABLE TO DETERMINE',
    'AIRBAG_DEPLOYED': 'UNABLE TO DETERMINE',
    'EJECTION': 'UNABLE TO DETERMINE',
    'DRIVER_ACTION': 'OTHER',
    'DRIVER_VISION': 'OTHER',
    'PHYSICAL_CONDITION': 'UNABLE TO DETERMINE',
    'PEDPEDAL_ACTION': 'UNABLE TO DETERMINE',
    'PEDPEDAL_VISIBILITY': 'UNABLE TO DETERMINE',
    
    'CELL_PHONE_USE': 'UNABLE TO DETERMINE',
    'SAFETY_EQUIPMENT': 'UNABLE TO DETERMINE',
    'BAC_RESULT VALUE': 0,
    'SEAT_NO':0
}, inplace=True)

# %%
train.isnull().sum()
# Out:
# CRASH_DATE                     0
# POSTED_SPEED_LIMIT             0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# LANE_CNT                   44603
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# INTERSECTION_RELATED_I         0
# NOT_RIGHT_OF_WAY_I             0
# HIT_AND_RUN_I                  0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# DOORING_I                      0
# WORK_ZONE_I                    0
# NUM_UNITS                      0
# MOST_SEVERE_INJURY           113
# INJURIES_TOTAL               112
# CRASH_HOUR                     0
# LATITUDE                     365
# LONGITUDE                    365
# NUM_PASSENGERS                 0
# LIC_PLATE_STATE                0
# VEHICLE_YEAR               10735
# VEHICLE_DEFECT                 0
# VEHICLE_TYPE                   0
# VEHICLE_USE                    0
# TRAVEL_DIRECTION               0
# MANEUVER                       0
# OCCUPANT_CNT                   0
# EXCEED_SPEED_LIMIT_I           0
# FIRST_CONTACT_POINT            0
# PERSON_TYPE                    0
# SEAT_NO                        0
# CITY                           0
# SEX                            0
# AGE                        23507
# SAFETY_EQUIPMENT               0
# AIRBAG_DEPLOYED                0
# EJECTION                       0
# DRIVER_ACTION                  0
# DRIVER_VISION                  0
# PHYSICAL_CONDITION             0
# PEDPEDAL_ACTION                0
# PEDPEDAL_VISIBILITY            0
# BAC_RESULT VALUE               0
# CELL_PHONE_USE                 0
# dtype: int64

# %% [markdown]
# | **Feature** | **Description** | **Decision on NA** |
# |:----|:----|:-----|
# | LANE_CNT | Total number of through lanes in either direction, excluding turn lanes, as determined by reporting officer (0 = intersection) | Replace with mode = 2 |
# | INTERSECTION_RELATED_I | A field observation by the police officer whether an intersection played a role in the crash. Does not represent whether or not the crash occurred within the intersection.Y&N | Replace with "N" |
# | HIT_AND_RUN_I |  Crash did/did not involve a driver who caused the crash and fled the scene without exchanging information and/or rendering aid Y&N | Replace with "N" |
# | INJURIES_TOTAL | Total persons sustaining fatal, incapacitating, non-incapacitating, and possible injuries as determined by the reporting officer | Replace with "0" |
# | INJURIES_FATAL | Total persons sustaining fatal injuries in the crash | Replace with "0" |
# | INJURIES_INCAPACITATING | Total persons sustaining incapacitating/serious injuries in the crash as determined by the reporting officer. Any injury other than fatal injury, which prevents the injured person from walking, driving, or normally continuing the activities they were capable of performing before the injury occurred. Includes severe lacerations, broken limbs, skull or chest injuries, and abdominal injuries. | Replace with "0" |
# | INJURIES_NON_INCAPACITATING | Total persons sustaining no injuries in the crash as determined by the reporting officer | Replace with "0" |
# | INJURIES_REPORTED_NOT_EVIDENT | Total persons sustaining possible injuries in the crash as determined by the reporting officer. Includes momentary unconsciousness, claims of injuries not evident, limping, complaint of pain, nausea, and hysteria. | Replace with "0" |
# | LOCATION | The crash location, as determined by reporting officer, as derived from the reported address of crash, in a column type that allows for mapping and other geographic analysis in the data portal software | DROP the row |
# | NUM_PASSENGERS | Number of passengers in the vehicle. The driver is not included. More information on passengers is in the People dataset. | DROP the column |
# | LIC_PLATE_STATE | The state issuing the license plate of the vehicle, if relevant | Replace with "IL" |
# | VEHICLE_YEAR | The model year of the vehicle, if relevant | DROP the row |
# | VEHICLE_DEFECT | no definition | Replace with "UNKNOWN" |
# | VEHICLE_TYPE | The type of vehicle, if relevant | Replace with "UNKNOWN/NA" |
# | VEHICLE_USE | The normal use of the vehicle, if relevant | Replace with "UNKNOWN/NA" |
# | TRAVEL_DIRECTION | The direction in which the unit was traveling prior to the crash, as determined by the reporting officer | Replace with "UNKNOWN" |
# | MANEUVER | The action the unit was taking prior to the crash, as determined by the reporting officer | Replace with "UNKNOWN/NA" |
# | OCCUPANT_CNT |The number of people in the unit, as determined by the reporting officer | DROP the row |
# | EXCEED_SPEED_LIMIT_I | Indicator of whether the unit was speeding, as determined by the reporting officer | DROP Column |
# | FIRST_CONTACT_POINT | No definition | Replace with "UNKNOWN" |
# | PERSON_ID | A unique identifier for each person record. IDs starting with P indicate passengers. IDs starting with O indicate a person who was not a passenger in the vehicle (e.g., driver, pedestrian, cyclist, etc.). | DROP the row |
# | PERSON_TYPE | Type of roadway user involved in crash | DROP the row |
# | SEX | Gender of person involved in crash, as determined by reporting officer | Replace with "X" |
# | AGE | Age of person involved in crash | Replace with mean |
# | SAFETY_EQUIPMENT | Safety equipment used by vehicle occupant in crash, if any | Replace with "USAGE UNKNOWN" |
# | AIRBAG_DEPLOYED | Whether vehicle occupant airbag deployed as result of crash | REplace with "DEPLOYMENT UNKNOWN" |
# | EJECTION | Whether vehicle occupant was ejected or extricated from the vehicle as a result of crash | Replace with "UNKNOWN" |
# | DRIVER_ACTION | Driver action that contributed to the crash, as determined by reporting officer | Replace with "UNKNOWN" |
# | DRIVER_VISION | What, if any, objects obscured the driver’s vision at time of crash| Replace with "UNKNOWN" |
# | PHYSICAL_CONDITION | Driver’s apparent physical condition at time of crash, as observed by the reporting officer | Replace with "UNKNOWN" |
# | CELL_PHONE_USE | Whether person was/was not using cellphone at the time of the crash, as determined by the reporting officer Y&N | DROP Column |

# %% [markdown]
# *Replace columns with 0*
# - 1. “INJURIES_TOTAL”: 97 missing data, replace with 0
# - 2. “INJURIES_FATAL”: 97 missing data, replace with 0
# - 3. “INJURIES_INCAPACITATING”: 97 missing data, replace with 0
# - 4. “INJURIES_NON_INCAPACITATING”: 97 missing data, replace with 0
# - 5. “INJURIES_REPORTED_NOT_EVIDENT”: 97 missing data, replace with 0
#
# *Replace with meaningful input*
# - 1. “LIC_PLATE_STATE”: 4,817 missing data, replace with "IL"
# - 2. "SEX": 6406 missing data, replace with "X"
# - 3. "SAFETY_EQUIPMENT" : 6,553 missing data, replace with "USAGE UNKNOWN"
# - 4. "AIRBAG_DEPLOYED" : 7,470 missing data, replace with "DEPLOYMENT UNKNOWN"
#
# *Replace with frequency (mode):*
# - 1. “LANE_CNT”: 30,763 missing data. Replace them with mode “2”
#
# *Replace with "N" to keep it binary:*
# - 1. “INTERSECTION_RELATED_I”: 34,718 missing data
# - 2. “HIT_AND_RUN_I”: 32,242 missing data
#
#
# *Replace with "UNKNOWN":*
# - 1. "VEHICLE_DEFECT": 1,225 missing data
# - 2. "TRAVEL_DIRECTION" : 1,225 missing data
# - 3. "FIRST_CONTACT_POINT" : 1,570 missing data
# - 4. "EJECTION" : 7,138 missing data
# - 5. "DRIVER_ACTION" : 6,511 missing data
# - 6. "DRIVER_VISION" : 6,518 missing data
# - 7. "PHYSICAL_CONDITION" : 6,466 missing data
#
# *Replace with "UNKNOWN/NA":*
# - 1. “VEHICLE_TYPE”: 1,225 missing data
# - 2. "VEHICLE_USE": 1,225 missing data
# - 3. "MANEUVER" : 1,225 missing data
#
# *Replace with Mean:*
# - 1. "AGE" : 16,073 missing data
#
# *Replace with mode/median:*
# - 1. "VEHICLE_YEAR" : 8,329 missing data
# - 2. "OCCUPANT_CNT" : 1,225 missing data
#
# *Drop the missing row:*
# - 1. "LOCATION" : 249 missing data
# - 2. "PERSON_TYPE" : 6.371 missing data
# - 3. "MOST_SEVERE_INJURY" : 115 missing data (target feature)
#
# *Drop the column:*
# - 1. "NUM_PASSENGERS" : 38,788 missing data
# - 2. "CELL_PHONE_USE" : 45,848 missing data
# - 3. "EXCEED_SPEED_LIMIT_I" : 45,757 missing data
# - 4. "PERSON_ID" : 6,371 missing data (not useful)

# %% [markdown]
# ### Adjust in dataset

# %% [markdown]
# #### Replace by 0

# %% [markdown]
# #### Replace with meaningful input

# %% [markdown]
# #### Replace with frequency (mode):
# “LANE_CNT”: 30,763 missing data. Replace them with mode “2”

# %%
train['LANE_CNT'].fillna("2",inplace=True)

# %%
print("Total NAs in LANE_CNT")
train['LANE_CNT'].isnull().sum()
# Out:
# Total NAs in LANE_CNT
# 0

# %% [markdown]
# #### Replace by "N" to keep it binary

# %% [markdown]
# #### Replace with "OTHER" or "UNKNOWN" or  "UNKNOWN/NA":

# %%
print("Total NAs in MANEUVER")
train['MANEUVER'].isnull().sum()
# Out:
# Total NAs in MANEUVER
# 0

# %% [markdown]
# #### Replace with median

# %%
train["AGE"] = pd.to_numeric(train["AGE"])
train['AGE'].fillna((train['AGE'].median()), inplace=True)
print("TOTAL NAs in AGE")
train['AGE'].isnull().sum()
# Out:
# TOTAL NAs in AGE
# 0

# %%
train.isnull().sum()
# Out:
# CRASH_DATE                     0
# POSTED_SPEED_LIMIT             0
# TRAFFIC_CONTROL_DEVICE         0
# DEVICE_CONDITION               0
# WEATHER_CONDITION              0
# LIGHTING_CONDITION             0
# FIRST_CRASH_TYPE               0
# TRAFFICWAY_TYPE                0
# LANE_CNT                       0
# ALIGNMENT                      0
# ROADWAY_SURFACE_COND           0
# ROAD_DEFECT                    0
# INTERSECTION_RELATED_I         0
# NOT_RIGHT_OF_WAY_I             0
# HIT_AND_RUN_I                  0
# PRIM_CONTRIBUTORY_CAUSE        0
# SEC_CONTRIBUTORY_CAUSE         0
# STREET_DIRECTION               0
# DOORING_I                      0
# WORK_ZONE_I                    0
# NUM_UNITS                      0
# MOST_SEVERE_INJURY           113
# INJURIES_TOTAL               112
# CRASH_HOUR                     0
# LATITUDE                     365
# LONGITUDE                    365
# NUM_PASSENGERS                 0
# LIC_PLATE_STATE                0
# VEHICLE_YEAR               10735
# VEHICLE_DEFECT                 0
# VEHICLE_TYPE                   0
# VEHICLE_USE                    0
# TRAVEL_DIRECTION               0
# MANEUVER                       0
# OCCUPANT_CNT                   0
# EXCEED_SPEED_LIMIT_I           0
# FIRST_CONTACT_POINT            0
# PERSON_TYPE                    0
# SEAT_NO                        0
# CITY                           0
# SEX                            0
# AGE                            0
# SAFETY_EQUIPMENT               0
# AIRBAG_DEPLOYED                0
# EJECTION                       0
# DRIVER_ACTION                  0
# DRIVER_VISION                  0
# PHYSICAL_CONDITION             0
# PEDPEDAL_ACTION                0
# PEDPEDAL_VISIBILITY            0
# BAC_RESULT VALUE               0
# CELL_PHONE_USE                 0
# dtype: int64

# %% [markdown]
# #### Replace with mode/median

# %%
train['VEHICLE_YEAR'].fillna(train['VEHICLE_YEAR'].mode()[0], inplace=True)

train["OCCUPANT_CNT"] = pd.to_numeric(train["OCCUPANT_CNT"])
train['OCCUPANT_CNT'].fillna((train['OCCUPANT_CNT'].median()), inplace=True)

print("TOTAL NAs in VEHICLE_YEAR")
train['VEHICLE_YEAR'].isnull().sum()
# Out:
# TOTAL NAs in VEHICLE_YEAR
# 0

# %% [markdown]
# #### Drop the missing row

# %%
drop_rows = ['INJURIES_TOTAL', 'LATITUDE','MOST_SEVERE_INJURY']
train.dropna(how='any', subset=drop_rows, inplace = True)
train.isnull().sum()
# Out:
# CRASH_DATE                 0
# POSTED_SPEED_LIMIT         0
# TRAFFIC_CONTROL_DEVICE     0
# DEVICE_CONDITION           0
# WEATHER_CONDITION          0
# LIGHTING_CONDITION         0
# FIRST_CRASH_TYPE           0
# TRAFFICWAY_TYPE            0
# LANE_CNT                   0
# ALIGNMENT                  0
# ROADWAY_SURFACE_COND       0
# ROAD_DEFECT                0
# INTERSECTION_RELATED_I     0
# NOT_RIGHT_OF_WAY_I         0
# HIT_AND_RUN_I              0
# PRIM_CONTRIBUTORY_CAUSE    0
# SEC_CONTRIBUTORY_CAUSE     0
# STREET_DIRECTION           0
# DOORING_I                  0
# WORK_ZONE_I                0
# NUM_UNITS                  0
# MOST_SEVERE_INJURY         0
# INJURIES_TOTAL             0
# CRASH_HOUR                 0
# LATITUDE                   0
# LONGITUDE                  0
# NUM_PASSENGERS             0
# LIC_PLATE_STATE            0
# VEHICLE_YEAR               0
# VEHICLE_DEFECT             0
# VEHICLE_TYPE               0
# VEHICLE_USE                0
# TRAVEL_DIRECTION           0
# MANEUVER                   0
# OCCUPANT_CNT               0
# EXCEED_SPEED_LIMIT_I       0
# FIRST_CONTACT_POINT        0
# PERSON_TYPE                0
# SEAT_NO                    0
# CITY                       0
# SEX                        0
# AGE                        0
# SAFETY_EQUIPMENT           0
# AIRBAG_DEPLOYED            0
# EJECTION                   0
# DRIVER_ACTION              0
# DRIVER_VISION              0
# PHYSICAL_CONDITION         0
# PEDPEDAL_ACTION            0
# PEDPEDAL_VISIBILITY        0
# BAC_RESULT VALUE           0
# CELL_PHONE_USE             0
# dtype: int64

# %%
train.shape
# Out:
# (66317, 52)

# %% [markdown]
# <a id='2.1.3.1'></a>
# #### Features that can be imputed/encoded

# %% [markdown]
# # Handling Outliers

# %% [markdown]
# ##  Categorical Features

# %% [markdown]
# Example 1: A, B, C, X.
#
# Example 2: Apple, Orange, Pear or Blueberry, Raspberry, Strawberry, Grape.
#
# "*The fact is **no outlier** exists in the examples above, for an outlier to exist there must be **a measure of distance**. This is intrinsic to numeric data types because there is a Euclidean distance between numbers.*"
#
# **Categorical Outliers don’t exist without a context.**
#
# > "*Techniques like **string indexing** or **one-hot encoding** on a categorical value to convert it from a string value to a numeric value and then use k-means clustering to find outliers.*"
#
# > "*the numeric vector assigned to the String value during the one hot encoding practice still lacks **the domain context**. It does satisfy the input constraint of the k-means model and the model will produce an output. However the output will not select the appropriate outlier, as the input **was not truly valid**.*"
#
# > "*There is an alternative. **K-modes** is designed to handle categorical values without the need for String Indexing or One Hot Encoding.*"

# %% [markdown]
# ##  Numerical Features

# %% [markdown]
# **`LANE_CNT`**
#
# **Outlier Identification**
#
# - 3 rows of 9
# - 13 rows of 10
# - 1 row of 11
# - 4 rows of 12
# - 2 rows of 99
#
# According to Chicago's roadway, 6 should be a maximum number for lanes
#
# **Decision** to replace outlier with 6 lanes

# %%
train['LANE_CNT']=pd.to_numeric(train['LANE_CNT'])
train['VEHICLE_YEAR']=pd.to_numeric(train['VEHICLE_YEAR'])

# %%
train['NUM_UNITS']=pd.to_numeric(train['NUM_UNITS'])

# %%
# Change all rows with value greater than 6 to 6
train.loc[(train['LANE_CNT'] > 6),'LANE_CNT'] = 6
train['LANE_CNT'].value_counts()
# Out:
# 2    54662
# 4     5563
# 1     3422
# 3      975
# 6      761
# 0      666
# 5      268
# Name: LANE_CNT, dtype: int64

# %% [markdown]
# **No Further Outliers according to the observation**
#
# - `NUM_UNITS`; varies from 1 to 12
# - `INJURIES_TOTAL`; varies from 0 to 8
# - `INJURIES_FATAL`; varies from 0 to 2
# - `INJURIES_INCAPACITATING`; varies from 0 to 5
# - `NUM_PASSENGERS`; varies from 1 to 38
# - `OCCUPANT_CNT`; varies from 0 to 39
# - `AGE`; varies from ... to 101

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ##  Target Feature Engineering

# %% [markdown]
# Pick **`INJURIES_TOTAL`** as a numerical target and/or encode **`INJURY`** as a categorical target.
#
# - `INJURY`: Total persons sustaining **fatal, incapacitating, non-incapacitating** as determined by the reporting officer.
#
# 13% Injuries, 87% Non-injuries

# %% [markdown]
# Removing NAs from INJURIES_TOTAL below

# %%
train.select_dtypes('object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66317 entries, 904 to 15795
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   POSTED_SPEED_LIMIT       66317 non-null  object
#  1   TRAFFIC_CONTROL_DEVICE   66317 non-null  object
#  2   DEVICE_CONDITION         66317 non-null  object
#  3   WEATHER_CONDITION        66317 non-null  object
#  4   LIGHTING_CONDITION       66317 non-null  object
#  5   FIRST_CRASH_TYPE         66317 non-null  object
#  6   TRAFFICWAY_TYPE          66317 non-null  object
#  7   ALIGNMENT                66317 non-null  object
#  8   ROADWAY_SURFACE_COND     66317 non-null  object
#  9   ROAD_DEFECT              66317 non-null  object
#  10  INTERSECTION_RELATED_I   66317 non-null  object
#  11  NOT_RIGHT_OF_WAY_I       66317 non-null  object
#  12  HIT_AND_RUN_I            66317 non-null  object
#  13  PRIM_CONTRIBUTORY_CAUSE  66317 non-null  object
#  14  SEC_CONTRIBUTORY_CAUSE   66317 non-null  object
#  15  STREET_DIRECTION         66317 non-null  object
#  16  DOORING_I                66317 non-null  object
#  17  WORK_ZONE_I              66317 non-null  object
#  18  MOST_SEVERE_INJURY       66317 non-null  object
#  19  INJURIES_TOTAL           66317 non-null  object
#  20  CRASH_HOUR               66317 non-null  object
#  21  LATITUDE                 66317 non-null  object
#  22  LONGITUDE                66317 non-null  object
#  23  NUM_PASSENGERS           66317 non-null  object
#  24  LIC_PLATE_STATE          66317 non-null  object
#  25  VEHICLE_DEFECT           66317 non-null  object
#  26  VEHICLE_TYPE             66317 non-null  object
#  27  VEHICLE_USE              66317 non-null  object
#  28  TRAVEL_DIRECTION         66317 non-null  object
#  29  MANEUVER                 66317 non-null  object
#  30  EXCEED_SPEED_LIMIT_I     66317 non-null  object
#  31  FIRST_CONTACT_POINT      66317 non-null  object
#  32  PERSON_TYPE              66317 non-null  object
#  33  SEAT_NO                  66317 non-null  object
#  34  CITY                     66317 non-null  object
#  35  SEX                      66317 non-null  object
#  36  SAFETY_EQUIPMENT         66317 non-null  object
#  37  AIRBAG_DEPLOYED          66317 non-null  object
#  38  EJECTION                 66317 non-null  object
#  39  DRIVER_ACTION            66317 non-null  object
#  40  DRIVER_VISION            66317 non-null  object
#  41  PHYSICAL_CONDITION       66317 non-null  object
#  42  PEDPEDAL_ACTION          66317 non-null  object
#  43  PEDPEDAL_VISIBILITY      66317 non-null  object
#  44  BAC_RESULT VALUE         66317 non-null  object
#  45  CELL_PHONE_USE           66317 non-null  object
# dtypes: object(46)
# memory usage: 23.8+ MB

# %%
# show all the levels of object columns in train dataframe
for col in train.select_dtypes('object'):
    print('\033[1m', col, '\033[0m')
    print(train[col].unique())
    print('')
    print('')
# Out:
#  POSTED_SPEED_LIMIT
# ['30' '35' '0' '25' '20' '10' '15' '40' '55' '5' '45' '60' '11' '50' '3'
#  '9' '65' '1' '2' '33' '4' '24' '32' '70' '39']
#
#
#  TRAFFIC_CONTROL_DEVICE
# ['TRAFFIC SIGNAL' 'NO CONTROLS' 'STOP SIGN/FLASHER' 'OTHER'
#  'LANE USE MARKING' 'RAILROAD CROSSING GATE' 'YIELD' 'OTHER REG. SIGN'
#  'SCHOOL ZONE' 'OTHER WARNING SIGN' 'PEDESTRIAN CROSSING SIGN'
#  'NO PASSING' 'FLASHING CONTROL SIGNAL' 'POLICE/FLAGMAN' 'DELINEATORS'
#  'OTHER RAILROAD CROSSING' 'BICYCLE CROSSING SIGN' 'RR CROSSING SIGN']
#
#
#  DEVICE_CONDITION
# ['FUNCTIONING PROPERLY' 'NO CONTROLS' 'OTHER' 'NOT FUNCTIONING'
#  'FUNCTIONING IMPROPERLY' 'MISSING' 'WORN REFLECTIVE MATERIAL']
#
#
#  WEATHER_CONDITION
# ['CLEAR' 'RAIN' 'SNOW' 'CLOUDY/OVERCAST' 'FOG/SMOKE/HAZE' 'SLEET/HAIL'
#  'OTHER' 'BLOWING SNOW' 'FREEZING RAIN/DRIZZLE' 'SEVERE CROSS WIND GATE'
#  'BLOWING SAND, SOIL, DIRT']
#
#
#  LIGHTING_CONDITION
# ['DAYLIGHT' 'DARKNESS' 'DARKNESS, LIGHTED ROAD' 'DAWN' 'DUSK']
#
#
#  FIRST_CRASH_TYPE
# ['HEAD ON' 'REAR END' 'PARKED MOTOR VEHICLE' 'TURNING'
#  'SIDESWIPE SAME DIRECTION' 'PEDESTRIAN' 'SIDESWIPE OPPOSITE DIRECTION'
#  'ANGLE' 'FIXED OBJECT' 'PEDALCYCLIST' 'REAR TO FRONT'
#  'OTHER NONCOLLISION' 'OTHER OBJECT' 'OVERTURNED' 'REAR TO SIDE'
#  'REAR TO REAR' 'ANIMAL' 'TRAIN']
#
#
#  TRAFFICWAY_TYPE
# ['DIVIDED - W/MEDIAN (NOT RAISED)' 'DIVIDED - W/MEDIAN BARRIER' 'ONE-WAY'
#  'NOT DIVIDED' 'FOUR WAY' 'CENTER TURN LANE' 'PARKING LOT' 'OTHER'
#  'T-INTERSECTION' 'DRIVEWAY' 'ALLEY' 'NOT REPORTED' 'RAMP'
#  'Y-INTERSECTION' 'TRAFFIC ROUTE' 'UNKNOWN INTERSECTION TYPE' 'ROUNDABOUT'
#  'FIVE POINT, OR MORE' 'L-INTERSECTION']
#
#
#  ALIGNMENT
# ['STRAIGHT AND LEVEL' 'STRAIGHT ON GRADE' 'STRAIGHT ON HILLCREST'
#  'CURVE, LEVEL' 'CURVE ON HILLCREST' 'CURVE ON GRADE']
#
#
#  ROADWAY_SURFACE_COND
# ['DRY' 'WET' 'SNOW OR SLUSH' 'NO DEFECTS' 'ICE' 'OTHER' 'SAND, MUD, DIRT']
#
#
#  ROAD_DEFECT
# ['NO DEFECTS' 'OTHER' 'CLEAR' 'RUT, HOLES' 'WORN SURFACE'
#  'DEBRIS ON ROADWAY' 'SHOULDER DEFECT']
#
#
#  INTERSECTION_RELATED_I
# ['N' 'Y']
#
#
#  NOT_RIGHT_OF_WAY_I
# ['N' 'Y']
#
#
#  HIT_AND_RUN_I
# ['N' 'Y']
#
#
#  PRIM_CONTRIBUTORY_CAUSE
# ['NOT APPLICABLE' 'UNABLE TO DETERMINE'
#  'FAILING TO REDUCE SPEED TO AVOID CRASH' 'IMPROPER OVERTAKING/PASSING'
#  'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER'
#  'IMPROPER LANE USAGE' 'FAILING TO YIELD RIGHT-OF-WAY'
#  'FOLLOWING TOO CLOSELY' 'DISREGARDING STOP SIGN'
#  'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE' 'WEATHER' 'IMPROPER BACKING'
#  'DISREGARDING ROAD MARKINGS' 'DRIVING ON WRONG SIDE/WRONG WAY'
#  'EQUIPMENT - VEHICLE CONDITION' 'EXCEEDING SAFE SPEED FOR CONDITIONS'
#  'ROAD CONSTRUCTION/MAINTENANCE' 'DISREGARDING TRAFFIC SIGNALS'
#  'IMPROPER TURNING/NO SIGNAL'
#  'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)'
#  'EXCEEDING AUTHORIZED SPEED LIMIT'
#  'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST'
#  'PHYSICAL CONDITION OF DRIVER' 'DISTRACTION - FROM OUTSIDE VEHICLE'
#  'DISTRACTION - FROM INSIDE VEHICLE'
#  'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)'
#  'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)'
#  'ANIMAL' 'TURNING RIGHT ON RED'
#  'ROAD ENGINEERING/SURFACE/MARKING DEFECTS' 'DISREGARDING YIELD SIGN'
#  'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
#  'TEXTING' 'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT'
#  'CELL PHONE USE OTHER THAN TEXTING' 'DISREGARDING OTHER TRAFFIC SIGNS'
#  'RELATED TO BUS STOP' 'PASSING STOPPED SCHOOL BUS'
#  'BICYCLE ADVANCING LEGALLY ON RED LIGHT']
#
#
#  SEC_CONTRIBUTORY_CAUSE
# ['NOT APPLICABLE' 'FAILING TO REDUCE SPEED TO AVOID CRASH'
#  'IMPROPER OVERTAKING/PASSING' 'EQUIPMENT - VEHICLE CONDITION'
#  'UNABLE TO DETERMINE' 'FAILING TO YIELD RIGHT-OF-WAY'
#  'ROAD CONSTRUCTION/MAINTENANCE' 'DRIVING ON WRONG SIDE/WRONG WAY'
#  'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE' 'FOLLOWING TOO CLOSELY'
#  'IMPROPER LANE USAGE' 'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST'
#  'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)'
#  'IMPROPER TURNING/NO SIGNAL'
#  'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER'
#  'BICYCLE ADVANCING LEGALLY ON RED LIGHT'
#  'EXCEEDING AUTHORIZED SPEED LIMIT' 'TEXTING' 'WEATHER'
#  'TURNING RIGHT ON RED' 'IMPROPER BACKING' 'PHYSICAL CONDITION OF DRIVER'
#  'DISTRACTION - FROM INSIDE VEHICLE' 'DISREGARDING ROAD MARKINGS'
#  'DISREGARDING TRAFFIC SIGNALS' 'ROAD ENGINEERING/SURFACE/MARKING DEFECTS'
#  'DISREGARDING STOP SIGN'
#  'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)'
#  'EXCEEDING SAFE SPEED FOR CONDITIONS'
#  'DISTRACTION - FROM OUTSIDE VEHICLE' 'CELL PHONE USE OTHER THAN TEXTING'
#  'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)'
#  'DISREGARDING OTHER TRAFFIC SIGNS'
#  'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)'
#  'ANIMAL' 'DISREGARDING YIELD SIGN' 'RELATED TO BUS STOP'
#  'PASSING STOPPED SCHOOL BUS' 'OBSTRUCTED CROSSWALKS'
#  'MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT']
#
#
#  STREET_DIRECTION
# ['W' 'N' 'S' 'E']
#
#
#  DOORING_I
# ['N' 'Y']
#
#
#  WORK_ZONE_I
# ['N' 'Y']
#
#
#  MOST_SEVERE_INJURY
# ['NO INDICATION OF INJURY' 'REPORTED, NOT EVIDENT' 'INCAPACITATING INJURY'
#  'NONINCAPACITATING INJURY' 'FATAL']
#
#
#  INJURIES_TOTAL
# ['0' '2' '1' '4' '3' '7' '8' '6' '5']
#
#
#  CRASH_HOUR
# ['17' '13' '3' '7' '10' '21' '16' '6' '12' '14' '11' '18' '15' '20' '9'
#  '5' '19' '0' '23' '8' '1' '22' '2' '4']
#
#
#  LATITUDE
# ['41.929775123' '41.900448122' '41.726898208' ... '41.890076919'
#  '41.759377346' '41.852495903']
#
#
#  LONGITUDE
# ['-87.732945186' '-87.66726606' '-87.623727063' ... '-87.635207836'
#  '-87.6611154' '-87.663190416']
#
#
#  NUM_PASSENGERS
# [0 '1' '6' '8' '3' '2' '5' '38' '4' '7' '10' '12' '9' '16' '43' '29' '19'
#  '32' '13' '11']
#
#
#  LIC_PLATE_STATE
# ['IL' 'IN' 'KS' 'PA' 'WI' 'WV' 'XX' 'TX' 'LA' 'MN' 'NY' 'MI' 'AZ' 'FL'
#  'OH' 'OK' 'GA' 'TN' 'NB' 'KY' 'MO' 'CA' 'WA' 'OR' 'AL' 'IA' 'CT' 'CO'
#  'NV' 'AR' 'ME' 'MS' 'SC' 'MA' 'ND' 'NC' 'MD' 'NJ' 'VA' 'WY' 'SD' 'VT'
#  'NH' 'NM' 'HI' 'UT' 'ID' 'MT' 'RI' 'AK']
#
#
#  VEHICLE_DEFECT
# ['NONE' 'BRAKES' 'UNABLE TO DETERMINE' 'STEERING' 'OTHER' 'TIRES'
#  'SUSPENSION' 'WHEELS' 'FUEL SYSTEM' 'WINDOWS' 'ENGINE/MOTOR' 'SIGNALS'
#  'LIGHTS' 'RESTRAINT SYSTEM' 'CARGO']
#
#
#  VEHICLE_TYPE
# ['PASSENGER' 'SPORT UTILITY VEHICLE (SUV)' 'VAN/MINI-VAN' 'OTHER'
#  'BUS UP TO 15 PASS.' 'TRACTOR W/ SEMI-TRAILER' 'MOTORCYCLE (OVER 150CC)'
#  'BUS OVER 15 PASS.' 'PICKUP' 'TRUCK - SINGLE UNIT'
#  'TRACTOR W/O SEMI-TRAILER' 'ALL-TERRAIN VEHICLE (ATV)'
#  'OTHER VEHICLE WITH TRAILER' 'MOTOR DRIVEN CYCLE' 'FARM EQUIPMENT'
#  'AUTOCYCLE' 'SINGLE UNIT TRUCK WITH TRAILER' 'MOPED OR MOTORIZED BICYCLE'
#  '3-WHEELED MOTORCYCLE (2 REAR WHEELS)' 'SNOWMOBILE']
#
#
#  VEHICLE_USE
# ['PERSONAL' 'NOT IN USE' 'UNKNOWN/NA' 'COMMERCIAL - SINGLE UNIT'
#  'TAXI/FOR HIRE' 'SCHOOL BUS' 'OTHER' 'RIDESHARE SERVICE'
#  'COMMERCIAL - MULTI-UNIT' 'CONSTRUCTION/MAINTENANCE' 'STATE OWNED'
#  'POLICE' 'CTA' 'TOW TRUCK' 'AMBULANCE' 'DRIVER EDUCATION' 'OTHER TRANSIT'
#  'MASS TRANSIT' 'FIRE' 'LAWN CARE/LANDSCAPING' 'AGRICULTURE' 'MILITARY'
#  'CAMPER/RV - TOWED/MULTI-UNIT' 'CAMPER/RV - SINGLE UNIT']
#
#
#  TRAVEL_DIRECTION
# ['S' 'N' 'W' 'SW' 'E' 'SE' 'NE' 'NW']
#
#
#  MANEUVER
# ['BACKING' 'STRAIGHT AHEAD' 'PARKED' 'PASSING/OVERTAKING' 'TURNING RIGHT'
#  'TURNING LEFT' 'SLOW/STOP IN TRAFFIC' 'OTHER' 'ENTER FROM DRIVE/ALLEY'
#  'SLOW/STOP - LOAD/UNLOAD' 'ENTERING TRAFFIC LANE FROM PARKING'
#  'SLOW/STOP - RIGHT TURN' 'LEAVING TRAFFIC LANE TO PARK' 'MERGING'
#  'CHANGING LANES' 'AVOIDING VEHICLES/OBJECTS' 'SLOW/STOP - LEFT TURN'
#  'DRIVERLESS' 'STARTING IN TRAFFIC' 'NEGOTIATING A CURVE'
#  'SKIDDING/CONTROL LOSS' 'DRIVING WRONG WAY' 'U-TURN'
#  'PARKED IN TRAFFIC LANE' 'DIVERGING' 'TURNING ON RED' 'DISABLED']
#
#
#  EXCEED_SPEED_LIMIT_I
# ['N' 'Y']
#
#
#  FIRST_CONTACT_POINT
# ['REAR' 'OTHER' 'FRONT-LEFT' 'SIDE-RIGHT' 'UNKNOWN' 'REAR-LEFT'
#  'REAR-RIGHT' 'SIDE-LEFT' 'FRONT-RIGHT' 'FRONT' 'ROOF' 'TOTAL (ALL AREAS)'
#  'NONE' 'UNDER CARRIAGE']
#
#
#  PERSON_TYPE
# ['DRIVER' 'UNABLE TO DETERMINE' 'PASSENGER' 'PEDESTRIAN' 'BICYCLE'
#  'NON-MOTOR VEHICLE' 'NON-CONTACT VEHICLE']
#
#
#  SEAT_NO
# [0 '4' '6' '5' '7' '1' '3' '11' '12' '2' '10' '8']
#
#
#  CITY
# ['NAPA' 'CHICAGO' 'OTHER' ... 'JERICHO' 'ANAHEIM' 'ALTADENA']
#
#
#  SEX
# ['M' 'F' 'UNABLE TO DETERMINE' 'X']
#
#
#  SAFETY_EQUIPMENT
# ['UNABLE TO DETERMINE' 'SAFETY BELT USED'
#  'CHILD RESTRAINT USED IMPROPERLY' 'HELMET NOT USED'
#  'CHILD RESTRAINT - TYPE UNKNOWN' 'NONE PRESENT' 'WHEELCHAIR'
#  'CHILD RESTRAINT - FORWARD FACING' 'SAFETY BELT NOT USED'
#  'DOT COMPLIANT MOTORCYCLE HELMET' 'CHILD RESTRAINT USED' 'HELMET USED'
#  'BICYCLE HELMET (PEDACYCLIST INVOLVED ONLY)' 'BOOSTER SEAT'
#  'CHILD RESTRAINT - REAR FACING' 'CHILD RESTRAINT NOT USED'
#  'SHOULD/LAP BELT USED IMPROPERLY' 'STRETCHER'
#  'NOT DOT COMPLIANT MOTORCYCLE HELMET']
#
#
#  AIRBAG_DEPLOYED
# ['DID NOT DEPLOY' 'DEPLOYED, FRONT' 'UNABLE TO DETERMINE' 'NOT APPLICABLE'
#  'DEPLOYED, COMBINATION' 'DEPLOYED, SIDE'
#  'DEPLOYED OTHER (KNEE, AIR, BELT, ETC.)']
#
#
#  EJECTION
# ['NONE' 'UNABLE TO DETERMINE' 'PARTIALLY EJECTED' 'TOTALLY EJECTED'
#  'TRAPPED/EXTRICATED']
#
#
#  DRIVER_ACTION
# ['IMPROPER BACKING' 'OTHER' 'IMPROPER PASSING' 'FAILED TO YIELD' 'NONE'
#  'FOLLOWED TOO CLOSELY' 'IMPROPER PARKING' 'IMPROPER LANE CHANGE'
#  'TOO FAST FOR CONDITIONS' 'WRONG WAY/SIDE'
#  'CELL PHONE USE OTHER THAN TEXTING' 'DISREGARDED CONTROL DEVICES'
#  'IMPROPER TURN' 'EMERGENCY VEHICLE ON CALL' 'EVADING POLICE VEHICLE'
#  'OVERCORRECTED' 'TEXTING' 'LICENSE RESTRICTIONS' 'STOPPED SCHOOL BUS']
#
#
#  DRIVER_VISION
# ['NOT OBSCURED' 'OTHER' 'WINDSHIELD (WATER/ICE)' 'MOVING VEHICLES'
#  'PARKED VEHICLES' 'BLINDED - SUNLIGHT' 'TREES, PLANTS'
#  'BLOWING MATERIALS' 'BUILDINGS' 'SIGNBOARD' 'HILLCREST'
#  'BLINDED - HEADLIGHTS' 'EMBANKMENT']
#
#
#  PHYSICAL_CONDITION
# ['NORMAL' 'UNABLE TO DETERMINE' 'REMOVED BY EMS' 'EMOTIONAL'
#  'IMPAIRED - DRUGS' 'FATIGUED/ASLEEP' 'OTHER' 'IMPAIRED - ALCOHOL'
#  'HAD BEEN DRINKING' 'ILLNESS/FAINTED' 'IMPAIRED - ALCOHOL AND DRUGS'
#  'MEDICATED']
#
#
#  PEDPEDAL_ACTION
# ['UNABLE TO DETERMINE' 'CROSSING - WITH SIGNAL' 'WITH TRAFFIC'
#  'AGAINST TRAFFIC' 'NO ACTION' 'CROSSING - AGAINST SIGNAL' 'OTHER ACTION'
#  'INTOXICATED PED/PEDAL'
#  'CROSSING - CONTROLS PRESENT (NOT AT INTERSECTION)' 'TURNING LEFT'
#  'PARKED VEHICLE' 'STANDING IN ROADWAY' 'NOT AT INTERSECTION'
#  'WORKING IN ROADWAY' 'ENTER FROM DRIVE/ALLEY' 'PLAYING IN ROADWAY'
#  'CROSSING - NO CONTROLS (AT INTERSECTION)'
#  'CROSSING - NO CONTROLS (NOT AT INTERSECTION)'
#  'PLAYING/WORKING ON VEHICLE' 'TURNING RIGHT' 'WAITING FOR SCHOOL BUS']
#
#
#  PEDPEDAL_VISIBILITY
# ['UNABLE TO DETERMINE' 'NO CONTRASTING CLOTHING' 'CONTRASTING CLOTHING'
#  'REFLECTIVE MATERIAL' 'OTHER LIGHT SOURCE USED']
#
#
#  BAC_RESULT VALUE
# [0 '0.1500' '0.2300' '0.2000' '0.1000' '0.1800' '0.2100' '0.0000' '0.2700'
#  '0.1300' '0.1900' '0.1400' '0.2200' '0.1700' '0.1200' '0.1100' '0.0300'
#  '0.0100' '0.3100' '0.2500' '0.2400' '0.3200' '0.3500' '0.1600' '0.0200'
#  '0.2800' '0.0700']
#
#
#  CELL_PHONE_USE
# ['UNABLE TO DETERMINE' 'Y' 'N']

# %%
train["MOST_SEVERE_INJURY"].unique()
# Out:
# array(['NO INDICATION OF INJURY', 'REPORTED, NOT EVIDENT',
#        'INCAPACITATING INJURY', 'NONINCAPACITATING INJURY', 'FATAL'],
#       dtype=object)

# %%
def injury(x): 
    if any(s in x for s in ["FATAL","NONINCAPACITATING INJURY","INCAPACITATING INJURY"]):
        return "INJURED"
    else:
        return "NOT INJURED"
    
# replacing NA values with OTHER
train["INJURY"] = train["MOST_SEVERE_INJURY"].apply(lambda x: injury(x))
train.drop("MOST_SEVERE_INJURY", axis=1, inplace=True)

# %%
train["INJURY"].value_counts()
# Out:
# NOT INJURED    58564
# INJURED         7753
# Name: INJURY, dtype: int64

# %% [markdown]
# ##  Other Feature Engineering / Adaptation

# %% [markdown]
# ### CONTACT_POINT

# %% [markdown]
# Reduced # of layers in `FIRST_CONTACT_POINT` to:
# - FRONT
# - SIDE
# - READ
# - OTHER

# %%
def contact_point(x):
    if "FRONT" in x:
        return "FRONT"
    elif "SIDE" in x:
        return "SIDE"
    elif "REAR" in x:
        return "REAR"
    else:
        return "OTHER"
    
# replacing NA values with OTHER
train["FIRST_CONTACT_POINT"] = train["FIRST_CONTACT_POINT"].apply(lambda x: contact_point(x))

# %%
train["MANEUVER"].unique()
# Out:
# array(['BACKING', 'STRAIGHT AHEAD', 'PARKED', 'PASSING/OVERTAKING',
#        'TURNING RIGHT', 'TURNING LEFT', 'SLOW/STOP IN TRAFFIC', 'OTHER',
#        'ENTER FROM DRIVE/ALLEY', 'SLOW/STOP - LOAD/UNLOAD',
#        'ENTERING TRAFFIC LANE FROM PARKING', 'SLOW/STOP - RIGHT TURN',
#        'LEAVING TRAFFIC LANE TO PARK', 'MERGING', 'CHANGING LANES',
#        'AVOIDING VEHICLES/OBJECTS', 'SLOW/STOP - LEFT TURN', 'DRIVERLESS',
#        'STARTING IN TRAFFIC', 'NEGOTIATING A CURVE',
#        'SKIDDING/CONTROL LOSS', 'DRIVING WRONG WAY', 'U-TURN',
#        'PARKED IN TRAFFIC LANE', 'DIVERGING', 'TURNING ON RED',
#        'DISABLED'], dtype=object)

# %% [markdown]
# ### MANEUVER, VEHICLE_YEAR, POSTED_SPEED_LIMIT

# %% [markdown]
# Reduced # of layers in `MANEUVER` to:
# - UNKNOWN/NA
# - TURN
# - LANE
# - OTHER

# %%
# merging same type of Maneuver in one
train["MANEUVER"] = train["MANEUVER"].apply(lambda x: "TURN" if "TURN" in x else("LANE" if any(s in x for s in ["LANE","OVER","ENTER"]) else x))
train["MANEUVER"] = train["MANEUVER"].apply(lambda x: "OTHER" if all(s not in x for s in ["AHEAD","TURN","UNKNOWN","LANE","BACKING"]) else x)

# converting VEHICLE_YEAR into new category of OLD or NEW
#train["VEHICLE_YEAR"]= train["VEHICLE_YEAR"].apply(lambda x: "UNKNOWN" if pd.isnull(x) else ("OLD (<2010)" if int(x)<2010 else "NEW"))

# converting POSTED_SPEED_LIMIT into new category of LOW SPEED or HIGH SPEED
#train["POSTED_SPEED_LIMIT"]=train["POSTED_SPEED_LIMIT"].apply(lambda x: "LOW_SPEED" if int(x)<=30 else "HIGH_SPEED")

# %% [markdown]
# ### SAFETY_EQUIPMENT, AIRBAG_DEPLOYED

# %% [markdown]
# Reduced # of layers in `SAFETY_EQUIPMENT` to:
# - USED SAFETY EQUIPMENT
# - DID NOT USE SAFETY EQUIPMENT
#
# Reduced # of layers in `AIRBAG_DEPLOYED` to:
# - DEPLOYED
# - NOT DEPLOYED

# %%
# grouping the SAFETY_EQUIPMENT used as SAFE and UNSAFE
def equip_used(x):
    if ("USED" in x) or ("HELMET" in x) or ("NONE PRESENT" in x):
        if any(s in x for s in ["NOT","IMPROPER","NONE PRESENT"]):
            return "DID NOT USE SAFETY EQUIP"
        else:
            return "USED SAFETY EQUIP"
    else:
        return x

train["SAFETY_EQUIPMENT"]= train["SAFETY_EQUIPMENT"].apply(lambda x: equip_used(x))


# grouping the AIRBAG_DEPLOYED used as DEPLOYED and NOT DEPLOYED
def airbag(x):
    if ("DEPLOY" in x) and ("UNKNOWN" not in x):
        if "NOT" in x:
            return "NOT DEPLOYED"
        else:
            return "DEPLOYED"
    else:
        return x
 
train["AIRBAG_DEPLOYED"]= train["AIRBAG_DEPLOYED"].apply(lambda x: airbag(x))

# %% [markdown]
# ### CRASH_HOUR

# %% [markdown]
# Transform the crash hour to 4 categories:
# - Early morning
# - Morning
# - Afternoon
# - Night

# %%
def crash_hour(x):
    if  2 <= x < 8:
        return "Early_morning"
    elif 8 <= x < 12:
        return "Morning"
    elif 12 <= x < 18:
        return "Afternoon"
    else:
        return "Night"
    
# replacing NA values with OTHER
train["CRASH_HOUR"] = train["CRASH_HOUR"].apply(lambda x: crash_hour(int(x)))

# %% [markdown]
# ### TRAFFIC_CONTROL_DEVICE

# %% [markdown]
# Transform the signs
# - 'TRAFFIC SIGNAL', 'STOP SIGN/FLASHER', 'LANE USE MARKING', 'YIELD', 'DELINEATORS',
# 'OTHER REG. SIGN', 'OTHER WARNING SIGN', 'POLICE/FLAGMAN', 'RAILROAD CROSSING GATE',
# 'OTHER RAILROAD CROSSING', 'FLASHING CONTROL SIGNAL', 'PEDESTRIAN CROSSING SIGN',
# 'NO PASSING', 'SCHOOL ZONE', 'BICYCLE CROSSING SIGN' as `SIGN`
#
# - 'NO CONTROLS','UNKNOWN', 'OTHER' as `NO_SIGN`

# %%
def traffic_control(x):
    if ("NO CONTROLS" in x) or ("UNKNOWN" in x) or ("OTHER" in x):
        return "NO_SIGN"
    else:
        return "SIGN"

train["TRAFFIC_CONTROL_DEVICE"]= train["TRAFFIC_CONTROL_DEVICE"].apply(lambda x: traffic_control(x))

# %% [markdown]
# ### LOCATION

# %%
def location(x1,x2):
    if (41.875297 <= float(x1) <= 41.9000064) and (-87.6321459 <= float(x2) <= -87.6096752):
        return "Downtown"
    else:
        return "Not Downtown"

#df['col_3'] = df.apply(lambda x: f(x.col_1, x.col_2), axis=1)
train["Location"] = train.apply(lambda x: location(x["LATITUDE"],x["LONGITUDE"]), axis=1)

# %%
display(train["Location"].unique())
train.groupby(['Location']).size()
# Out:
# array(['Not Downtown', 'Downtown'], dtype=object)
# Location
# Downtown         2987
# Not Downtown    63330
# dtype: int64

# %% [markdown]
# ### CAR AGE

# %%
train["VEHICLE_AGE"]=train["CRASH_DATE"].dt.year-train["VEHICLE_YEAR"]

# %%
train.loc[train["VEHICLE_AGE"]<0,"VEHICLE_AGE"]=0

# %%
train.drop("VEHICLE_YEAR",axis=1,inplace=True)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66317 entries, 904 to 15795
# Data columns (total 53 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CRASH_DATE               66317 non-null  datetime64[ns]
#  1   POSTED_SPEED_LIMIT       66317 non-null  object
#  2   TRAFFIC_CONTROL_DEVICE   66317 non-null  object
#  3   DEVICE_CONDITION         66317 non-null  object
#  4   WEATHER_CONDITION        66317 non-null  object
#  5   LIGHTING_CONDITION       66317 non-null  object
#  6   FIRST_CRASH_TYPE         66317 non-null  object
#  7   TRAFFICWAY_TYPE          66317 non-null  object
#  8   LANE_CNT                 66317 non-null  int64
#  9   ALIGNMENT                66317 non-null  object
#  10  ROADWAY_SURFACE_COND     66317 non-null  object
#  11  ROAD_DEFECT              66317 non-null  object
#  12  INTERSECTION_RELATED_I   66317 non-null  object
#  13  NOT_RIGHT_OF_WAY_I       66317 non-null  object
#  14  HIT_AND_RUN_I            66317 non-null  object
#  15  PRIM_CONTRIBUTORY_CAUSE  66317 non-null  object
#  16  SEC_CONTRIBUTORY_CAUSE   66317 non-null  object
#  17  STREET_DIRECTION         66317 non-null  object
#  18  DOORING_I                66317 non-null  object
#  19  WORK_ZONE_I              66317 non-null  object
#  20  NUM_UNITS                66317 non-null  int64
#  21  INJURIES_TOTAL           66317 non-null  object
#  22  CRASH_HOUR               66317 non-null  object
#  23  LATITUDE                 66317 non-null  object
#  24  LONGITUDE                66317 non-null  object
#  25  NUM_PASSENGERS           66317 non-null  object
#  26  LIC_PLATE_STATE          66317 non-null  object
#  27  VEHICLE_DEFECT           66317 non-null  object
#  28  VEHICLE_TYPE             66317 non-null  object
#  29  VEHICLE_USE              66317 non-null  object
#  30  TRAVEL_DIRECTION         66317 non-null  object
#  31  MANEUVER                 66317 non-null  object
#  32  OCCUPANT_CNT             66317 non-null  int64
#  33  EXCEED_SPEED_LIMIT_I     66317 non-null  object
#  34  FIRST_CONTACT_POINT      66317 non-null  object
#  35  PERSON_TYPE              66317 non-null  object
#  36  SEAT_NO                  66317 non-null  object
#  37  CITY                     66317 non-null  object
#  38  SEX                      66317 non-null  object
#  39  AGE                      66317 non-null  float64
#  40  SAFETY_EQUIPMENT         66317 non-null  object
#  41  AIRBAG_DEPLOYED          66317 non-null  object
#  42  EJECTION                 66317 non-null  object
#  43  DRIVER_ACTION            66317 non-null  object
#  44  DRIVER_VISION            66317 non-null  object
#  45  PHYSICAL_CONDITION       66317 non-null  object
#  46  PEDPEDAL_ACTION          66317 non-null  object
#  47  PEDPEDAL_VISIBILITY      66317 non-null  object
#  48  BAC_RESULT VALUE         66317 non-null  object
#  49  CELL_PHONE_USE           66317 non-null  object
#  50  INJURY                   66317 non-null  object
#  51  Location                 66317 non-null  object
#  52  VEHICLE_AGE              66317 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(47)
# memory usage: 27.3+ MB

# %%
train["INJURIES_TOTAL"]
# Out:
# 904      0
# 18433    2
# 71357    0
# 24768    0
# 34668    0
#         ..
# 82386    2
# 6265     0
# 54886    0
# 76820    0
# 15795    0
# Name: INJURIES_TOTAL, Length: 66317, dtype: object

# %%
train["POSTED_SPEED_LIMIT"]=pd.to_numeric(train["POSTED_SPEED_LIMIT"])

# %%
# removing below columns
drop_list=["LATITUDE","LONGITUDE","INJURIES_TOTAL","CRASH_DATE", "LIC_PLATE_STATE", "CITY"]
# drop LIC_PLATE_STATE  
# drop city
train_new_class = train.drop(drop_list, axis=1)

# %%
train_new_class[train_new_class["VEHICLE_AGE"] > 59]
# Out:
#        POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE DEVICE_CONDITION  \
# 29563                  35                NO_SIGN      NO CONTROLS
# 3100                   30                NO_SIGN      NO CONTROLS
# 29562                  35                NO_SIGN      NO CONTROLS
# 42692                  30                NO_SIGN      NO CONTROLS
# 11969                  25                NO_SIGN      NO CONTROLS
# 77303                   0                NO_SIGN      NO CONTROLS
# 77302                   0                NO_SIGN      NO CONTROLS
# 58576                  30                NO_SIGN      NO CONTROLS
#
#       WEATHER_CONDITION      LIGHTING_CONDITION      FIRST_CRASH_TYPE  \
# 29563             CLEAR  DARKNESS, LIGHTED ROAD              REAR END
# 3100              CLEAR                DAYLIGHT               HEAD ON
# 29562             CLEAR  DARKNESS, LIGHTED ROAD              REAR END
# 42692             CLEAR                DAYLIGHT  PARKED MOTOR VEHICLE
# 11969             CLEAR                DAYLIGHT  PARKED MOTOR VEHICLE
# 77303             CLEAR                DAYLIGHT              REAR END
# 77302             CLEAR                DAYLIGHT              REAR END
# 58576             CLEAR  DARKNESS, LIGHTED ROAD  PARKED MOTOR VEHICLE
#
#                        TRAFFICWAY_TYPE  LANE_CNT           ALIGNMENT  \
# 29563                      NOT DIVIDED         2  STRAIGHT AND LEVEL
# 3100                             ALLEY         2  STRAIGHT AND LEVEL
# 29562                      NOT DIVIDED         2  STRAIGHT AND LEVEL
# 42692                      NOT DIVIDED         2  STRAIGHT AND LEVEL
# 11969                      NOT DIVIDED         2  STRAIGHT AND LEVEL
# 77303                          ONE-WAY         2  STRAIGHT AND LEVEL
# 77302                          ONE-WAY         2  STRAIGHT AND LEVEL
# 58576  DIVIDED - W/MEDIAN (NOT RAISED)         2  STRAIGHT AND LEVEL
#
#       ROADWAY_SURFACE_COND ROAD_DEFECT INTERSECTION_RELATED_I  \
# 29563                  DRY       CLEAR                      N
# 3100                   DRY  NO DEFECTS                      N
# 29562                  DRY       CLEAR                      N
# 42692                  DRY  NO DEFECTS                      N
# 11969           NO DEFECTS       CLEAR                      N
# 77303                  DRY  NO DEFECTS                      N
# 77302                  DRY  NO DEFECTS                      N
# 58576                  DRY  NO DEFECTS                      N
#
#       NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I PRIM_CONTRIBUTORY_CAUSE  \
# 29563                  N             Y   FOLLOWING TOO CLOSELY
# 3100                   N             N     UNABLE TO DETERMINE
# 29562                  N             Y   FOLLOWING TOO CLOSELY
# 42692                  N             Y     UNABLE TO DETERMINE
# 11969                  N             N     UNABLE TO DETERMINE
# 77303                  N             Y          NOT APPLICABLE
# 77302                  N             Y          NOT APPLICABLE
# 58576                  N             Y        IMPROPER BACKING
#
#       SEC_CONTRIBUTORY_CAUSE STREET_DIRECTION DOORING_I WORK_ZONE_I  \
# 29563  FOLLOWING TOO CLOSELY                W         N           N
# 3100     UNABLE TO DETERMINE                W         N           N
# 29562  FOLLOWING TOO CLOSELY                W         N           N
# 42692    UNABLE TO DETERMINE                W         N           N
# 11969    UNABLE TO DETERMINE                S         N           N
# 77303         NOT APPLICABLE                S         N           N
# 77302         NOT APPLICABLE                S         N           N
# 58576    UNABLE TO DETERMINE                W         N           N
#
#        NUM_UNITS     CRASH_HOUR NUM_PASSENGERS       VEHICLE_DEFECT  \
# 29563          2          Night              1  UNABLE TO DETERMINE
# 3100           2        Morning              0                 NONE
# 29562          2          Night              1  UNABLE TO DETERMINE
# 42692          4  Early_morning              0                 NONE
# 11969          2          Night              0  UNABLE TO DETERMINE
# 77303          2        Morning              1  UNABLE TO DETERMINE
# 77302          2        Morning              1  UNABLE TO DETERMINE
# 58576          2          Night              0  UNABLE TO DETERMINE
#
#                   VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION        MANEUVER  \
# 29563                    OTHER  UNKNOWN/NA                E  STRAIGHT AHEAD
# 3100                 PASSENGER    PERSONAL                N  STRAIGHT AHEAD
# 29562                    OTHER  UNKNOWN/NA                E  STRAIGHT AHEAD
# 42692  MOTORCYCLE (OVER 150CC)  NOT IN USE                W           OTHER
# 11969                    OTHER  UNKNOWN/NA                N           OTHER
# 77303             VAN/MINI-VAN    PERSONAL                N  STRAIGHT AHEAD
# 77302             VAN/MINI-VAN    PERSONAL                N  STRAIGHT AHEAD
# 58576                    OTHER  UNKNOWN/NA                N           OTHER
#
#        OCCUPANT_CNT EXCEED_SPEED_LIMIT_I FIRST_CONTACT_POINT  \
# 29563             2                    N               OTHER
# 3100              1                    N               OTHER
# 29562             2                    N               OTHER
# 42692             0                    N               OTHER
# 11969             1                    N               OTHER
# 77303             2                    N               FRONT
# 77302             2                    N               FRONT
# 58576             1                    N               OTHER
#
#                PERSON_TYPE SEAT_NO                  SEX   AGE  \
# 29563            PASSENGER       4                    M  39.0
# 3100                DRIVER       0                    F  35.0
# 29562               DRIVER       0                    X  35.0
# 42692  UNABLE TO DETERMINE       0  UNABLE TO DETERMINE  35.0
# 11969               DRIVER       0                    X  35.0
# 77303            PASSENGER       3                    F  35.0
# 77302               DRIVER       0                    M  35.0
# 58576               DRIVER       0                    X  35.0
#
#           SAFETY_EQUIPMENT      AIRBAG_DEPLOYED             EJECTION  \
# 29563    USED SAFETY EQUIP         NOT DEPLOYED                 NONE
# 3100     USED SAFETY EQUIP         NOT DEPLOYED                 NONE
# 29562  UNABLE TO DETERMINE  UNABLE TO DETERMINE                 NONE
# 42692  UNABLE TO DETERMINE  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 11969  UNABLE TO DETERMINE  UNABLE TO DETERMINE                 NONE
# 77303  UNABLE TO DETERMINE         NOT DEPLOYED                 NONE
# 77302  UNABLE TO DETERMINE  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 58576  UNABLE TO DETERMINE  UNABLE TO DETERMINE  UNABLE TO DETERMINE
#
#       DRIVER_ACTION DRIVER_VISION   PHYSICAL_CONDITION      PEDPEDAL_ACTION  \
# 29563         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 3100          OTHER  NOT OBSCURED               NORMAL  UNABLE TO DETERMINE
# 29562          NONE         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 42692         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 11969         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 77303         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 77302         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
# 58576         OTHER         OTHER  UNABLE TO DETERMINE  UNABLE TO DETERMINE
#
#        PEDPEDAL_VISIBILITY BAC_RESULT VALUE       CELL_PHONE_USE       INJURY  \
# 29563  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE      INJURED
# 3100   UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
# 29562  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE      INJURED
# 42692  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
# 11969  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
# 77303  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
# 77302  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
# 58576  UNABLE TO DETERMINE                0  UNABLE TO DETERMINE  NOT INJURED
#
#            Location  VEHICLE_AGE
# 29563  Not Downtown          117
# 3100   Not Downtown          111
# 29562  Not Downtown          117
# 42692  Not Downtown          118
# 11969  Not Downtown          118
# 77303  Not Downtown          116
# 77302  Not Downtown          116
# 58576  Not Downtown          118

# %%
train_new_class.groupby(['PERSON_TYPE']).size()
# Out:
# PERSON_TYPE
# BICYCLE                  416
# DRIVER                 45526
# NON-CONTACT VEHICLE       12
# NON-MOTOR VEHICLE         56
# PASSENGER              12548
# PEDESTRIAN               853
# UNABLE TO DETERMINE     6906
# dtype: int64

# %%
# 853 PEDESTRIAN => 646 (75.7%) are INJURED ; 207 (24.26%) NOT INJURED
train_new_class[train_new_class["PERSON_TYPE"] == "PEDESTRIAN"].groupby(["INJURY"]).size()
# Out:
# INJURY
# INJURED        646
# NOT INJURED    207
# dtype: int64

# %% [markdown]
# # Insight

# %% [markdown]
# ### Insight 1 : Crashes involve BICYCLE or PEDESTRIAN No. INJURED > NOT INJURED
# - Both PERSON_TYPE and FIRST_CRASH_TYPE column
# - From FIRST_CRASH_TYPE Column, PEDESTRIAN INJURY is almost 3 times more than Not-injured

# %%
# BICYCLE & PEDESTRIAN No# INJURED > NOT INJURED
train_new_class.groupby(['PERSON_TYPE', 'INJURY']).size().reset_index()
# Out:
#             PERSON_TYPE       INJURY      0
# 0               BICYCLE      INJURED    248
# 1               BICYCLE  NOT INJURED    168
# 2                DRIVER      INJURED   4418
# 3                DRIVER  NOT INJURED  41108
# 4   NON-CONTACT VEHICLE      INJURED      2
# 5   NON-CONTACT VEHICLE  NOT INJURED     10
# 6     NON-MOTOR VEHICLE      INJURED      5
# 7     NON-MOTOR VEHICLE  NOT INJURED     51
# 8             PASSENGER      INJURED   2030
# 9             PASSENGER  NOT INJURED  10518
# 10           PEDESTRIAN      INJURED    646
# 11           PEDESTRIAN  NOT INJURED    207
# 12  UNABLE TO DETERMINE      INJURED    404
# 13  UNABLE TO DETERMINE  NOT INJURED   6502

# %%
ax = train_new_class.groupby(['INJURY','PERSON_TYPE'])['PERSON_TYPE'].count().unstack(0).plot.bar(title="Number of crashes for each PERSON_TYPE", 
                                                                                                  figsize=(14,8), color=['red', 'blue'])
_ = ax.set_xlabel('PERSON_TYPE')
_ = ax.set_ylabel('INJURY')

# %%
train_new_class.groupby(['FIRST_CRASH_TYPE']).size()
# Out:
# FIRST_CRASH_TYPE
# ANGLE                            8081
# ANIMAL                             30
# FIXED OBJECT                     1822
# HEAD ON                           650
# OTHER NONCOLLISION                121
# OTHER OBJECT                      384
# OVERTURNED                         16
# PARKED MOTOR VEHICLE            13982
# PEDALCYCLIST                      907
# PEDESTRIAN                       1600
# REAR END                        16564
# REAR TO FRONT                     433
# REAR TO REAR                      102
# REAR TO SIDE                      282
# SIDESWIPE OPPOSITE DIRECTION     1020
# SIDESWIPE SAME DIRECTION        10157
# TRAIN                               3
# TURNING                         10163
# dtype: int64

# %%
train_new_class.groupby(['FIRST_CRASH_TYPE', 'INJURY']).size().reset_index()
# Out:
#                 FIRST_CRASH_TYPE       INJURY      0
# 0                          ANGLE      INJURED   1506
# 1                          ANGLE  NOT INJURED   6575
# 2                         ANIMAL  NOT INJURED     30
# 3                   FIXED OBJECT      INJURED    310
# 4                   FIXED OBJECT  NOT INJURED   1512
# 5                        HEAD ON      INJURED    229
# 6                        HEAD ON  NOT INJURED    421
# 7             OTHER NONCOLLISION      INJURED     25
# 8             OTHER NONCOLLISION  NOT INJURED     96
# 9                   OTHER OBJECT      INJURED     47
# 10                  OTHER OBJECT  NOT INJURED    337
# 11                    OVERTURNED      INJURED      6
# 12                    OVERTURNED  NOT INJURED     10
# 13          PARKED MOTOR VEHICLE      INJURED    554
# 14          PARKED MOTOR VEHICLE  NOT INJURED  13428
# 15                  PEDALCYCLIST      INJURED    544
# 16                  PEDALCYCLIST  NOT INJURED    363
# 17                    PEDESTRIAN      INJURED   1189
# 18                    PEDESTRIAN  NOT INJURED    411
# 19                      REAR END      INJURED   1373
# 20                      REAR END  NOT INJURED  15191
# 21                 REAR TO FRONT      INJURED     28
# 22                 REAR TO FRONT  NOT INJURED    405
# 23                  REAR TO REAR  NOT INJURED    102
# 24                  REAR TO SIDE      INJURED      9
# 25                  REAR TO SIDE  NOT INJURED    273
# 26  SIDESWIPE OPPOSITE DIRECTION      INJURED    114
# 27  SIDESWIPE OPPOSITE DIRECTION  NOT INJURED    906
# 28      SIDESWIPE SAME DIRECTION      INJURED    484
# 29      SIDESWIPE SAME DIRECTION  NOT INJURED   9673
# 30                         TRAIN  NOT INJURED      3
# 31                       TURNING      INJURED   1335
# 32                       TURNING  NOT INJURED   8828

# %%
ax = train_new_class.groupby(['INJURY','FIRST_CRASH_TYPE'])['PERSON_TYPE'].count().unstack(0).plot.bar(title="Number of crashes for each FIRST_CRASH_TYPE", 
                                                                                                  figsize=(14,8), color=['red', 'blue'])
_ = ax.set_xlabel('FIRST_CRASH_TYPE')
_ = ax.set_ylabel('INJURY')

# %%
train_new_class = train_new_class["FIRST_CRASH_TYPE"].drop('UNABLE TO DETERMINE')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-180-970691634e1b> in <module>
# ----> 1 train_new_class = train_new_class["FIRST_CRASH_TYPE"].drop('UNABLE TO DETERMINE')
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4495         dtype: float64
#    4496         """
# -> 4497         return super().drop(
#    4498             labels=labels,
#    4499             axis=axis,
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['UNABLE TO DETERMINE'] not found in axis"

# %%
train_new_class[train_new_class["FIRST_CRASH_TYPE"] == "PEDESTRIAN"].groupby(['PRIM_CONTRIBUTORY_CAUSE'])\
                                                                    .size() \
                                                                    .reset_index(name='count') \
                                                                    .sort_values(['count'], ascending=False)
# Out:
#                               PRIM_CONTRIBUTORY_CAUSE  count
# 27                                UNABLE TO DETERMINE    584
# 15                      FAILING TO YIELD RIGHT-OF-WAY    453
# 22                                     NOT APPLICABLE    112
# 14             FAILING TO REDUCE SPEED TO AVOID CRASH     77
# 5                        DISREGARDING TRAFFIC SIGNALS     61
# 23  OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELE...     50
# 29  VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...     47
# 18                                   IMPROPER BACKING     43
# 30                                            WEATHER     23
# 24                       PHYSICAL CONDITION OF DRIVER     21
# 10                DRIVING SKILLS/KNOWLEDGE/EXPERIENCE     20
# 4                              DISREGARDING STOP SIGN     19
# 7                  DISTRACTION - FROM OUTSIDE VEHICLE     10
# 3                          DISREGARDING ROAD MARKINGS      9
# 20                        IMPROPER OVERTAKING/PASSING      8
# 21                         IMPROPER TURNING/NO SIGNAL      8
# 2                    DISREGARDING OTHER TRAFFIC SIGNS      7
# 0                                              ANIMAL      6
# 17    HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)      5
# 19                                IMPROPER LANE USAGE      5
# 16                              FOLLOWING TOO CLOSELY      5
# 25                                RELATED TO BUS STOP      4
# 12                   EXCEEDING AUTHORIZED SPEED LIMIT      4
# 11  EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST      4
# 26                               TURNING RIGHT ON RED      3
# 28  UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN...      3
# 9                     DRIVING ON WRONG SIDE/WRONG WAY      3
# 6                   DISTRACTION - FROM INSIDE VEHICLE      2
# 13                EXCEEDING SAFE SPEED FOR CONDITIONS      2
# 1                   CELL PHONE USE OTHER THAN TEXTING      1
# 8   DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGAT...      1

# %%
train_new_class.groupby(['PRIM_CONTRIBUTORY_CAUSE', 'INJURY']).size().reset_index()
# Out:
#                               PRIM_CONTRIBUTORY_CAUSE       INJURY    0
# 0                                              ANIMAL      INJURED   16
# 1                                              ANIMAL  NOT INJURED   36
# 2              BICYCLE ADVANCING LEGALLY ON RED LIGHT      INJURED    3
# 3              BICYCLE ADVANCING LEGALLY ON RED LIGHT  NOT INJURED    8
# 4                   CELL PHONE USE OTHER THAN TEXTING      INJURED   10
# ..                                                ...          ...  ...
# 71  UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN...  NOT INJURED  310
# 72  VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...      INJURED   79
# 73  VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS,...  NOT INJURED  322
# 74                                            WEATHER      INJURED  118
# 75                                            WEATHER  NOT INJURED  934
#
# [76 rows x 3 columns]

# %% [markdown]
# **Code for seating position of motor vehicle occupant:**
# - 1= driver,
# - 2= center front,
# - 3 = front passenger,
# - 4 = second row left,
# - 5 = second row center,
# - 6 = second row right,
# - 7 = enclosed passengers,
# - 8 = exposed passengers,
# - 9= unknown position,
# - 10 = third row left,
# - 11 = third row center,
# - 12 = third row right

# %%
train_new_class.groupby(['SEAT_NO', 'INJURY']).size().reset_index()
# Out:
#    SEAT_NO       INJURY      0
# 0        0      INJURED   5723
# 1        0  NOT INJURED  48046
# 2        1      INJURED     35
# 3        1  NOT INJURED    508
# 4       10      INJURED     50
# 5       10  NOT INJURED    235
# 6       11      INJURED     33
# 7       11  NOT INJURED     97
# 8       12      INJURED     69
# 9       12  NOT INJURED    265
# 10       2      INJURED     85
# 11       2  NOT INJURED    432
# 12       3      INJURED    967
# 13       3  NOT INJURED   4987
# 14       4      INJURED    281
# 15       4  NOT INJURED   1438
# 16       5      INJURED    117
# 17       5  NOT INJURED    504
# 18       6      INJURED    369
# 19       6  NOT INJURED   1797
# 20       7      INJURED     16
# 21       7  NOT INJURED    245
# 22       8      INJURED      8
# 23       8  NOT INJURED     10

# %%
train_new_class.groupby(['SEAT_NO', 'INJURY']).size().reset_index(name='count') \
 .sort_values(['count'], ascending = False)
# Out:
#    SEAT_NO       INJURY  count
# 1        0  NOT INJURED  48046
# 0        0      INJURED   5723
# 13       3  NOT INJURED   4987
# 19       6  NOT INJURED   1797
# 15       4  NOT INJURED   1438
# 12       3      INJURED    967
# 3        1  NOT INJURED    508
# 17       5  NOT INJURED    504
# 11       2  NOT INJURED    432
# 18       6      INJURED    369
# 14       4      INJURED    281
# 9       12  NOT INJURED    265
# 21       7  NOT INJURED    245
# 5       10  NOT INJURED    235
# 16       5      INJURED    117
# 7       11  NOT INJURED     97
# 10       2      INJURED     85
# 8       12      INJURED     69
# 4       10      INJURED     50
# 2        1      INJURED     35
# 6       11      INJURED     33
# 20       7      INJURED     16
# 23       8  NOT INJURED     10
# 22       8      INJURED      8

# %%
# trial 1 drop "PERSON_TYPE"
train_new_class = train_new_class.drop("PERSON_TYPE", axis=1)
# trial 2 drop "CRASH_HOUR"
train_new_class = train_new_class.drop("CRASH_HOUR", axis=1)
# trial 3 drop "PEDPEDAL_VISIBILITY"
train_new_class = train_new_class.drop("PEDPEDAL_VISIBILITY", axis=1)

# %%
train_new_class.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 66317 entries, 904 to 15795
# Data columns (total 44 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   POSTED_SPEED_LIMIT       66317 non-null  int64
#  1   TRAFFIC_CONTROL_DEVICE   66317 non-null  object
#  2   DEVICE_CONDITION         66317 non-null  object
#  3   WEATHER_CONDITION        66317 non-null  object
#  4   LIGHTING_CONDITION       66317 non-null  object
#  5   FIRST_CRASH_TYPE         66317 non-null  object
#  6   TRAFFICWAY_TYPE          66317 non-null  object
#  7   LANE_CNT                 66317 non-null  int64
#  8   ALIGNMENT                66317 non-null  object
#  9   ROADWAY_SURFACE_COND     66317 non-null  object
#  10  ROAD_DEFECT              66317 non-null  object
#  11  INTERSECTION_RELATED_I   66317 non-null  object
#  12  NOT_RIGHT_OF_WAY_I       66317 non-null  object
#  13  HIT_AND_RUN_I            66317 non-null  object
#  14  PRIM_CONTRIBUTORY_CAUSE  66317 non-null  object
#  15  SEC_CONTRIBUTORY_CAUSE   66317 non-null  object
#  16  STREET_DIRECTION         66317 non-null  object
#  17  DOORING_I                66317 non-null  object
#  18  WORK_ZONE_I              66317 non-null  object
#  19  NUM_UNITS                66317 non-null  int64
#  20  NUM_PASSENGERS           66317 non-null  object
#  21  VEHICLE_DEFECT           66317 non-null  object
#  22  VEHICLE_TYPE             66317 non-null  object
#  23  VEHICLE_USE              66317 non-null  object
#  24  TRAVEL_DIRECTION         66317 non-null  object
#  25  MANEUVER                 66317 non-null  object
#  26  OCCUPANT_CNT             66317 non-null  int64
#  27  EXCEED_SPEED_LIMIT_I     66317 non-null  object
#  28  FIRST_CONTACT_POINT      66317 non-null  object
#  29  SEAT_NO                  66317 non-null  object
#  30  SEX                      66317 non-null  object
#  31  AGE                      66317 non-null  float64
#  32  SAFETY_EQUIPMENT         66317 non-null  object
#  33  AIRBAG_DEPLOYED          66317 non-null  object
#  34  EJECTION                 66317 non-null  object
#  35  DRIVER_ACTION            66317 non-null  object
#  36  DRIVER_VISION            66317 non-null  object
#  37  PHYSICAL_CONDITION       66317 non-null  object
#  38  PEDPEDAL_ACTION          66317 non-null  object
#  39  BAC_RESULT VALUE         66317 non-null  object
#  40  CELL_PHONE_USE           66317 non-null  object
#  41  INJURY                   66317 non-null  object
#  42  Location                 66317 non-null  object
#  43  VEHICLE_AGE              66317 non-null  int64
# dtypes: float64(1), int64(5), object(38)
# memory usage: 22.8+ MB

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Decision Tree

# %%
# splitting the dataset into x_train and y_train
X_train = train_new_class.drop(["INJURY"],axis=1)
y_train = train_new_class["INJURY"]

# %%
#X_train.info()

# %%
# performing one hot encoding on all the object features
X_train = pd.get_dummies(X_train, columns=X_train.select_dtypes(['object']).columns, drop_first=True)

# %%
X_train.head()
# Out:
#        POSTED_SPEED_LIMIT  LANE_CNT  NUM_UNITS  OCCUPANT_CNT   AGE  \
# 904                    30         2          2             1  41.0
# 18433                  30         2          3             1  52.0
# 71357                  30         1          2             0  35.0
# 24768                  30         2          2             2  35.0
# 34668                  30         2          2             2  35.0
#
#        VEHICLE_AGE  TRAFFIC_CONTROL_DEVICE_SIGN  \
# 904             21                            1
# 18433            1                            0
# 71357           12                            0
# 24768           10                            0
# 34668           17                            0
#
#        DEVICE_CONDITION_FUNCTIONING PROPERLY  DEVICE_CONDITION_MISSING  \
# 904                                        1                         0
# 18433                                      0                         0
# 71357                                      0                         0
# 24768                                      0                         0
# 34668                                      0                         0
#
#        DEVICE_CONDITION_NO CONTROLS  DEVICE_CONDITION_NOT FUNCTIONING  \
# 904                               0                                 0
# 18433                             1                                 0
# 71357                             1                                 0
# 24768                             1                                 0
# 34668                             1                                 0
#
#        DEVICE_CONDITION_OTHER  DEVICE_CONDITION_WORN REFLECTIVE MATERIAL  \
# 904                         0                                          0
# 18433                       0                                          0
# 71357                       0                                          0
# 24768                       0                                          0
# 34668                       0                                          0
#
#        WEATHER_CONDITION_BLOWING SNOW  WEATHER_CONDITION_CLEAR  \
# 904                                 0                        1
# 18433                               0                        0
# 71357                               0                        0
# 24768                               0                        1
# 34668                               0                        1
#
#        WEATHER_CONDITION_CLOUDY/OVERCAST  WEATHER_CONDITION_FOG/SMOKE/HAZE  \
# 904                                    0                                 0
# 18433                                  0                                 0
# 71357                                  0                                 0
# 24768                                  0                                 0
# 34668                                  0                                 0
#
#        WEATHER_CONDITION_FREEZING RAIN/DRIZZLE  WEATHER_CONDITION_OTHER  \
# 904                                          0                        0
# 18433                                        0                        0
# 71357                                        0                        0
# 24768                                        0                        0
# 34668                                        0                        0
#
#        WEATHER_CONDITION_RAIN  WEATHER_CONDITION_SEVERE CROSS WIND GATE  \
# 904                         0                                         0
# 18433                       1                                         0
# 71357                       0                                         0
# 24768                       0                                         0
# 34668                       0                                         0
#
#        WEATHER_CONDITION_SLEET/HAIL  WEATHER_CONDITION_SNOW  \
# 904                               0                       0
# 18433                             0                       0
# 71357                             0                       1
# 24768                             0                       0
# 34668                             0                       0
#
#        LIGHTING_CONDITION_DARKNESS, LIGHTED ROAD  LIGHTING_CONDITION_DAWN  \
# 904                                            0                        0
# 18433                                          0                        0
# 71357                                          0                        0
# 24768                                          0                        0
# 34668                                          0                        0
#
#        LIGHTING_CONDITION_DAYLIGHT  LIGHTING_CONDITION_DUSK  \
# 904                              1                        0
# 18433                            1                        0
# 71357                            0                        0
# 24768                            1                        0
# 34668                            1                        0
#
#        FIRST_CRASH_TYPE_ANIMAL  FIRST_CRASH_TYPE_FIXED OBJECT  \
# 904                          0                              0
# 18433                        0                              0
# 71357                        0                              0
# 24768                        0                              0
# 34668                        0                              0
#
#        FIRST_CRASH_TYPE_HEAD ON  FIRST_CRASH_TYPE_OTHER NONCOLLISION  \
# 904                           1                                    0
# 18433                         0                                    0
# 71357                         0                                    0
# 24768                         0                                    0
# 34668                         0                                    0
#
#        FIRST_CRASH_TYPE_OTHER OBJECT  FIRST_CRASH_TYPE_OVERTURNED  \
# 904                                0                            0
# 18433                              0                            0
# 71357                              0                            0
# 24768                              0                            0
# 34668                              0                            0
#
#        FIRST_CRASH_TYPE_PARKED MOTOR VEHICLE  FIRST_CRASH_TYPE_PEDALCYCLIST  \
# 904                                        0                              0
# 18433                                      0                              0
# 71357                                      1                              0
# 24768                                      1                              0
# 34668                                      0                              0
#
#        FIRST_CRASH_TYPE_PEDESTRIAN  FIRST_CRASH_TYPE_REAR END  \
# 904                              0                          0
# 18433                            0                          1
# 71357                            0                          0
# 24768                            0                          0
# 34668                            0                          0
#
#        FIRST_CRASH_TYPE_REAR TO FRONT  FIRST_CRASH_TYPE_REAR TO REAR  \
# 904                                 0                              0
# 18433                               0                              0
# 71357                               0                              0
# 24768                               0                              0
# 34668                               0                              0
#
#        FIRST_CRASH_TYPE_REAR TO SIDE  \
# 904                                0
# 18433                              0
# 71357                              0
# 24768                              0
# 34668                              0
#
#        FIRST_CRASH_TYPE_SIDESWIPE OPPOSITE DIRECTION  \
# 904                                                0
# 18433                                              0
# 71357                                              0
# 24768                                              0
# 34668                                              0
#
#        FIRST_CRASH_TYPE_SIDESWIPE SAME DIRECTION  FIRST_CRASH_TYPE_TRAIN  \
# 904                                            0                       0
# 18433                                          0                       0
# 71357                                          0                       0
# 24768                                          0                       0
# 34668                                          0                       0
#
#        FIRST_CRASH_TYPE_TURNING  TRAFFICWAY_TYPE_CENTER TURN LANE  \
# 904                           0                                 0
# 18433                         0                                 0
# 71357                         0                                 0
# 24768                         0                                 0
# 34668                         1                                 0
#
#        TRAFFICWAY_TYPE_DIVIDED - W/MEDIAN (NOT RAISED)  \
# 904                                                  1
# 18433                                                0
# 71357                                                0
# 24768                                                0
# 34668                                                0
#
#        TRAFFICWAY_TYPE_DIVIDED - W/MEDIAN BARRIER  TRAFFICWAY_TYPE_DRIVEWAY  \
# 904                                             0                         0
# 18433                                           1                         0
# 71357                                           0                         0
# 24768                                           0                         0
# 34668                                           0                         0
#
#        TRAFFICWAY_TYPE_FIVE POINT, OR MORE  TRAFFICWAY_TYPE_FOUR WAY  \
# 904                                      0                         0
# 18433                                    0                         0
# 71357                                    0                         0
# 24768                                    0                         0
# 34668                                    0                         0
#
#        TRAFFICWAY_TYPE_L-INTERSECTION  TRAFFICWAY_TYPE_NOT DIVIDED  \
# 904                                 0                            0
# 18433                               0                            0
# 71357                               0                            0
# 24768                               0                            1
# 34668                               0                            1
#
#        TRAFFICWAY_TYPE_NOT REPORTED  TRAFFICWAY_TYPE_ONE-WAY  \
# 904                               0                        0
# 18433                             0                        0
# 71357                             0                        1
# 24768                             0                        0
# 34668                             0                        0
#
#        TRAFFICWAY_TYPE_OTHER  TRAFFICWAY_TYPE_PARKING LOT  \
# 904                        0                            0
# 18433                      0                            0
# 71357                      0                            0
# 24768                      0                            0
# 34668                      0                            0
#
#        TRAFFICWAY_TYPE_RAMP  TRAFFICWAY_TYPE_ROUNDABOUT  \
# 904                       0                           0
# 18433                     0                           0
# 71357                     0                           0
# 24768                     0                           0
# 34668                     0                           0
#
#        TRAFFICWAY_TYPE_T-INTERSECTION  TRAFFICWAY_TYPE_TRAFFIC ROUTE  \
# 904                                 0                              0
# 18433                               0                              0
# 71357                               0                              0
# 24768                               0                              0
# 34668                               0                              0
#
#        TRAFFICWAY_TYPE_UNKNOWN INTERSECTION TYPE  \
# 904                                            0
# 18433                                          0
# 71357                                          0
# 24768                                          0
# 34668                                          0
#
#        TRAFFICWAY_TYPE_Y-INTERSECTION  ALIGNMENT_CURVE ON HILLCREST  \
# 904                                 0                             0
# 18433                               0                             0
# 71357                               0                             0
# 24768                               0                             0
# 34668                               0                             0
#
#        ALIGNMENT_CURVE, LEVEL  ALIGNMENT_STRAIGHT AND LEVEL  \
# 904                         0                             1
# 18433                       0                             1
# 71357                       0                             1
# 24768                       0                             1
# 34668                       0                             1
#
#        ALIGNMENT_STRAIGHT ON GRADE  ALIGNMENT_STRAIGHT ON HILLCREST  \
# 904                              0                                0
# 18433                            0                                0
# 71357                            0                                0
# 24768                            0                                0
# 34668                            0                                0
#
#        ROADWAY_SURFACE_COND_ICE  ROADWAY_SURFACE_COND_NO DEFECTS  \
# 904                           0                                0
# 18433                         0                                0
# 71357                         0                                0
# 24768                         0                                0
# 34668                         0                                0
#
#        ROADWAY_SURFACE_COND_OTHER  ROADWAY_SURFACE_COND_SAND, MUD, DIRT  \
# 904                             0                                     0
# 18433                           0                                     0
# 71357                           0                                     0
# 24768                           0                                     0
# 34668                           0                                     0
#
#        ROADWAY_SURFACE_COND_SNOW OR SLUSH  ROADWAY_SURFACE_COND_WET  \
# 904                                     0                         0
# 18433                                   0                         1
# 71357                                   1                         0
# 24768                                   0                         0
# 34668                                   0                         0
#
#        ROAD_DEFECT_DEBRIS ON ROADWAY  ROAD_DEFECT_NO DEFECTS  \
# 904                                0                       1
# 18433                              0                       1
# 71357                              0                       1
# 24768                              0                       1
# 34668                              0                       1
#
#        ROAD_DEFECT_OTHER  ROAD_DEFECT_RUT, HOLES  ROAD_DEFECT_SHOULDER DEFECT  \
# 904                    0                       0                            0
# 18433                  0                       0                            0
# 71357                  0                       0                            0
# 24768                  0                       0                            0
# 34668                  0                       0                            0
#
#        ROAD_DEFECT_WORN SURFACE  INTERSECTION_RELATED_I_Y  \
# 904                           0                         0
# 18433                         0                         0
# 71357                         0                         0
# 24768                         0                         0
# 34668                         0                         0
#
#        NOT_RIGHT_OF_WAY_I_Y  HIT_AND_RUN_I_Y  \
# 904                       0                0
# 18433                     0                0
# 71357                     0                0
# 24768                     0                1
# 34668                     0                0
#
#        PRIM_CONTRIBUTORY_CAUSE_BICYCLE ADVANCING LEGALLY ON RED LIGHT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_CELL PHONE USE OTHER THAN TEXTING  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISREGARDING OTHER TRAFFIC SIGNS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISREGARDING ROAD MARKINGS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISREGARDING STOP SIGN  \
# 904                                                 0
# 18433                                               0
# 71357                                               0
# 24768                                               0
# 34668                                               0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISREGARDING TRAFFIC SIGNALS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISREGARDING YIELD SIGN  \
# 904                                                  0
# 18433                                                0
# 71357                                                0
# 24768                                                0
# 34668                                                0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - FROM INSIDE VEHICLE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - FROM OUTSIDE VEHICLE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DRIVING ON WRONG SIDE/WRONG WAY  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_DRIVING SKILLS/KNOWLEDGE/EXPERIENCE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_EQUIPMENT - VEHICLE CONDITION  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_EXCEEDING AUTHORIZED SPEED LIMIT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_EXCEEDING SAFE SPEED FOR CONDITIONS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_FAILING TO REDUCE SPEED TO AVOID CRASH  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  1
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_FAILING TO YIELD RIGHT-OF-WAY  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_FOLLOWING TOO CLOSELY  \
# 904                                                0
# 18433                                              0
# 71357                                              0
# 24768                                              0
# 34668                                              0
#
#        PRIM_CONTRIBUTORY_CAUSE_HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_IMPROPER BACKING  \
# 904                                           0
# 18433                                         0
# 71357                                         0
# 24768                                         0
# 34668                                         0
#
#        PRIM_CONTRIBUTORY_CAUSE_IMPROPER LANE USAGE  \
# 904                                              0
# 18433                                            0
# 71357                                            0
# 24768                                            0
# 34668                                            0
#
#        PRIM_CONTRIBUTORY_CAUSE_IMPROPER OVERTAKING/PASSING  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  1
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_IMPROPER TURNING/NO SIGNAL  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_NOT APPLICABLE  \
# 904                                         1
# 18433                                       0
# 71357                                       0
# 24768                                       0
# 34668                                       0
#
#        PRIM_CONTRIBUTORY_CAUSE_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  1
#
#        PRIM_CONTRIBUTORY_CAUSE_PASSING STOPPED SCHOOL BUS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_PHYSICAL CONDITION OF DRIVER  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_RELATED TO BUS STOP  \
# 904                                              0
# 18433                                            0
# 71357                                            0
# 24768                                            0
# 34668                                            0
#
#        PRIM_CONTRIBUTORY_CAUSE_ROAD CONSTRUCTION/MAINTENANCE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_ROAD ENGINEERING/SURFACE/MARKING DEFECTS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_TEXTING  \
# 904                                  0
# 18433                                0
# 71357                                0
# 24768                                0
# 34668                                0
#
#        PRIM_CONTRIBUTORY_CAUSE_TURNING RIGHT ON RED  \
# 904                                               0
# 18433                                             0
# 71357                                             0
# 24768                                             0
# 34668                                             0
#
#        PRIM_CONTRIBUTORY_CAUSE_UNABLE TO DETERMINE  \
# 904                                              0
# 18433                                            1
# 71357                                            0
# 24768                                            0
# 34668                                            0
#
#        PRIM_CONTRIBUTORY_CAUSE_UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PRIM_CONTRIBUTORY_CAUSE_WEATHER  \
# 904                                  0
# 18433                                0
# 71357                                0
# 24768                                0
# 34668                                0
#
#        SEC_CONTRIBUTORY_CAUSE_BICYCLE ADVANCING LEGALLY ON RED LIGHT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_CELL PHONE USE OTHER THAN TEXTING  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISREGARDING OTHER TRAFFIC SIGNS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISREGARDING ROAD MARKINGS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISREGARDING STOP SIGN  \
# 904                                                0
# 18433                                              0
# 71357                                              0
# 24768                                              0
# 34668                                              0
#
#        SEC_CONTRIBUTORY_CAUSE_DISREGARDING TRAFFIC SIGNALS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISREGARDING YIELD SIGN  \
# 904                                                 0
# 18433                                               0
# 71357                                               0
# 24768                                               0
# 34668                                               0
#
#        SEC_CONTRIBUTORY_CAUSE_DISTRACTION - FROM INSIDE VEHICLE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISTRACTION - FROM OUTSIDE VEHICLE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DRIVING ON WRONG SIDE/WRONG WAY  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_DRIVING SKILLS/KNOWLEDGE/EXPERIENCE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_EQUIPMENT - VEHICLE CONDITION  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  1
#
#        SEC_CONTRIBUTORY_CAUSE_EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_EXCEEDING AUTHORIZED SPEED LIMIT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_EXCEEDING SAFE SPEED FOR CONDITIONS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_FAILING TO REDUCE SPEED TO AVOID CRASH  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  1
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_FAILING TO YIELD RIGHT-OF-WAY  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_FOLLOWING TOO CLOSELY  \
# 904                                               0
# 18433                                             0
# 71357                                             0
# 24768                                             0
# 34668                                             0
#
#        SEC_CONTRIBUTORY_CAUSE_HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_IMPROPER BACKING  \
# 904                                          0
# 18433                                        0
# 71357                                        0
# 24768                                        0
# 34668                                        0
#
#        SEC_CONTRIBUTORY_CAUSE_IMPROPER LANE USAGE  \
# 904                                             0
# 18433                                           0
# 71357                                           0
# 24768                                           0
# 34668                                           0
#
#        SEC_CONTRIBUTORY_CAUSE_IMPROPER OVERTAKING/PASSING  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  1
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_IMPROPER TURNING/NO SIGNAL  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_NOT APPLICABLE  \
# 904                                        1
# 18433                                      1
# 71357                                      0
# 24768                                      0
# 34668                                      0
#
#        SEC_CONTRIBUTORY_CAUSE_OBSTRUCTED CROSSWALKS  \
# 904                                               0
# 18433                                             0
# 71357                                             0
# 24768                                             0
# 34668                                             0
#
#        SEC_CONTRIBUTORY_CAUSE_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_PASSING STOPPED SCHOOL BUS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_PHYSICAL CONDITION OF DRIVER  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_RELATED TO BUS STOP  \
# 904                                             0
# 18433                                           0
# 71357                                           0
# 24768                                           0
# 34668                                           0
#
#        SEC_CONTRIBUTORY_CAUSE_ROAD CONSTRUCTION/MAINTENANCE  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_ROAD ENGINEERING/SURFACE/MARKING DEFECTS  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_TEXTING  \
# 904                                 0
# 18433                               0
# 71357                               0
# 24768                               0
# 34668                               0
#
#        SEC_CONTRIBUTORY_CAUSE_TURNING RIGHT ON RED  \
# 904                                              0
# 18433                                            0
# 71357                                            0
# 24768                                            0
# 34668                                            0
#
#        SEC_CONTRIBUTORY_CAUSE_UNABLE TO DETERMINE  \
# 904                                             0
# 18433                                           0
# 71357                                           0
# 24768                                           0
# 34668                                           0
#
#        SEC_CONTRIBUTORY_CAUSE_UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        SEC_CONTRIBUTORY_CAUSE_WEATHER  STREET_DIRECTION_N  STREET_DIRECTION_S  \
# 904                                 0                   0                   0
# 18433                               0                   1                   0
# 71357                               0                   0                   1
# 24768                               0                   0                   0
# 34668                               0                   0                   0
#
#        STREET_DIRECTION_W  DOORING_I_Y  WORK_ZONE_I_Y  NUM_PASSENGERS_1  \
# 904                     1            0              0                 0
# 18433                   0            0              0                 0
# ...
#
#        DRIVER_VISION_BLINDED - SUNLIGHT  DRIVER_VISION_BLOWING MATERIALS  \
# 904                                   0                                0
# 18433                                 0                                0
# 71357                                 0                                0
# 24768                                 0                                0
# 34668                                 0                                0
#
#        DRIVER_VISION_BUILDINGS  DRIVER_VISION_EMBANKMENT  \
# 904                          0                         0
# 18433                        0                         0
# 71357                        0                         0
# 24768                        0                         0
# 34668                        0                         0
#
#        DRIVER_VISION_HILLCREST  DRIVER_VISION_MOVING VEHICLES  \
# 904                          0                              0
# 18433                        0                              0
# 71357                        0                              0
# 24768                        0                              0
# 34668                        0                              0
#
#        DRIVER_VISION_NOT OBSCURED  DRIVER_VISION_OTHER  \
# 904                             1                    0
# 18433                           1                    0
# 71357                           0                    1
# 24768                           0                    1
# 34668                           0                    1
#
#        DRIVER_VISION_PARKED VEHICLES  DRIVER_VISION_SIGNBOARD  \
# 904                                0                        0
# 18433                              0                        0
# 71357                              0                        0
# 24768                              0                        0
# 34668                              0                        0
#
#        DRIVER_VISION_TREES, PLANTS  DRIVER_VISION_WINDSHIELD (WATER/ICE)  \
# 904                              0                                     0
# 18433                            0                                     0
# 71357                            0                                     0
# 24768                            0                                     0
# 34668                            0                                     0
#
#        PHYSICAL_CONDITION_FATIGUED/ASLEEP  \
# 904                                     0
# 18433                                   0
# 71357                                   0
# 24768                                   0
# 34668                                   0
#
#        PHYSICAL_CONDITION_HAD BEEN DRINKING  \
# 904                                       0
# 18433                                     0
# 71357                                     0
# 24768                                     0
# 34668                                     0
#
#        PHYSICAL_CONDITION_ILLNESS/FAINTED  \
# 904                                     0
# 18433                                   0
# 71357                                   0
# 24768                                   0
# 34668                                   0
#
#        PHYSICAL_CONDITION_IMPAIRED - ALCOHOL  \
# 904                                        0
# 18433                                      0
# 71357                                      0
# 24768                                      0
# 34668                                      0
#
#        PHYSICAL_CONDITION_IMPAIRED - ALCOHOL AND DRUGS  \
# 904                                                  0
# 18433                                                0
# 71357                                                0
# 24768                                                0
# 34668                                                0
#
#        PHYSICAL_CONDITION_IMPAIRED - DRUGS  PHYSICAL_CONDITION_MEDICATED  \
# 904                                      0                             0
# 18433                                    0                             0
# 71357                                    0                             0
# 24768                                    0                             0
# 34668                                    0                             0
#
#        PHYSICAL_CONDITION_NORMAL  PHYSICAL_CONDITION_OTHER  \
# 904                            1                         0
# 18433                          1                         0
# 71357                          0                         0
# 24768                          0                         0
# 34668                          0                         0
#
#        PHYSICAL_CONDITION_REMOVED BY EMS  \
# 904                                    0
# 18433                                  0
# 71357                                  0
# 24768                                  0
# 34668                                  0
#
#        PHYSICAL_CONDITION_UNABLE TO DETERMINE  \
# 904                                         0
# 18433                                       0
# 71357                                       1
# 24768                                       1
# 34668                                       1
#
#        PEDPEDAL_ACTION_CROSSING - AGAINST SIGNAL  \
# 904                                            0
# 18433                                          0
# 71357                                          0
# 24768                                          0
# 34668                                          0
#
#        PEDPEDAL_ACTION_CROSSING - CONTROLS PRESENT (NOT AT INTERSECTION)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PEDPEDAL_ACTION_CROSSING - NO CONTROLS (AT INTERSECTION)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PEDPEDAL_ACTION_CROSSING - NO CONTROLS (NOT AT INTERSECTION)  \
# 904                                                    0
# 18433                                                  0
# 71357                                                  0
# 24768                                                  0
# 34668                                                  0
#
#        PEDPEDAL_ACTION_CROSSING - WITH SIGNAL  \
# 904                                         0
# 18433                                       0
# 71357                                       0
# 24768                                       0
# 34668                                       0
#
#        PEDPEDAL_ACTION_ENTER FROM DRIVE/ALLEY  \
# 904                                         0
# 18433                                       0
# 71357                                       0
# 24768                                       0
# 34668                                       0
#
#        PEDPEDAL_ACTION_INTOXICATED PED/PEDAL  PEDPEDAL_ACTION_NO ACTION  \
# 904                                        0                          0
# 18433                                      0                          0
# 71357                                      0                          0
# 24768                                      0                          0
# 34668                                      0                          0
#
#        PEDPEDAL_ACTION_NOT AT INTERSECTION  PEDPEDAL_ACTION_OTHER ACTION  \
# 904                                      0                             0
# 18433                                    0                             0
# 71357                                    0                             0
# 24768                                    0                             0
# 34668                                    0                             0
#
#        PEDPEDAL_ACTION_PARKED VEHICLE  PEDPEDAL_ACTION_PLAYING IN ROADWAY  \
# 904                                 0                                   0
# 18433                               0                                   0
# 71357                               0                                   0
# 24768                               0                                   0
# 34668                               0                                   0
#
#        PEDPEDAL_ACTION_PLAYING/WORKING ON VEHICLE  \
# 904                                             0
# 18433                                           0
# 71357                                           0
# 24768                                           0
# 34668                                           0
#
#        PEDPEDAL_ACTION_STANDING IN ROADWAY  PEDPEDAL_ACTION_TURNING LEFT  \
# 904                                      0                             0
# 18433                                    0                             0
# 71357                                    0                             0
# 24768                                    0                             0
# 34668                                    0                             0
#
#        PEDPEDAL_ACTION_TURNING RIGHT  PEDPEDAL_ACTION_UNABLE TO DETERMINE  \
# 904                                0                                    1
# 18433                              0                                    1
# 71357                              0                                    1
# 24768                              0                                    1
# 34668                              0                                    1
#
#        PEDPEDAL_ACTION_WAITING FOR SCHOOL BUS  PEDPEDAL_ACTION_WITH TRAFFIC  \
# 904                                         0                             0
# 18433                                       0                             0
# 71357                                       0                             0
# 24768                                       0                             0
# 34668                                       0                             0
#
#        PEDPEDAL_ACTION_WORKING IN ROADWAY  BAC_RESULT VALUE_0.0000  \
# 904                                     0                        0
# 18433                                   0                        0
# 71357                                   0                        0
# 24768                                   0                        0
# 34668                                   0                        0
#
#        BAC_RESULT VALUE_0.0100  BAC_RESULT VALUE_0.0200  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.0300  BAC_RESULT VALUE_0.0700  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.1000  BAC_RESULT VALUE_0.1100  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.1200  BAC_RESULT VALUE_0.1300  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.1400  BAC_RESULT VALUE_0.1500  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.1600  BAC_RESULT VALUE_0.1700  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.1800  BAC_RESULT VALUE_0.1900  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.2000  BAC_RESULT VALUE_0.2100  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.2200  BAC_RESULT VALUE_0.2300  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.2400  BAC_RESULT VALUE_0.2500  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.2700  BAC_RESULT VALUE_0.2800  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.3100  BAC_RESULT VALUE_0.3200  \
# 904                          0                        0
# 18433                        0                        0
# 71357                        0                        0
# 24768                        0                        0
# 34668                        0                        0
#
#        BAC_RESULT VALUE_0.3500  CELL_PHONE_USE_UNABLE TO DETERMINE  \
# 904                          0                                   1
# 18433                        0                                   1
# 71357                        0                                   1
# 24768                        0                                   1
# 34668                        0                                   1
#
#        CELL_PHONE_USE_Y  Location_Not Downtown
# 904                   0                      1
# 18433                 0                      1
# 71357                 0                      1
# 24768                 0                      1
# 34668                 0                      1

# %%
#Encode the y_train labels
lb = preprocessing.LabelBinarizer()
y_train=lb.fit_transform(y_train)

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Fitting the decision tree with default hyperparameters, apart from
# max_depth which is 5 so that we can plot and read the tree.
dt_default = DecisionTreeClassifier(random_state=0, max_depth=10)

# %%
#Train the model using the training sets y_pred=clf.predict(X_test)
scores = cross_val_score(dt_default, X_train, y_train, cv=5)
print('Accuracy', np.mean(scores), scores)
# Out:
# Accuracy 0.9056199691460511 [0.90681544 0.90493064 0.90530046 0.90379251 0.9072608 ]

# %%
recall = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='recall')
print('Recall', np.mean(recall), recall)
precision = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='precision')
print('Precision', np.mean(precision), precision)
f1 = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='f1')
print('F1', np.mean(f1), f1)
# Out:
# Recall 0.9796291114235316 [0.98326646 0.97763169 0.97797319 0.9803637  0.97891052]
# Precision 0.9188681107619866 [0.91717767 0.91975904 0.91985867 0.91651369 0.92103149]
# F1 0.9482730672852101 [0.94907293 0.94781277 0.94802615 0.94736408 0.9490894 ]

# %%
dt_default.fit(X_train,y_train)
print(dt_default.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(dt_default.feature_importances_, index=X_train.columns)
feat_importances.nlargest(25).plot(kind='barh')
plt.title("Feature Importance")
plt.show()
# Out:
# [1.81342949e-02 4.02786846e-03 7.60540220e-02 4.01780811e-02
#  1.24439087e-02 6.52930903e-03 3.31557014e-04 8.31216523e-03
#  1.10200267e-03 5.73040773e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.26523758e-03
#  0.00000000e+00 0.00000000e+00 4.98858809e-04 1.09419373e-03
#  6.93712682e-04 2.51762207e-03 1.57196451e-03 0.00000000e+00
#  7.87243157e-03 1.62562785e-02 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.13387778e-03 1.01343366e-01 2.85206676e-01
#  1.01611666e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.38337140e-03 0.00000000e+00 1.24310826e-03
#  2.60679213e-03 4.16595571e-03 7.37730477e-04 0.00000000e+00
#  0.00000000e+00 5.93202022e-03 0.00000000e+00 3.31355991e-03
#  0.00000000e+00 1.12784255e-03 0.00000000e+00 1.97337094e-03
#  0.00000000e+00 0.00000000e+00 9.81109068e-04 6.58517327e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.02627627e-03 2.44418197e-03 0.00000000e+00 0.00000000e+00
#  6.16726942e-04 0.00000000e+00 0.00000000e+00 3.88143047e-04
#  3.62266844e-04 0.00000000e+00 3.79138508e-05 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.20590075e-03 6.29171318e-02
#  4.18948051e-04 5.56697608e-03 0.00000000e+00 0.00000000e+00
#  7.50694246e-04 0.00000000e+00 1.09417815e-03 8.38514336e-04
#  0.00000000e+00 0.00000000e+00 2.95635245e-03 0.00000000e+00
#  1.78957698e-03 1.12477470e-03 0.00000000e+00 2.46500345e-03
#  3.01789512e-03 0.00000000e+00 1.36681122e-02 5.27732143e-03
#  0.00000000e+00 6.42601941e-04 0.00000000e+00 1.31558832e-03
#  2.47816601e-03 8.74744113e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 8.06977830e-03 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.16260029e-02 1.98806821e-03 2.08495824e-03 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 4.59547684e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.16444838e-03
#  1.47381626e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.85629187e-03 0.00000000e+00
#  5.01123812e-03 1.20139515e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.68858832e-03 0.00000000e+00
#  0.00000000e+00 2.27810614e-03 0.00000000e+00 2.26183875e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.79936475e-03
#  0.00000000e+00 0.00000000e+00 1.18819300e-03 0.00000000e+00
#  1.22216134e-03 5.03040225e-04 4.20977557e-04 0.00000000e+00
#  1.10086213e-03 2.31248946e-03 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.45052309e-03 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 3.88143047e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.04406028e-02 1.62854076e-03 0.00000000e+00 0.00000000e+00
#  8.23813815e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.74848256e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.31583162e-03 8.94405375e-04
#  0.00000000e+00 0.00000000e+00 8.83661329e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.45672026e-03 0.00000000e+00 0.00000000e+00 5.77943289e-04
#  1.29590906e-03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 3.88143047e-04 0.00000000e+00
#  0.00000000e+00 1.00271394e-03 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.60107224e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 1.01473714e-03
#  0.00000000e+00 0.00000000e+00 2.70268652e-03 0.00000000e+00
#  6.01017878e-02 3.51180145e-02 3.61017762e-02 0.00000000e+00
#  1.01691009e-03 0.00000000e+00 4.18948051e-04 3.53936948e-04
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.63564587e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.21796027e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.28713086e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  7.51036933e-04 0.00000000e+00 2.27059929e-02 3.64872319e-04
#  0.00000000e+00 5.56090658e-04 0.00000000e+00 5.54490068e-04
#  5.67026365e-04 2.88216228e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.89892909e-04 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.95728036e-04 0.00000000e+00
#  8.18425564e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 7.48225330e-04 0.00000000e+00
#  3.36638112e-03]

# %%
for importance, name in sorted(zip(dt_default.feature_importances_, X_train.columns),reverse=True)[:]:
    print (name, importance)
# Out:
# FIRST_CRASH_TYPE_PEDESTRIAN 0.28520667649037507
# FIRST_CRASH_TYPE_PEDALCYCLIST 0.10134336620883234
# NUM_UNITS 0.07605402200771896
# INTERSECTION_RELATED_I_Y 0.06291713178552998
# AIRBAG_DEPLOYED_NOT APPLICABLE 0.060101787767949603
# OCCUPANT_CNT 0.04017808109499562
# AIRBAG_DEPLOYED_UNABLE TO DETERMINE 0.03610177618435339
# AIRBAG_DEPLOYED_NOT DEPLOYED 0.03511801450276114
# PHYSICAL_CONDITION_REMOVED BY EMS 0.02270599285265274
# POSTED_SPEED_LIMIT 0.018134294907976085
# FIRST_CRASH_TYPE_HEAD ON 0.01625627846166221
# PRIM_CONTRIBUTORY_CAUSE_FAILING TO REDUCE SPEED TO AVOID CRASH 0.013668112223051764
# AGE 0.012443908730060075
# PRIM_CONTRIBUTORY_CAUSE_UNABLE TO DETERMINE 0.011626002877889214
# VEHICLE_TYPE_MOTORCYCLE (OVER 150CC) 0.010440602812506902
# FIRST_CRASH_TYPE_REAR END 0.01016116662495514
# DEVICE_CONDITION_FUNCTIONING PROPERLY 0.008312165226768522
# PRIM_CONTRIBUTORY_CAUSE_PHYSICAL CONDITION OF DRIVER 0.008069778303708005
# FIRST_CRASH_TYPE_FIXED OBJECT 0.007872431569375414
# VEHICLE_AGE 0.006529309029622598
# TRAFFICWAY_TYPE_FOUR WAY 0.005932020219074485
# HIT_AND_RUN_I_Y 0.005566976080681745
# NUM_PASSENGERS_3 0.005450523089291583
# FIRST_CRASH_TYPE_SIDESWIPE SAME DIRECTION 0.005383371403096644
# PRIM_CONTRIBUTORY_CAUSE_FAILING TO YIELD RIGHT-OF-WAY 0.005277321427174297
# FIRST_CRASH_TYPE_PARKED MOTOR VEHICLE 0.005133877784843128
# SEC_CONTRIBUTORY_CAUSE_FAILING TO REDUCE SPEED TO AVOID CRASH 0.005011238115069196
# SEC_CONTRIBUTORY_CAUSE_DISREGARDING ROAD MARKINGS 0.004595476844581533
# TRAFFICWAY_TYPE_DIVIDED - W/MEDIAN (NOT RAISED) 0.004165955709807809
# LANE_CNT 0.0040278684633719706
# SEC_CONTRIBUTORY_CAUSE_UNABLE TO DETERMINE 0.0037993647478249027
# SEC_CONTRIBUTORY_CAUSE_IMPROPER OVERTAKING/PASSING 0.003688588324364647
# Location_Not Downtown 0.003366381124260486
# TRAFFICWAY_TYPE_NOT DIVIDED 0.0033135599078709327
# WEATHER_CONDITION_RAIN 0.0032652375781932917
# ALIGNMENT_STRAIGHT AND LEVEL 0.0030262762661060643
# PRIM_CONTRIBUTORY_CAUSE_EXCEEDING AUTHORIZED SPEED LIMIT 0.003017895118276601
# PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - FROM OUTSIDE VEHICLE 0.002956352451595956
# SAFETY_EQUIPMENT_USED SAFETY EQUIP 0.0027026865204603464
# TRAFFICWAY_TYPE_CENTER TURN LANE 0.0026067921264535613
# LIGHTING_CONDITION_DAYLIGHT 0.0025176220748790138
# PRIM_CONTRIBUTORY_CAUSE_IMPROPER OVERTAKING/PASSING 0.0024781660102178495
# PRIM_CONTRIBUTORY_CAUSE_EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST 0.0024650034523723296
# ALIGNMENT_STRAIGHT ON GRADE 0.002444181969645256
# NUM_PASSENGERS_10 0.0023124894582011567
# SEC_CONTRIBUTORY_CAUSE_NOT APPLICABLE 0.0022781061352485457
# SEC_CONTRIBUTORY_CAUSE_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER 0.0022618387530266328
# PRIM_CONTRIBUTORY_CAUSE_VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.) 0.002084958244719822
# PRIM_CONTRIBUTORY_CAUSE_UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED) 0.001988068212110637
# TRAFFICWAY_TYPE_PARKING LOT 0.0019733709362780892
# SEC_CONTRIBUTORY_CAUSE_EXCEEDING AUTHORIZED SPEED LIMIT 0.0018562918722533869
# PRIM_CONTRIBUTORY_CAUSE_DRIVING ON WRONG SIDE/WRONG WAY 0.0017895769817114478
# VEHICLE_TYPE_OTHER 0.0016285407630300891
# LIGHTING_CONDITION_DUSK 0.0015719645113180978
# SEC_CONTRIBUTORY_CAUSE_DISTRACTION - FROM OUTSIDE VEHICLE 0.0014738162576875087
# MANEUVER_STRAIGHT AHEAD 0.0014567202607791492
# VEHICLE_USE_UNKNOWN/NA 0.0013158316177063348
# PRIM_CONTRIBUTORY_CAUSE_IMPROPER LANE USAGE 0.0013155883202680882
# FIRST_CONTACT_POINT_REAR 0.001295909056799163
# FIRST_CRASH_TYPE_TURNING 0.001243108259733517
# STREET_DIRECTION_S 0.0012221613436768084
# ROAD_DEFECT_WORN SURFACE 0.0012059007460720262
# SEC_CONTRIBUTORY_CAUSE_WEATHER 0.0011881930025452216
# SEC_CONTRIBUTORY_CAUSE_DISTRACTION - FROM INSIDE VEHICLE 0.0011644483844862599
# TRAFFICWAY_TYPE_ONE-WAY 0.0011278425544394071
# PRIM_CONTRIBUTORY_CAUSE_DRIVING SKILLS/KNOWLEDGE/EXPERIENCE 0.0011247747012780595
# DEVICE_CONDITION_MISSING 0.0011020026676854644
# NUM_PASSENGERS_1 0.0011008621267564697
# LIGHTING_CONDITION_DARKNESS, LIGHTED ROAD 0.0010941937338994217
# PRIM_CONTRIBUTORY_CAUSE_DISREGARDING STOP SIGN 0.00109417815286485
# EJECTION_TOTALLY EJECTED 0.0010169100861548487
# SAFETY_EQUIPMENT_DID NOT USE SAFETY EQUIP 0.0010147371351651156
# SEAT_NO_5 0.001002713938358755
# TRAFFICWAY_TYPE_T-INTERSECTION 0.0009811090678016076
# TRAVEL_DIRECTION_N 0.0008944053745670636
# TRAVEL_DIRECTION_S 0.0008836613294526216
# PRIM_CONTRIBUTORY_CAUSE_IMPROPER TURNING/NO SIGNAL 0.0008747441125167397
# PRIM_CONTRIBUTORY_CAUSE_DISREGARDING TRAFFIC SIGNALS 0.0008385143362013931
# VEHICLE_TYPE_PICKUP 0.0008238138150980204
# PEDPEDAL_ACTION_UNABLE TO DETERMINE 0.0008184255640202497
# PHYSICAL_CONDITION_NORMAL 0.0007510369330576594
# PRIM_CONTRIBUTORY_CAUSE_DISREGARDING OTHER TRAFFIC SIGNS 0.0007506942457106219
# CELL_PHONE_USE_UNABLE TO DETERMINE 0.0007482253303561161
# TRAFFICWAY_TYPE_DIVIDED - W/MEDIAN BARRIER 0.0007377304772963134
# LIGHTING_CONDITION_DAWN 0.0006937126822940756
# SEX_M 0.0006601072236362343
# TRAFFICWAY_TYPE_TRAFFIC ROUTE 0.0006585173266649727
# PRIM_CONTRIBUTORY_CAUSE_HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE) 0.0006426019411646377
# ROADWAY_SURFACE_COND_NO DEFECTS 0.0006167269422666497
# FIRST_CONTACT_POINT_OTHER 0.0005779432892118653
# DEVICE_CONDITION_NO CONTROLS 0.0005730407734212383
# PEDPEDAL_ACTION_CROSSING - WITH SIGNAL 0.000567026365040711
# PEDPEDAL_ACTION_CROSSING - CONTROLS PRESENT (NOT AT INTERSECTION) 0.0005560906577410272
# PEDPEDAL_ACTION_CROSSING - NO CONTROLS (NOT AT INTERSECTION) 0.0005544900678544366
# STREET_DIRECTION_W 0.0005030402252567517
# WEATHER_CONDITION_SNOW 0.0004988588092429377
# DOORING_I_Y 0.0004209775573985057
# NOT_RIGHT_OF_WAY_I_Y 0.00041894805126779664
# EJECTION_UNABLE TO DETERMINE 0.00041894805126779664
# VEHICLE_DEFECT_NONE 0.0003881430474981057
# SEAT_NO_2 0.0003881430474981057
# ROADWAY_SURFACE_COND_SNOW OR SLUSH 0.0003881430474981057
# VEHICLE_USE_CTA 0.000374848256397502
# PHYSICAL_CONDITION_UNABLE TO DETERMINE 0.0003648723194267892
# DRIVER_ACTION_IMPROPER BACKING 0.00036356458704356516
# ROADWAY_SURFACE_COND_WET 0.00036226684433156514
# DRIVER_ACTION_DISREGARDED CONTROL DEVICES 0.00035393694828959025
# TRAFFIC_CONTROL_DEVICE_SIGN 0.00033155701391596805
# DRIVER_VISION_OTHER 0.0003287130863793482
# PEDPEDAL_ACTION_TURNING LEFT 0.0002957280361890329
# PEDPEDAL_ACTION_ENTER FROM DRIVE/ALLEY 0.0002882162277831616
# DRIVER_ACTION_NONE 0.00022179602714177466
# PEDPEDAL_ACTION_OTHER ACTION 0.00018989290879117563
# SEC_CONTRIBUTORY_CAUSE_FAILING TO YIELD RIGHT-OF-WAY 0.00012013951470179461
# ROAD_DEFECT_NO DEFECTS 3.791385079346542e-05
# WORK_ZONE_I_Y 0.0
# WEATHER_CONDITION_SLEET/HAIL 0.0
# WEATHER_CONDITION_SEVERE CROSS WIND GATE 0.0
# WEATHER_CONDITION_OTHER 0.0
# WEATHER_CONDITION_FREEZING RAIN/DRIZZLE 0.0
# WEATHER_CONDITION_FOG/SMOKE/HAZE 0.0
# WEATHER_CONDITION_CLOUDY/OVERCAST 0.0
# WEATHER_CONDITION_CLEAR 0.0
# WEATHER_CONDITION_BLOWING SNOW 0.0
# VEHICLE_USE_TOW TRUCK 0.0
# VEHICLE_USE_TAXI/FOR HIRE 0.0
# VEHICLE_USE_STATE OWNED 0.0
# VEHICLE_USE_SCHOOL BUS 0.0
# VEHICLE_USE_RIDESHARE SERVICE 0.0
# VEHICLE_USE_POLICE 0.0
# VEHICLE_USE_PERSONAL 0.0
# VEHICLE_USE_OTHER TRANSIT 0.0
# VEHICLE_USE_OTHER 0.0
# VEHICLE_USE_NOT IN USE 0.0
# VEHICLE_USE_MILITARY 0.0
# VEHICLE_USE_MASS TRANSIT 0.0
# VEHICLE_USE_LAWN CARE/LANDSCAPING 0.0
# VEHICLE_USE_FIRE 0.0
# VEHICLE_USE_DRIVER EDUCATION 0.0
# VEHICLE_USE_CONSTRUCTION/MAINTENANCE 0.0
# VEHICLE_USE_COMMERCIAL - SINGLE UNIT 0.0
# VEHICLE_USE_COMMERCIAL - MULTI-UNIT 0.0
# VEHICLE_USE_CAMPER/RV - TOWED/MULTI-UNIT 0.0
# VEHICLE_USE_CAMPER/RV - SINGLE UNIT 0.0
# VEHICLE_USE_AMBULANCE 0.0
# VEHICLE_TYPE_VAN/MINI-VAN 0.0
# VEHICLE_TYPE_TRUCK - SINGLE UNIT 0.0
# VEHICLE_TYPE_TRACTOR W/O SEMI-TRAILER 0.0
# VEHICLE_TYPE_TRACTOR W/ SEMI-TRAILER 0.0
# VEHICLE_TYPE_SPORT UTILITY VEHICLE (SUV) 0.0
# VEHICLE_TYPE_SNOWMOBILE 0.0
# VEHICLE_TYPE_SINGLE UNIT TRUCK WITH TRAILER 0.0
# VEHICLE_TYPE_PASSENGER 0.0
# VEHICLE_TYPE_OTHER VEHICLE WITH TRAILER 0.0
# VEHICLE_TYPE_MOTOR DRIVEN CYCLE 0.0
# VEHICLE_TYPE_MOPED OR MOTORIZED BICYCLE 0.0
# VEHICLE_TYPE_FARM EQUIPMENT 0.0
# VEHICLE_TYPE_BUS UP TO 15 PASS. 0.0
# VEHICLE_TYPE_BUS OVER 15 PASS. 0.0
# VEHICLE_TYPE_AUTOCYCLE 0.0
# VEHICLE_TYPE_ALL-TERRAIN VEHICLE (ATV) 0.0
# VEHICLE_DEFECT_WINDOWS 0.0
# VEHICLE_DEFECT_WHEELS 0.0
# VEHICLE_DEFECT_UNABLE TO DETERMINE 0.0
# VEHICLE_DEFECT_TIRES 0.0
# VEHICLE_DEFECT_SUSPENSION 0.0
# VEHICLE_DEFECT_STEERING 0.0
# VEHICLE_DEFECT_SIGNALS 0.0
# VEHICLE_DEFECT_RESTRAINT SYSTEM 0.0
# VEHICLE_DEFECT_OTHER 0.0
# VEHICLE_DEFECT_LIGHTS 0.0
# VEHICLE_DEFECT_FUEL SYSTEM 0.0
# VEHICLE_DEFECT_ENGINE/MOTOR 0.0
# VEHICLE_DEFECT_CARGO 0.0
# TRAVEL_DIRECTION_W 0.0
# TRAVEL_DIRECTION_SW 0.0
# TRAVEL_DIRECTION_SE 0.0
# TRAVEL_DIRECTION_NW 0.0
# TRAVEL_DIRECTION_NE 0.0
# TRAFFICWAY_TYPE_Y-INTERSECTION 0.0
# TRAFFICWAY_TYPE_UNKNOWN INTERSECTION TYPE 0.0
# TRAFFICWAY_TYPE_ROUNDABOUT 0.0
# TRAFFICWAY_TYPE_RAMP 0.0
# TRAFFICWAY_TYPE_OTHER 0.0
# TRAFFICWAY_TYPE_NOT REPORTED 0.0
# TRAFFICWAY_TYPE_L-INTERSECTION 0.0
# TRAFFICWAY_TYPE_FIVE POINT, OR MORE 0.0
# TRAFFICWAY_TYPE_DRIVEWAY 0.0
# STREET_DIRECTION_N 0.0
# SEX_X 0.0
# SEX_UNABLE TO DETERMINE 0.0
# SEC_CONTRIBUTORY_CAUSE_VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.) 0.0
# SEC_CONTRIBUTORY_CAUSE_UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED) 0.0
# SEC_CONTRIBUTORY_CAUSE_TURNING RIGHT ON RED 0.0
# SEC_CONTRIBUTORY_CAUSE_TEXTING 0.0
# SEC_CONTRIBUTORY_CAUSE_ROAD ENGINEERING/SURFACE/MARKING DEFECTS 0.0
# SEC_CONTRIBUTORY_CAUSE_ROAD CONSTRUCTION/MAINTENANCE 0.0
# SEC_CONTRIBUTORY_CAUSE_RELATED TO BUS STOP 0.0
# SEC_CONTRIBUTORY_CAUSE_PHYSICAL CONDITION OF DRIVER 0.0
# SEC_CONTRIBUTORY_CAUSE_PASSING STOPPED SCHOOL BUS 0.0
# SEC_CONTRIBUTORY_CAUSE_OBSTRUCTED CROSSWALKS 0.0
# SEC_CONTRIBUTORY_CAUSE_MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT 0.0
# SEC_CONTRIBUTORY_CAUSE_IMPROPER TURNING/NO SIGNAL 0.0
# SEC_CONTRIBUTORY_CAUSE_IMPROPER LANE USAGE 0.0
# SEC_CONTRIBUTORY_CAUSE_IMPROPER BACKING 0.0
# SEC_CONTRIBUTORY_CAUSE_HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE) 0.0
# SEC_CONTRIBUTORY_CAUSE_FOLLOWING TOO CLOSELY 0.0
# SEC_CONTRIBUTORY_CAUSE_EXCEEDING SAFE SPEED FOR CONDITIONS 0.0
# SEC_CONTRIBUTORY_CAUSE_EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST 0.0
# SEC_CONTRIBUTORY_CAUSE_EQUIPMENT - VEHICLE CONDITION 0.0
# SEC_CONTRIBUTORY_CAUSE_DRIVING SKILLS/KNOWLEDGE/EXPERIENCE 0.0
# SEC_CONTRIBUTORY_CAUSE_DRIVING ON WRONG SIDE/WRONG WAY 0.0
# SEC_CONTRIBUTORY_CAUSE_DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.) 0.0
# SEC_CONTRIBUTORY_CAUSE_DISREGARDING YIELD SIGN 0.0
# SEC_CONTRIBUTORY_CAUSE_DISREGARDING TRAFFIC SIGNALS 0.0
# SEC_CONTRIBUTORY_CAUSE_DISREGARDING STOP SIGN 0.0
# SEC_CONTRIBUTORY_CAUSE_DISREGARDING OTHER TRAFFIC SIGNS 0.0
# SEC_CONTRIBUTORY_CAUSE_CELL PHONE USE OTHER THAN TEXTING 0.0
# SEC_CONTRIBUTORY_CAUSE_BICYCLE ADVANCING LEGALLY ON RED LIGHT 0.0
# SEAT_NO_8 0.0
# SEAT_NO_7 0.0
# SEAT_NO_6 0.0
# SEAT_NO_4 0.0
# SEAT_NO_3 0.0
# SEAT_NO_12 0.0
# SEAT_NO_11 0.0
# SEAT_NO_10 0.0
# SEAT_NO_1 0.0
# SAFETY_EQUIPMENT_WHEELCHAIR 0.0
# SAFETY_EQUIPMENT_UNABLE TO DETERMINE 0.0
# SAFETY_EQUIPMENT_STRETCHER 0.0
# SAFETY_EQUIPMENT_CHILD RESTRAINT - TYPE UNKNOWN 0.0
# SAFETY_EQUIPMENT_CHILD RESTRAINT - REAR FACING 0.0
# SAFETY_EQUIPMENT_CHILD RESTRAINT - FORWARD FACING 0.0
# ROAD_DEFECT_SHOULDER DEFECT 0.0
# ROAD_DEFECT_RUT, HOLES 0.0
# ROAD_DEFECT_OTHER 0.0
# ROAD_DEFECT_DEBRIS ON ROADWAY 0.0
# ROADWAY_SURFACE_COND_SAND, MUD, DIRT 0.0
# ROADWAY_SURFACE_COND_OTHER 0.0
# ROADWAY_SURFACE_COND_ICE 0.0
# PRIM_CONTRIBUTORY_CAUSE_WEATHER 0.0
# PRIM_CONTRIBUTORY_CAUSE_TURNING RIGHT ON RED 0.0
# PRIM_CONTRIBUTORY_CAUSE_TEXTING 0.0
# PRIM_CONTRIBUTORY_CAUSE_ROAD ENGINEERING/SURFACE/MARKING DEFECTS 0.0
# PRIM_CONTRIBUTORY_CAUSE_ROAD CONSTRUCTION/MAINTENANCE 0.0
# PRIM_CONTRIBUTORY_CAUSE_RELATED TO BUS STOP 0.0
# PRIM_CONTRIBUTORY_CAUSE_PASSING STOPPED SCHOOL BUS 0.0
# PRIM_CONTRIBUTORY_CAUSE_OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER 0.0
# PRIM_CONTRIBUTORY_CAUSE_NOT APPLICABLE 0.0
# PRIM_CONTRIBUTORY_CAUSE_MOTORCYCLE ADVANCING LEGALLY ON RED LIGHT 0.0
# PRIM_CONTRIBUTORY_CAUSE_IMPROPER BACKING 0.0
# PRIM_CONTRIBUTORY_CAUSE_FOLLOWING TOO CLOSELY 0.0
# PRIM_CONTRIBUTORY_CAUSE_EXCEEDING SAFE SPEED FOR CONDITIONS 0.0
# PRIM_CONTRIBUTORY_CAUSE_EQUIPMENT - VEHICLE CONDITION 0.0
# PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.) 0.0
# PRIM_CONTRIBUTORY_CAUSE_DISTRACTION - FROM INSIDE VEHICLE 0.0
# PRIM_CONTRIBUTORY_CAUSE_DISREGARDING YIELD SIGN 0.0
# PRIM_CONTRIBUTORY_CAUSE_DISREGARDING ROAD MARKINGS 0.0
# PRIM_CONTRIBUTORY_CAUSE_CELL PHONE USE OTHER THAN TEXTING 0.0
# PRIM_CONTRIBUTORY_CAUSE_BICYCLE ADVANCING LEGALLY ON RED LIGHT 0.0
# PHYSICAL_CONDITION_OTHER 0.0
# PHYSICAL_CONDITION_MEDICATED 0.0
# PHYSICAL_CONDITION_IMPAIRED - DRUGS 0.0
# PHYSICAL_CONDITION_IMPAIRED - ALCOHOL AND DRUGS 0.0
# PHYSICAL_CONDITION_IMPAIRED - ALCOHOL 0.0
# PHYSICAL_CONDITION_ILLNESS/FAINTED 0.0
# PHYSICAL_CONDITION_HAD BEEN DRINKING 0.0
# PHYSICAL_CONDITION_FATIGUED/ASLEEP 0.0
# PEDPEDAL_ACTION_WORKING IN ROADWAY 0.0
# PEDPEDAL_ACTION_WITH TRAFFIC 0.0
# PEDPEDAL_ACTION_WAITING FOR SCHOOL BUS 0.0
# PEDPEDAL_ACTION_TURNING RIGHT 0.0
# PEDPEDAL_ACTION_STANDING IN ROADWAY 0.0
# PEDPEDAL_ACTION_PLAYING/WORKING ON VEHICLE 0.0
# PEDPEDAL_ACTION_PLAYING IN ROADWAY 0.0
# PEDPEDAL_ACTION_PARKED VEHICLE 0.0
# PEDPEDAL_ACTION_NOT AT INTERSECTION 0.0
# PEDPEDAL_ACTION_NO ACTION 0.0
# PEDPEDAL_ACTION_INTOXICATED PED/PEDAL 0.0
# PEDPEDAL_ACTION_CROSSING - NO CONTROLS (AT INTERSECTION) 0.0
# PEDPEDAL_ACTION_CROSSING - AGAINST SIGNAL 0.0
# NUM_PASSENGERS_9 0.0
# NUM_PASSENGERS_8 0.0
# NUM_PASSENGERS_7 0.0
# NUM_PASSENGERS_6 0.0
# NUM_PASSENGERS_5 0.0
# NUM_PASSENGERS_43 0.0
# NUM_PASSENGERS_4 0.0
# NUM_PASSENGERS_38 0.0
# NUM_PASSENGERS_32 0.0
# NUM_PASSENGERS_29 0.0
# NUM_PASSENGERS_2 0.0
# NUM_PASSENGERS_19 0.0
# NUM_PASSENGERS_16 0.0
# NUM_PASSENGERS_13 0.0
# NUM_PASSENGERS_12 0.0
# NUM_PASSENGERS_11 0.0
# MANEUVER_TURN 0.0
# MANEUVER_OTHER 0.0
# MANEUVER_LANE 0.0
# FIRST_CRASH_TYPE_TRAIN 0.0
# FIRST_CRASH_TYPE_SIDESWIPE OPPOSITE DIRECTION 0.0
# FIRST_CRASH_TYPE_REAR TO SIDE 0.0
# FIRST_CRASH_TYPE_REAR TO REAR 0.0
# FIRST_CRASH_TYPE_REAR TO FRONT 0.0
# FIRST_CRASH_TYPE_OVERTURNED 0.0
# FIRST_CRASH_TYPE_OTHER OBJECT 0.0
# FIRST_CRASH_TYPE_OTHER NONCOLLISION 0.0
# FIRST_CRASH_TYPE_ANIMAL 0.0
# FIRST_CONTACT_POINT_SIDE 0.0
# EXCEED_SPEED_LIMIT_I_Y 0.0
# EJECTION_TRAPPED/EXTRICATED 0.0
# EJECTION_PARTIALLY EJECTED 0.0
# DRIVER_VISION_WINDSHIELD (WATER/ICE) 0.0
# DRIVER_VISION_TREES, PLANTS 0.0
# DRIVER_VISION_SIGNBOARD 0.0
# DRIVER_VISION_PARKED VEHICLES 0.0
# DRIVER_VISION_NOT OBSCURED 0.0
# DRIVER_VISION_MOVING VEHICLES 0.0
# DRIVER_VISION_HILLCREST 0.0
# DRIVER_VISION_EMBANKMENT 0.0
# DRIVER_VISION_BUILDINGS 0.0
# DRIVER_VISION_BLOWING MATERIALS 0.0
# DRIVER_VISION_BLINDED - SUNLIGHT 0.0
# DRIVER_ACTION_WRONG WAY/SIDE 0.0
# DRIVER_ACTION_TOO FAST FOR CONDITIONS 0.0
# DRIVER_ACTION_TEXTING 0.0
# DRIVER_ACTION_STOPPED SCHOOL BUS 0.0
# DRIVER_ACTION_OVERCORRECTED 0.0
# DRIVER_ACTION_OTHER 0.0
# DRIVER_ACTION_LICENSE RESTRICTIONS 0.0
# DRIVER_ACTION_IMPROPER TURN 0.0
# DRIVER_ACTION_IMPROPER PASSING 0.0
# DRIVER_ACTION_IMPROPER PARKING 0.0
# DRIVER_ACTION_IMPROPER LANE CHANGE 0.0
# DRIVER_ACTION_FOLLOWED TOO CLOSELY 0.0
# DRIVER_ACTION_FAILED TO YIELD 0.0
# DRIVER_ACTION_EVADING POLICE VEHICLE 0.0
# DRIVER_ACTION_EMERGENCY VEHICLE ON CALL 0.0
# DEVICE_CONDITION_WORN REFLECTIVE MATERIAL 0.0
# DEVICE_CONDITION_OTHER 0.0
# DEVICE_CONDITION_NOT FUNCTIONING 0.0
# CELL_PHONE_USE_Y 0.0
# BAC_RESULT VALUE_0.3500 0.0
# BAC_RESULT VALUE_0.3200 0.0
# BAC_RESULT VALUE_0.3100 0.0
# BAC_RESULT VALUE_0.2800 0.0
# BAC_RESULT VALUE_0.2700 0.0
# BAC_RESULT VALUE_0.2500 0.0
# BAC_RESULT VALUE_0.2400 0.0
# BAC_RESULT VALUE_0.2300 0.0
# BAC_RESULT VALUE_0.2200 0.0
# BAC_RESULT VALUE_0.2100 0.0
# BAC_RESULT VALUE_0.2000 0.0
# BAC_RESULT VALUE_0.1900 0.0
# BAC_RESULT VALUE_0.1800 0.0
# BAC_RESULT VALUE_0.1700 0.0
# BAC_RESULT VALUE_0.1600 0.0
# BAC_RESULT VALUE_0.1500 0.0
# BAC_RESULT VALUE_0.1400 0.0
# BAC_RESULT VALUE_0.1300 0.0
# BAC_RESULT VALUE_0.1200 0.0
# BAC_RESULT VALUE_0.1100 0.0
# BAC_RESULT VALUE_0.1000 0.0
# BAC_RESULT VALUE_0.0700 0.0
# BAC_RESULT VALUE_0.0300 0.0
# BAC_RESULT VALUE_0.0200 0.0
# BAC_RESULT VALUE_0.0100 0.0
# BAC_RESULT VALUE_0.0000 0.0
# ALIGNMENT_STRAIGHT ON HILLCREST 0.0
# ALIGNMENT_CURVE, LEVEL 0.0
# ALIGNMENT_CURVE ON HILLCREST 0.0

# %%
feats = {} # a dict to hold feature_name: feature_importance
for feature, importance in zip(X_train.columns, dt_default.feature_importances_):
    feats[feature] = importance #add the name/value pair 

importances = pd.DataFrame.from_dict(feats, orient='index').rename(columns={0: 'Gini-importance'})
Gini_importance = importances.sort_values(by=['Gini-importance'], ascending=False)
Gini_importance[Gini_importance['Gini-importance'] > 0]
# Out:
#                                                     Gini-importance
# FIRST_CRASH_TYPE_PEDESTRIAN                                0.285207
# FIRST_CRASH_TYPE_PEDALCYCLIST                              0.101343
# NUM_UNITS                                                  0.076054
# INTERSECTION_RELATED_I_Y                                   0.062917
# AIRBAG_DEPLOYED_NOT APPLICABLE                             0.060102
# ...                                                             ...
# PEDPEDAL_ACTION_ENTER FROM DRIVE/ALLEY                     0.000288
# DRIVER_ACTION_NONE                                         0.000222
# PEDPEDAL_ACTION_OTHER ACTION                               0.000190
# SEC_CONTRIBUTORY_CAUSE_FAILING TO YIELD RIGHT-O...         0.000120
# ROAD_DEFECT_NO DEFECTS                                     0.000038
#
# [115 rows x 1 columns]

# %%
Gini_importance[Gini_importance['Gini-importance'].str.contains("PERSON_TYPE", case=False)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-177-d2c71a50e748> in <module>
# ----> 1 Gini_importance[Gini_importance['Gini-importance'].str.contains("PERSON_TYPE", case=False)]
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~/anaconda3/envs/vision_zero/lib/python3.8/site-packages/pandas/core/strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
# Importing required packages for visualization
from IPython.display import Image 
from io import StringIO
#from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
#import pydotplus

# Putting features
features = list(train_new_class.columns[1:])
features
# Out:
# ['TRAFFIC_CONTROL_DEVICE',
#  'DEVICE_CONDITION',
#  'WEATHER_CONDITION',
#  'LIGHTING_CONDITION',
#  'FIRST_CRASH_TYPE',
#  'TRAFFICWAY_TYPE',
#  'LANE_CNT',
#  'ALIGNMENT',
#  'ROADWAY_SURFACE_COND',
#  'ROAD_DEFECT',
#  'INTERSECTION_RELATED_I',
#  'NOT_RIGHT_OF_WAY_I',
#  'HIT_AND_RUN_I',
#  'PRIM_CONTRIBUTORY_CAUSE',
#  'SEC_CONTRIBUTORY_CAUSE',
#  'STREET_DIRECTION',
#  'DOORING_I',
#  'WORK_ZONE_I',
#  'NUM_UNITS',
#  'NUM_PASSENGERS',
#  'VEHICLE_DEFECT',
#  'VEHICLE_TYPE',
#  'VEHICLE_USE',
#  'TRAVEL_DIRECTION',
#  'MANEUVER',
#  'OCCUPANT_CNT',
#  'EXCEED_SPEED_LIMIT_I',
#  'FIRST_CONTACT_POINT',
#  'SEAT_NO',
#  'SEX',
#  'AGE',
#  'SAFETY_EQUIPMENT',
#  'AIRBAG_DEPLOYED',
#  'EJECTION',
#  'DRIVER_ACTION',
#  'DRIVER_VISION',
#  'PHYSICAL_CONDITION',
#  'PEDPEDAL_ACTION',
#  'BAC_RESULT VALUE',
#  'CELL_PHONE_USE',
#  'INJURY',
#  'Location',
#  'VEHICLE_AGE']

# %%
fn = X_train.columns.tolist()
cn = ['Injuries', 'No-Injuries']
plt.figure(figsize=(25,10))
tree_visual = tree.plot_tree(dt_default,
               feature_names = fn, 
               class_names = cn,
               max_depth = 2,
               fontsize = 18,
               rounded = True,
               filled = True)

# %% [markdown]
# ## Logistic Regression model

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression(random_state = 0)
scores = cross_val_score(LR, X_train, y_train, cv=5)
print('Accuracy', np.mean(scores), scores)
# Out:
# Accuracy 0.9003875308810064 [0.90199035 0.89889928 0.89904245 0.90130438 0.9007012 ]

# %%
recall = cross_val_score(LR, X_train, y_train, cv=5, scoring='recall')
print('Recall', np.mean(recall), recall)
precision = cross_val_score(LR, X_train, y_train, cv=5, scoring='precision')
print('Precision', np.mean(precision), precision)
f1 = cross_val_score(LR, X_train, y_train, cv=5, scoring='f1')
print('F1', np.mean(f1), f1)
# Out:
# Recall 0.9794071941572555 [0.97711944 0.98010757 0.97805857 0.97942457 0.98232582]
# Precision 0.9139623731965554 [0.91728781 0.91197966 0.91370234 0.91483254 0.91200951]
# F1 0.9455503139477115 [0.94625878 0.94481709 0.94478578 0.9460273  0.94586262]

# %%
#Train the model using the training sets y_pred=clf.predict(X_test)
scores = cross_val_score(LR, X_train, y_train, cv=5)
print('Accuracy', np.mean(scores), scores)
# Out:
# Accuracy 0.9003875308810064 [0.90199035 0.89889928 0.89904245 0.90130438 0.9007012 ]

# %%
LR.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
print(LR.coef_)
# Out:
# [[-2.87834944e-02  3.35846114e-02 -6.18532978e-01  3.44888578e-02
#   -2.85612423e-03 -1.93260417e-02  1.61498816e-01  2.84186008e-02
#   -5.98714288e-03  5.92526298e-02  4.65991557e-02  7.49401934e-02
#    1.39913073e-02 -1.02479946e-02  2.25483044e-02 -3.10905280e-02
#    7.66063916e-03  1.82936514e-02  7.12110183e-02  8.12396760e-02
#    5.49887548e-03 -1.84144835e-03  2.11719762e-01 -1.73398801e-01
#    1.37120367e-01  1.85634253e-02  1.07559401e-01  2.64610433e-02
#   -3.06833983e-01 -5.90918199e-01 -7.81859725e-02 -5.05883394e-02
#   -2.37519156e-02  1.61466900e+00 -1.49599420e+00 -2.64661752e+00
#    8.42853060e-01  9.20420188e-02  4.32534586e-02  1.07822377e-01
#    1.66051298e-01  1.26200456e+00  3.21624585e-03  5.59868128e-01
#    5.32700796e-02 -1.74066897e-01 -1.94404556e-01 -5.65757442e-02
#   -7.08899004e-04 -3.09222126e-01 -7.13206643e-03 -1.16892915e-02
#    3.13794644e-02  1.42356186e-01  2.33045664e-01  6.30514395e-01
#    7.16123024e-02  5.06209099e-04 -1.39311723e-01 -9.44616158e-03
#   -3.90777976e-02 -3.28085206e-02  3.87276883e-03  5.95921777e-02
#    2.13158604e-01  8.83445150e-02  8.11004739e-02 -4.35780527e-02
#    4.92199597e-01 -3.56037800e-02  2.86842570e-03  2.40646906e-01
#   -1.20153887e-02  8.02400221e-03 -2.56151507e-01 -1.09750106e-01
#    1.99675870e-01  3.22359397e-03  6.31647312e-02 -2.01942299e-01
#    1.51071429e-01  2.02566880e-01  3.54973193e-03  1.52648049e-02
#   -1.01771398e-01  1.16804915e-02  1.84934584e-02 -2.60625813e-01
#   -3.04219610e-02 -6.82964774e-02 -1.07906364e-01  1.61492856e-02
#   -1.51757720e-01  2.23103388e-01  7.62980800e-02 -4.57057233e-02
#   -2.45414785e-01 -3.13016439e-02 -5.64656877e-01  7.16281128e-02
#    3.33259000e-01 -1.94314848e-02  6.70111686e-01  2.19024726e-01
#    3.91467129e-01  2.50742392e-01 -2.00936612e-02  2.59011039e-01
#   -1.73415849e-01  8.56891462e-03 -5.74816059e-01 -2.59100219e-02
#    1.25461736e-02  4.94471714e-02  2.78050688e-02  3.12241426e-02
#    3.04842758e-01 -2.15212344e-01 -8.50642290e-03  7.91127629e-02
#    1.33657694e-02 -1.44107135e-02 -2.92885247e-02 -9.87561471e-02
#   -1.38507348e-02 -5.27269177e-02 -4.87605308e-02 -9.68574925e-02
#    1.30085125e-02  2.10793763e-02 -1.73659206e-01  1.36816005e-01
#    7.13324894e-02  3.35199774e-02 -1.46926324e-01  8.65607181e-02
#   -1.58435971e-01  1.92361982e-01  2.64853347e-01 -6.22399260e-03
#    1.25056777e-01  1.91712124e-01  7.90332583e-02  7.54144130e-02
#    6.64512050e-03  5.20720062e-02 -2.04357503e-03 -2.33722808e-01
#    2.42397156e-03 -9.50236927e-03  1.24111580e-02  2.60746633e-02
#    2.39998537e-02 -6.07239196e-03 -1.15062219e-02  8.86129179e-02
#   -1.63763777e-02 -5.43767679e-02  3.53705699e-02  2.20277261e-01
#    7.90747754e-02  1.69628124e-01 -2.63700002e-01 -2.24594191e-02
#   -5.27166620e-01 -3.97533331e-02  2.43904611e-03  6.45396847e-03
#    6.26074366e-03  1.66379268e-02  1.51150071e-02 -7.48025505e-01
#    1.90156491e-02 -6.87057299e-01  1.60169104e-02  1.54385292e-02
#   -3.92750957e-01  9.93629064e-02 -1.55670723e-01 -8.29303188e-02
#    6.04493128e-04  1.78398078e-02  2.07780621e-02  7.48274165e-04
#    8.72752525e-03  3.09203666e-03  1.83651180e-03  1.58828367e-01
#    1.12356640e-01  2.41703997e-03  1.95055807e-03 -6.37432098e-03
#    7.54112396e-04 -1.57565841e-02 -3.51105573e-03  3.58759173e-03
#   -1.35337117e-03 -3.84889100e-02 -1.82788967e-02  2.32639223e-02
#    2.64302746e-02 -2.02222591e-03 -5.33034666e-02 -4.77035939e-02
#   -3.20071913e-01  1.84423748e-01  1.12442561e-02  1.43269912e-01
#    1.50076071e-02  3.03363443e-02  4.11083881e-04  1.19460665e-01
#    5.70774630e-02 -3.71325929e-04  1.61109764e-01  8.47142423e-02
#    1.38576105e-02  4.28697430e-04  9.45497209e-04  4.45742894e-02
#    5.16319975e-02  1.58231107e-02 -1.49942254e-01 -1.26296253e-02
#    4.45313391e-02  1.34604281e-02 -3.38242047e-02  1.00318730e-03
#    8.78190830e-02  1.06124820e-01 -2.16711043e-02  1.59040881e-02
#   -2.02470664e-01 -8.83904072e-02  1.80313420e-01 -1.15539901e-02
#    3.02680626e-02  1.97987206e-02  2.75121031e-01  1.58237296e-01
#    4.48859683e-02  2.48386693e-03  4.44050276e-02 -8.23890787e-02
#   -9.45216643e-02  5.22875372e-02  2.94323047e-01 -1.29452557e-01
#   -1.07292737e-01 -2.67864785e-01 -1.70839806e-01  7.61133552e-03
#   -4.84777821e-02  2.29061989e-01  1.76787376e-02 -6.69299512e-02
#   -1.03754614e-01 -1.19832205e-01 -1.08244346e-01  4.12305781e-02
#   -2.20394901e-01 -2.22177522e-01 -2.91089175e-01  6.39768762e-02
#   -3.68281964e-02  6.11637315e-02  4.91033255e-01  3.65123616e-01
#    4.18495947e-02  2.01845020e-02 -5.32054267e-02  1.00119250e-02
#   -5.00866517e-03  6.65232294e-02  2.86803321e-01  6.91781690e-03
#    1.50224076e+00  1.60677701e+00  1.02182345e+00 -3.05129227e-02
#   -2.99973865e-01 -6.98311228e-02  7.01863654e-02 -4.68433769e-02
#   -6.04190522e-02 -5.07738462e-02 -7.42882866e-02  2.68029778e-01
#    2.58364352e-01  1.29598376e-01  3.85320513e-02  8.15855175e-02
#    6.43383834e-02 -2.21089516e-03 -1.72971872e-02 -1.19654072e-01
#    2.97836162e-03  1.91059711e-03  1.38155287e-02 -8.15284201e-02
#   -5.37681737e-02 -3.58967623e-02  2.88345281e-04  1.06527838e-02
#    1.00333821e-03  3.16410423e-03 -2.94523794e-02  2.09754505e-01
#    1.18662813e-01  1.11206351e-02  1.74859870e-03  8.94214785e-03
#    7.71035282e-02 -3.21190392e-03 -1.09517144e-02 -1.29263537e-01
#   -3.29365438e-02  1.83676202e-02  1.07239713e-02 -5.98817174e-03
#    5.37798349e-01 -4.41249340e-02 -5.29845621e-01  6.54821561e-01
#    3.60557965e-02 -1.94324114e-02 -3.74750401e-02  1.29242150e-02
#   -2.64564337e-02 -9.95197827e-03  1.40896863e-03 -6.46679476e-02
#   -3.44293281e-02 -4.88489509e-02 -3.34191473e-02 -7.17400643e-03
#    1.85123715e-05 -4.57158589e-03 -1.33523811e-02  3.83019193e-03
#    6.82583254e-01  4.30708324e-03 -8.70540028e-02  2.83854654e-03
#   -3.72266787e-02  6.63933741e-04  1.17947141e-03  2.60195789e-03
#    7.33002149e-04 -3.22050765e-04  2.59617897e-03 -3.31317267e-03
#    5.45203098e-03  9.52458609e-03  6.18503535e-03 -4.07210216e-03
#   -3.22707228e-03 -1.13880803e-02 -5.32978372e-03  2.99247939e-03
#    1.34224891e-02 -3.61037310e-03  4.50947810e-03 -9.87961915e-03
#   -1.06599133e-03 -4.58430190e-03 -2.10515647e-04 -2.39028940e-03
#   -1.21869714e-02  7.51889931e-04  3.74645940e-01 -3.23286035e-03
#   -1.45171617e-01]]

# %%
X_train.columns
# Out:
# Index(['POSTED_SPEED_LIMIT', 'LANE_CNT', 'NUM_UNITS', 'OCCUPANT_CNT', 'AGE',
#        'VEHICLE_AGE', 'TRAFFIC_CONTROL_DEVICE_SIGN',
#        'DEVICE_CONDITION_FUNCTIONING PROPERLY', 'DEVICE_CONDITION_MISSING',
#        'DEVICE_CONDITION_NO CONTROLS',
#        ...
#        'BAC_RESULT VALUE_0.2400', 'BAC_RESULT VALUE_0.2500',
#        'BAC_RESULT VALUE_0.2700', 'BAC_RESULT VALUE_0.2800',
#        'BAC_RESULT VALUE_0.3100', 'BAC_RESULT VALUE_0.3200',
#        'BAC_RESULT VALUE_0.3500', 'CELL_PHONE_USE_UNABLE TO DETERMINE',
#        'CELL_PHONE_USE_Y', 'Location_Not Downtown'],
#       dtype='object', length=373)

# %%
# list = np.round(LR.coef_, decimals=2) >0
#plot graph of feature importances for better visualization
# feat_importance = pd.Series(LR.coef_, index=X_train.columns)
# feat_importance.nlargest(20).plot(kind='barh')
# plt.title("Feature Importance")
# plt.show()

for importance, name in sorted(zip(LR.coef_, X_train.columns),reverse=True)[:]:
    print (name, importance)
# Out:
# POSTED_SPEED_LIMIT [-2.87834944e-02  3.35846114e-02 -6.18532978e-01  3.44888578e-02
#  -2.85612423e-03 -1.93260417e-02  1.61498816e-01  2.84186008e-02
#  -5.98714288e-03  5.92526298e-02  4.65991557e-02  7.49401934e-02
#   1.39913073e-02 -1.02479946e-02  2.25483044e-02 -3.10905280e-02
#   7.66063916e-03  1.82936514e-02  7.12110183e-02  8.12396760e-02
#   5.49887548e-03 -1.84144835e-03  2.11719762e-01 -1.73398801e-01
#   1.37120367e-01  1.85634253e-02  1.07559401e-01  2.64610433e-02
#  -3.06833983e-01 -5.90918199e-01 -7.81859725e-02 -5.05883394e-02
#  -2.37519156e-02  1.61466900e+00 -1.49599420e+00 -2.64661752e+00
#   8.42853060e-01  9.20420188e-02  4.32534586e-02  1.07822377e-01
#   1.66051298e-01  1.26200456e+00  3.21624585e-03  5.59868128e-01
#   5.32700796e-02 -1.74066897e-01 -1.94404556e-01 -5.65757442e-02
#  -7.08899004e-04 -3.09222126e-01 -7.13206643e-03 -1.16892915e-02
#   3.13794644e-02  1.42356186e-01  2.33045664e-01  6.30514395e-01
#   7.16123024e-02  5.06209099e-04 -1.39311723e-01 -9.44616158e-03
#  -3.90777976e-02 -3.28085206e-02  3.87276883e-03  5.95921777e-02
#   2.13158604e-01  8.83445150e-02  8.11004739e-02 -4.35780527e-02
#   4.92199597e-01 -3.56037800e-02  2.86842570e-03  2.40646906e-01
#  -1.20153887e-02  8.02400221e-03 -2.56151507e-01 -1.09750106e-01
#   1.99675870e-01  3.22359397e-03  6.31647312e-02 -2.01942299e-01
#   1.51071429e-01  2.02566880e-01  3.54973193e-03  1.52648049e-02
#  -1.01771398e-01  1.16804915e-02  1.84934584e-02 -2.60625813e-01
#  -3.04219610e-02 -6.82964774e-02 -1.07906364e-01  1.61492856e-02
#  -1.51757720e-01  2.23103388e-01  7.62980800e-02 -4.57057233e-02
#  -2.45414785e-01 -3.13016439e-02 -5.64656877e-01  7.16281128e-02
#   3.33259000e-01 -1.94314848e-02  6.70111686e-01  2.19024726e-01
#   3.91467129e-01  2.50742392e-01 -2.00936612e-02  2.59011039e-01
#  -1.73415849e-01  8.56891462e-03 -5.74816059e-01 -2.59100219e-02
#   1.25461736e-02  4.94471714e-02  2.78050688e-02  3.12241426e-02
#   3.04842758e-01 -2.15212344e-01 -8.50642290e-03  7.91127629e-02
#   1.33657694e-02 -1.44107135e-02 -2.92885247e-02 -9.87561471e-02
#  -1.38507348e-02 -5.27269177e-02 -4.87605308e-02 -9.68574925e-02
#   1.30085125e-02  2.10793763e-02 -1.73659206e-01  1.36816005e-01
#   7.13324894e-02  3.35199774e-02 -1.46926324e-01  8.65607181e-02
#  -1.58435971e-01  1.92361982e-01  2.64853347e-01 -6.22399260e-03
#   1.25056777e-01  1.91712124e-01  7.90332583e-02  7.54144130e-02
#   6.64512050e-03  5.20720062e-02 -2.04357503e-03 -2.33722808e-01
#   2.42397156e-03 -9.50236927e-03  1.24111580e-02  2.60746633e-02
#   2.39998537e-02 -6.07239196e-03 -1.15062219e-02  8.86129179e-02
#  -1.63763777e-02 -5.43767679e-02  3.53705699e-02  2.20277261e-01
#   7.90747754e-02  1.69628124e-01 -2.63700002e-01 -2.24594191e-02
#  -5.27166620e-01 -3.97533331e-02  2.43904611e-03  6.45396847e-03
#   6.26074366e-03  1.66379268e-02  1.51150071e-02 -7.48025505e-01
#   1.90156491e-02 -6.87057299e-01  1.60169104e-02  1.54385292e-02
#  -3.92750957e-01  9.93629064e-02 -1.55670723e-01 -8.29303188e-02
#   6.04493128e-04  1.78398078e-02  2.07780621e-02  7.48274165e-04
#   8.72752525e-03  3.09203666e-03  1.83651180e-03  1.58828367e-01
#   1.12356640e-01  2.41703997e-03  1.95055807e-03 -6.37432098e-03
#   7.54112396e-04 -1.57565841e-02 -3.51105573e-03  3.58759173e-03
#  -1.35337117e-03 -3.84889100e-02 -1.82788967e-02  2.32639223e-02
#   2.64302746e-02 -2.02222591e-03 -5.33034666e-02 -4.77035939e-02
#  -3.20071913e-01  1.84423748e-01  1.12442561e-02  1.43269912e-01
#   1.50076071e-02  3.03363443e-02  4.11083881e-04  1.19460665e-01
#   5.70774630e-02 -3.71325929e-04  1.61109764e-01  8.47142423e-02
#   1.38576105e-02  4.28697430e-04  9.45497209e-04  4.45742894e-02
#   5.16319975e-02  1.58231107e-02 -1.49942254e-01 -1.26296253e-02
#   4.45313391e-02  1.34604281e-02 -3.38242047e-02  1.00318730e-03
#   8.78190830e-02  1.06124820e-01 -2.16711043e-02  1.59040881e-02
#  -2.02470664e-01 -8.83904072e-02  1.80313420e-01 -1.15539901e-02
#   3.02680626e-02  1.97987206e-02  2.75121031e-01  1.58237296e-01
#   4.48859683e-02  2.48386693e-03  4.44050276e-02 -8.23890787e-02
#  -9.45216643e-02  5.22875372e-02  2.94323047e-01 -1.29452557e-01
#  -1.07292737e-01 -2.67864785e-01 -1.70839806e-01  7.61133552e-03
#  -4.84777821e-02  2.29061989e-01  1.76787376e-02 -6.69299512e-02
#  -1.03754614e-01 -1.19832205e-01 -1.08244346e-01  4.12305781e-02
#  -2.20394901e-01 -2.22177522e-01 -2.91089175e-01  6.39768762e-02
#  -3.68281964e-02  6.11637315e-02  4.91033255e-01  3.65123616e-01
#   4.18495947e-02  2.01845020e-02 -5.32054267e-02  1.00119250e-02
#  -5.00866517e-03  6.65232294e-02  2.86803321e-01  6.91781690e-03
#   1.50224076e+00  1.60677701e+00  1.02182345e+00 -3.05129227e-02
#  -2.99973865e-01 -6.98311228e-02  7.01863654e-02 -4.68433769e-02
#  -6.04190522e-02 -5.07738462e-02 -7.42882866e-02  2.68029778e-01
#   2.58364352e-01  1.29598376e-01  3.85320513e-02  8.15855175e-02
#   6.43383834e-02 -2.21089516e-03 -1.72971872e-02 -1.19654072e-01
#   2.97836162e-03  1.91059711e-03  1.38155287e-02 -8.15284201e-02
#  -5.37681737e-02 -3.58967623e-02  2.88345281e-04  1.06527838e-02
#   1.00333821e-03  3.16410423e-03 -2.94523794e-02  2.09754505e-01
#   1.18662813e-01  1.11206351e-02  1.74859870e-03  8.94214785e-03
#   7.71035282e-02 -3.21190392e-03 -1.09517144e-02 -1.29263537e-01
#  -3.29365438e-02  1.83676202e-02  1.07239713e-02 -5.98817174e-03
#   5.37798349e-01 -4.41249340e-02 -5.29845621e-01  6.54821561e-01
#   3.60557965e-02 -1.94324114e-02 -3.74750401e-02  1.29242150e-02
#  -2.64564337e-02 -9.95197827e-03  1.40896863e-03 -6.46679476e-02
#  -3.44293281e-02 -4.88489509e-02 -3.34191473e-02 -7.17400643e-03
#   1.85123715e-05 -4.57158589e-03 -1.33523811e-02  3.83019193e-03
#   6.82583254e-01  4.30708324e-03 -8.70540028e-02  2.83854654e-03
#  -3.72266787e-02  6.63933741e-04  1.17947141e-03  2.60195789e-03
#   7.33002149e-04 -3.22050765e-04  2.59617897e-03 -3.31317267e-03
#   5.45203098e-03  9.52458609e-03  6.18503535e-03 -4.07210216e-03
#  -3.22707228e-03 -1.13880803e-02 -5.32978372e-03  2.99247939e-03
#   1.34224891e-02 -3.61037310e-03  4.50947810e-03 -9.87961915e-03
#  -1.06599133e-03 -4.58430190e-03 -2.10515647e-04 -2.39028940e-03
#  -1.21869714e-02  7.51889931e-04  3.74645940e-01 -3.23286035e-03
#  -1.45171617e-01]

# %%
from sklearn.feature_selection import SelectFromModel
smf = SelectFromModel(LR, threshold=-np.inf, max_features=8)
smf.fit(X_train,y_train)
feature_idx=smf.get_support()
feature_name=features.columns[feature_idx]
feature_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-c9752f4245ee> in <module>
#       3 smf.fit(X_train,y_train)
#       4 feature_idx=smf.get_support()
# ----> 5 feature_name=features.columns[feature_idx]
#       6 feature_name
#
# AttributeError: 'list' object has no attribute 'columns'

# %% [markdown]
# ## Random Forest -Classifier (All Post-Crash Categories)

# %%
#Create a Random Forest Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
scores = cross_val_score(clf, X_train, y_train, cv=5)
print('Accuracy', np.mean(scores), scores)

# %%
recall = cross_val_score(clf, X_train, y_train, cv=5, scoring='recall')
print('Recall', np.mean(recall), recall)
precision = cross_val_score(clf, X_train, y_train, cv=5, scoring='precision')
print('Precision', np.mean(precision), precision)
f1 = cross_val_score(clf, X_train, y_train, cv=5, scoring='f1')
print('F1', np.mean(f1), f1)

# %%
#Create a Random Forest Classifier
clf=RandomForestClassifier(n_estimators=100)
clf.fit(X_train,y_train)
print(clf.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(clf.feature_importances_, index=X_train.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
feat_importances.nlargest(50)

# %% [markdown]
# ## Random Forest - Regressor (All Post-Crash Categories)

# %%
# removing below columns
drop_list=["LATITUDE","LONGITUDE","INJURY","CRASH_DATE"]

train_new_reg = train.drop(drop_list, axis=1)

# %%
# splitting the dataset into x_train and y_train
X_train = train_new_reg.drop(["INJURIES_TOTAL"],axis=1)
y_train = train_new_reg["INJURIES_TOTAL"]

# %%
#X_train.info()

# %%
# performing one hot encoding on all the object features
X_train = pd.get_dummies(X_train, columns=X_train.select_dtypes(['object']).columns, drop_first=True)

# %%
X_train.head()

# %%
#Create a Random Forest Classifier
#clf=RandomForestRegressor()

#Train the model using the training sets y_pred=clf.predict(X_test)
#scores = cross_val_score(clf, X_train, y_train, cv=5)
#print('mean_squared_error', np.mean(scores), scores)

# %%
#Create a Random Forest Classifier
clf=RandomForestRegressor()
clf.fit(X_train,y_train)
print(clf.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(clf.feature_importances_, index=X_train.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
feat_importances.nlargest(50)

# %% [markdown]
# ## Decision Tree

# %% [markdown]
# Filtering out the most important variables identified by Random Forest

# %%
train["POSTED_SPEED_LIMIT"]=pd.to_numeric(train["POSTED_SPEED_LIMIT"])

# %%
filter_list=["FIRST_CRASH_TYPE","AGE","AIRBAG_DEPLOYED","INTERSECTION_RELATED_I","LANE_CNT","SEX",
             "TRAFFICWAY_TYPE","POSTED_SPEED_LIMIT","CRASH_HOUR","VEHICLE_YEAR","FIRST_CRASH_TYPE","INJURY"]

train_new = train[filter_list]

# %%
#train_new["FIRST_CRASH_TYPE"].unique

# %%
# splitting the dataset into x_train and y_train
X_train = train_new.drop(["INJURY"],axis=1)
y_train = train_new["INJURY"]

# %%
# performing one hot encoding on all the object features
X_train = pd.get_dummies(X_train, columns=X_train.select_dtypes(['object']).columns, drop_first=True)

# %%
X_train

# %%
#Encode the y_train labels
lb = preprocessing.LabelBinarizer()
y_train=lb.fit_transform(y_train)

# %%
# Importing decision tree classifier from sklearn library
from sklearn.tree import DecisionTreeClassifier

# Fitting the decision tree with default hyperparameters, apart from
# max_depth which is 5 so that we can plot and read the tree.
dt_default = DecisionTreeClassifier(max_depth=10)

# %%
recall = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='recall')
print('Recall', np.mean(recall), recall)
precision = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='precision')
print('Precision', np.mean(precision), precision)
f1 = cross_val_score(dt_default, X_train, y_train, cv=5, scoring='f1')
print('F1', np.mean(f1), f1)

# %% [markdown]
# ### Graphviz
#
# Python requires library pydot and an external software graphviz to visualize the decision tree. If you are on wondows, you'll need to specify the path for the pydot library to access dot file from graphviz.
#
# Please read the downloadable instructions to install graphviz. For Mac users, one way is to:
#
# Install the python graphviz module: pip install graphviz
# Then install the Graphviz software on Mac, you do this using homebrew:
# Install homebrew: https://docs.brew.sh/Installation
# brew install graphviz

# %%
# Importing required packages for visualization
from IPython.display import Image 
from io import StringIO
#from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
#import pydotplus

# Putting features
features = list(train_new.columns[1:])
features

# %%
# dt_default.fit(X_train,y_train)
# export_graphviz(dt_default,
#                      out_file="tree.dot",
#                      filled=True,rounded=True)
