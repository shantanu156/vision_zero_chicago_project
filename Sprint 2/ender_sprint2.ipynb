# %% [markdown]
# # Ground Zero

# %% [markdown]
# ## Packages and Datasets

# %%
import timeit
start_time = timeit.default_timer()  #timestamp to calculate total runtime

import pandas as pd
import numpy as np

import researchpy as rp
import missingno as msno

import seaborn as sns
import matplotlib.pyplot as plt

import itertools
import scipy.stats as ss

import folium
from folium import plugins

from sklearn.model_selection import train_test_split
from sklearn import feature_selection
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline
pd.set_option('display.max_columns', None)  # prevent column output trancation
sns.set()  # change plot styling from Matlab's 90s feel to today's Seaborn.

# %%
# File Directories
path_crashes = '~/repos/vision_zero_chicago_project/crashes.sample2020.csv'
path_vehicles = '~/repos/vision_zero_chicago_project/vehicles.sample.csv'
path_people = '~/repos/vision_zero_chicago_project/people.sample.csv'

# Columns that will be read as categorical
# The fromkeys() method returns a dictionary with the specified keys and the specified value
#categoricals_crashes = dict.fromkeys(
#    [5, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 17, 18, 19, 20, 22, 23, 35],
#    'category')
#categoricals_vehicles = dict.fromkeys([5, 9, 10, 11, 13, 14, 15, 16, 17, 38],
#                                      'category')
#categoricals_people = dict.fromkeys(
#    [7, 8, 10, 12, 13, 14, 15, 17, 21, 22, 23, 27], 'category')

# Import samples
crashes = pd.read_csv(
    path_crashes,
    parse_dates=["CRASH_DATE", "CRASH_DATE_EST_I", "DATE_POLICE_NOTIFIED"],
    low_memory=False,
    dtype=object)

vehicles = pd.read_csv(path_vehicles,
                       parse_dates=["CRASH_DATE"],
                       low_memory=False,
                       dtype=object)

people = pd.read_csv(path_people,
                     parse_dates=["CRASH_DATE"],
                     low_memory=False,
                     dtype=object)

# %% [markdown]
# ## Our Understanding

# %% [markdown]
# ### Feature Engineering Process
#
# [Source](https://en.wikipedia.org/wiki/Feature_engineering)
#
# The feature engineering process is:
# - Brainstorming or testing features;
# - Deciding what features to create;
# - Creating features;
# - Checking how the features work with your model;
# - **Improving your features if needed;**
# - Go back to brainstorming/creating more features until the work is done.

# %% [markdown]
# ### Some Terms
#
# [Source](https://datascience.stackexchange.com/questions/29006/feature-selection-vs-feature-extraction-which-to-use-when)
#
# **Feature Extraction and Feature Engineering:** transformation of raw data into features suitable for modeling;
#
# - Texts(ngrams, word2vec, tf-idf etc)
# - Geospatial data(lat, long)
# - Date and time(day, month, week, year, rolling based)
# - Time series, web, etc
# - Dimensional Reduction Techniques (PCA, SVD, Eigen-Faces etc)
# - Clustering (DBSCAN etc)
# - And others.
#
# ---
#
# **Feature / Data Transformation:** transformation of data to improve the accuracy of the algorithm;
# - Normalization and changing distribution(Scaling)
# - Interactions
# - Handling missing Values
# - Handling outliers
# - Handling time-date / mixed variables
# - Encoding categorical features
# - Variable types
# - And others.
#
# ---
#
# **Feature Selection:** removing unnecessary features.
#
# - Statistical approaches
# - Selection by modeling
# - Grid search
# - Cross Validation
# - And others
#
# ---
#
# For the purpose of workflow, we will split **Feature Selection** into;
# - **feature reduction** to remove unnecessary features,
# - and **feature selection** to select features by their importance scores through ML/statistical techniques.

# %% [markdown]
# # Data Merge & Split

# %% [markdown]
# ## Merging datasets
#
# The goal is to successfully merge all datasets by increasing crash records as little as possible.

# %%
print(crashes.shape)
print(vehicles.shape)
print(people.shape)
# Out:
# (33408, 49)
# (75673, 72)
# (82049, 30)

# %% [markdown]
# **Data Merge Strategy**
#
# - Filter out passengers from **`people`**, and left-join it to **`vehicles`** on `CRASH_RECORD_ID`, `RD_NO`, `CRASH_DATE`, `VEHICLE_ID`.
#
# - Then inner-join this dataset to **`crashes`** on `CRASH_RECORD_ID`, `RD_NO`, `CRASH_DATE`.
#
# ---
#
# **Reasoning**
#
# - `people` has **many-to-one relationship** with `vehicles` but a pedestrian in `vehicles` has **one-to-one** with `people`,
#
# - Passengers don't have <u>a trajectory separate from the unit</u> they belong to and they don't contribute to accidents with their existence but they are involved if they got harmed through `injuries` features,
#
# - This method increases `crashes` records **only per active parties involved**.

# %%
# Filter only non-pessenger people (drivers, pedestrian, cyclist, etc.)
non_passengers = people[people.PERSON_ID.str.contains('^O')]

# %%
# Left join non-peseenger people with vehicles
vehicles_with_people = vehicles.merge(non_passengers, 
                                      how='left', 
                                      on=['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE', 'VEHICLE_ID'])
vehicles_with_people.head()
# Out:
#   CRASH_UNIT_ID                                    CRASH_RECORD_ID     RD_NO  \
# 0        228894  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 1        228895  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 2        228896  2524b06fc6634bd349fc1d7f132c8362529473768f6ac2...  JA453603
# 3        228905  f7210aec9ac43a7b36c30b49033adebcb3060b96580341...  JA453640
# 4        228906  f7210aec9ac43a7b36c30b49033adebcb3060b96580341...  JA453640
#
#            CRASH_DATE UNIT_NO   UNIT_TYPE NUM_PASSENGERS VEHICLE_ID  \
# 0 2017-10-01 02:20:00       1      DRIVER            NaN     224185
# 1 2017-10-01 02:20:00       2      PARKED            NaN     224187
# 2 2017-10-01 02:20:00       3      PARKED            NaN     224191
# 3 2017-10-01 02:41:00       1      DRIVER            NaN     224199
# 4 2017-10-01 02:41:00       2  DRIVERLESS            NaN     224203
#
#   CMRC_VEH_I                  MAKE     MODEL LIC_PLATE_STATE VEHICLE_YEAR  \
# 0        NaN                 DODGE   CHARGER              IL         2012
# 1        NaN  GENERAL MOTORS CORP.     YUKON              IL         2003
# 2        NaN                SATURN   UNKNOWN              IL         2000
# 3        NaN                  FORD  WINDSTAR              IL         2007
# 4        NaN             CHEVROLET     CRUZE              IL         2012
#
#   VEHICLE_DEFECT  VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION        MANEUVER  \
# 0        UNKNOWN     PASSENGER    PERSONAL                N  STRAIGHT AHEAD
# 1        UNKNOWN     PASSENGER    PERSONAL                N          PARKED
# 2        UNKNOWN     PASSENGER    PERSONAL                N          PARKED
# 3           NONE  VAN/MINI-VAN    PERSONAL                E  STRAIGHT AHEAD
# 4           NONE     PASSENGER  NOT IN USE          UNKNOWN          PARKED
#
#   TOWED_I FIRE_I OCCUPANT_CNT EXCEED_SPEED_LIMIT_I     TOWED_BY TOWED_TO  \
# 0       Y    NaN            1                  NaN  PRIVATE TOW  UNKNOWN
# 1       Y    NaN            0                  NaN  PRIVATE TOW  UNKNOWN
# 2     NaN    NaN            0                  NaN          NaN      NaN
# 3       Y    NaN            1                  NaN          NaN      NaN
# 4       Y    NaN            0                  NaN          NaN      NaN
#
#   AREA_00_I AREA_01_I AREA_02_I AREA_03_I AREA_04_I AREA_05_I AREA_06_I  \
# 0       NaN         Y         Y       NaN       NaN       NaN       NaN
# 1         N       NaN       NaN       NaN       NaN       NaN         Y
# 2       NaN       NaN         Y         Y         Y       NaN       NaN
# 3       NaN         Y         Y         Y         Y       NaN         N
# 4       NaN         Y         Y       NaN       NaN       NaN         Y
#
#   AREA_07_I AREA_08_I AREA_09_I AREA_10_I AREA_11_I AREA_12_I AREA_99_I  \
# 0       NaN         Y       NaN       NaN       NaN       NaN       NaN
# 1         Y         Y       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3         N         N       NaN       NaN         Y       NaN       NaN
# 4         Y         Y       NaN       NaN         Y       NaN       NaN
#
#   FIRST_CONTACT_POINT CMV_ID USDOT_NO CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR  \
# 0               FRONT    NaN      NaN     NaN     NaN            NaN  NaN
# 1           REAR-LEFT    NaN      NaN     NaN     NaN            NaN  NaN
# 2          REAR-RIGHT    NaN      NaN     NaN     NaN            NaN  NaN
# 3   TOTAL (ALL AREAS)    NaN      NaN     NaN     NaN            NaN  NaN
# 4           REAR-LEFT    NaN      NaN     NaN     NaN            NaN  NaN
#
#   CARRIER_NAME CARRIER_STATE CARRIER_CITY HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO  \
# 0          NaN           NaN          NaN               NaN         NaN   NaN
# 1          NaN           NaN          NaN               NaN         NaN   NaN
# 2          NaN           NaN          NaN               NaN         NaN   NaN
# 3          NaN           NaN          NaN               NaN         NaN   NaN
# 4          NaN           NaN          NaN               NaN         NaN   NaN
#
#   HAZMAT_PRESENT_I HAZMAT_REPORT_I HAZMAT_REPORT_NO MCS_REPORT_I  \
# 0              NaN             NaN              NaN          NaN
# 1              NaN             NaN              NaN          NaN
# 2              NaN             NaN              NaN          NaN
# 3              NaN             NaN              NaN          NaN
# 4              NaN             NaN              NaN          NaN
#
#   MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO  \
# 0           NaN                      NaN                   NaN            NaN
# 1           NaN                      NaN                   NaN            NaN
# 2           NaN                      NaN                   NaN            NaN
# 3           NaN                      NaN                   NaN            NaN
# 4           NaN                      NaN                   NaN            NaN
#
#   WIDE_LOAD_I TRAILER1_WIDTH TRAILER2_WIDTH TRAILER1_LENGTH TRAILER2_LENGTH  \
# 0         NaN            NaN            NaN             NaN             NaN
# 1         NaN            NaN            NaN             NaN             NaN
# 2         NaN            NaN            NaN             NaN             NaN
# 3         NaN            NaN            NaN             NaN             NaN
# 4         NaN            NaN            NaN             NaN             NaN
#
#   TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE  \
# 0                  NaN      NaN            NaN             NaN       NaN
# 1                  NaN      NaN            NaN             NaN       NaN
# 2                  NaN      NaN            NaN             NaN       NaN
# 3                  NaN      NaN            NaN             NaN       NaN
# 4                  NaN      NaN            NaN             NaN       NaN
#
#   HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I HAZMAT_CLASS PERSON_ID  \
# 0                     NaN                  NaN          NaN   O228894
# 1                     NaN                  NaN          NaN       NaN
# 2                     NaN                  NaN          NaN       NaN
# 3                     NaN                  NaN          NaN   O228905
# 4                     NaN                  NaN          NaN       NaN
#
#   PERSON_TYPE SEAT_NO      CITY STATE ZIPCODE  SEX  AGE DRIVERS_LICENSE_STATE  \
# 0      DRIVER     NaN  KANKAKKE    IL   60901    M   18                    IL
# 1         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
# 2         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
# 3      DRIVER     NaN   CHICAGO    IL   60632    M   43                    IL
# 4         NaN     NaN       NaN   NaN     NaN  NaN  NaN                   NaN
#
#   DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT  AIRBAG_DEPLOYED EJECTION  \
# 0                     D  SAFETY BELT USED  DEPLOYED, FRONT     NONE
# 1                   NaN               NaN              NaN      NaN
# 2                   NaN               NaN              NaN      NaN
# 3                     D  SAFETY BELT USED   DID NOT DEPLOY     NONE
# 4                   NaN               NaN              NaN      NaN
#
#       INJURY_CLASSIFICATION HOSPITAL EMS_AGENCY EMS_RUN_NO  \
# 0  NONINCAPACITATING INJURY      NaN        NaN        NaN
# 1                       NaN      NaN        NaN        NaN
# 2                       NaN      NaN        NaN        NaN
# 3   NO INDICATION OF INJURY      NaN        NaN        NaN
# 4                       NaN      NaN        NaN        NaN
#
#           DRIVER_ACTION DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION  \
# 0               UNKNOWN  NOT OBSCURED             NORMAL             NaN
# 1                   NaN           NaN                NaN             NaN
# 2                   NaN           NaN                NaN             NaN
# 3  IMPROPER LANE CHANGE  NOT OBSCURED             NORMAL             NaN
# 4                   NaN           NaN                NaN             NaN
#
#   PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE  \
# 0                 NaN               NaN  TEST NOT OFFERED              NaN
# 1                 NaN               NaN               NaN              NaN
# 2                 NaN               NaN               NaN              NaN
# 3                 NaN               NaN  TEST NOT OFFERED              NaN
# 4                 NaN               NaN               NaN              NaN
#
#   CELL_PHONE_USE
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
print(vehicles_with_people.shape)
# Out:
# (75838, 98)

# %%
#wtf = df_test.groupby('CRASH_RECORD_ID')
#wtf.head(n=20)
# should we filter as 'OCCUPANT_CNT >= 1' ?
# OCCUPANT_CNT = The number of people in the unit, as determined by the reporting officer.

# %%
merged_data = crashes.merge(vehicles_with_people, 
                            how='inner', 
                            on=['CRASH_RECORD_ID', 'RD_NO', 'CRASH_DATE'])

print('Dimensions of the data after merging', merged_data.shape)
# Out:
# Dimensions of the data after merging (68503, 144)

# %% [markdown]
# **Inspection 1**

# %%
merged_data.groupby('CRASH_RECORD_ID').head()
# Out:
#                                          CRASH_RECORD_ID     RD_NO  \
# 0      0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 1      0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 2      02e2ed3606a50dda185f5e97c57a45552087d6fbea1c4b...  JB256393
# 3      02e2ed3606a50dda185f5e97c57a45552087d6fbea1c4b...  JB256393
# 4      03def753c76d0105940f82e9eaac6f1d87683b7a574c20...  JB246843
# ...                                                  ...       ...
# 68498  674d6a3c4f2df46285b73f5003a8ee0342cc0ab5cd1f66...  JD314340
# 68499  2a82ef3a871842cf16a0c04108aff04f7926308b399d1d...  JD314360
# 68500  2a82ef3a871842cf16a0c04108aff04f7926308b399d1d...  JD314360
# 68501  4e5a88b3896b2e88779ecd6f3a12e13fc335b94f4a6e8b...  JD313988
# 68502  4e5a88b3896b2e88779ecd6f3a12e13fc335b94f4a6e8b...  JD313988
#
#       CRASH_DATE_EST_I          CRASH_DATE POSTED_SPEED_LIMIT  \
# 0                  NaN 2019-06-11 08:40:00                 30
# 1                  NaN 2019-06-11 08:40:00                 30
# 2                  NaN 2018-05-09 11:30:00                 25
# 3                  NaN 2018-05-09 11:30:00                 25
# 4                  NaN 2018-05-02 12:50:00                 30
# ...                ...                 ...                ...
# 68498              NaN 2020-07-29 17:20:00                 15
# 68499              NaN 2020-07-29 17:17:00                 30
# 68500              NaN 2020-07-29 17:17:00                 30
# 68501              NaN 2020-07-29 12:55:00                 30
# 68502              NaN 2020-07-29 12:55:00                 30
#
#       TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0             TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1             TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 2                NO CONTROLS           NO CONTROLS              RAIN
# 3                NO CONTROLS           NO CONTROLS              RAIN
# 4                NO CONTROLS           NO CONTROLS             CLEAR
# ...                      ...                   ...               ...
# 68498            NO CONTROLS           NO CONTROLS             CLEAR
# 68499            NO CONTROLS           NO CONTROLS             CLEAR
# 68500            NO CONTROLS           NO CONTROLS             CLEAR
# 68501                  OTHER  FUNCTIONING PROPERLY             CLEAR
# 68502                  OTHER  FUNCTIONING PROPERLY             CLEAR
#
#       LIGHTING_CONDITION          FIRST_CRASH_TYPE  \
# 0               DAYLIGHT                  REAR END
# 1               DAYLIGHT                  REAR END
# 2               DAYLIGHT                     ANGLE
# 3               DAYLIGHT                     ANGLE
# 4               DAYLIGHT              OTHER OBJECT
# ...                  ...                       ...
# 68498           DAYLIGHT              FIXED OBJECT
# 68499           DAYLIGHT                   TURNING
# 68500           DAYLIGHT                   TURNING
# 68501           DAYLIGHT  SIDESWIPE SAME DIRECTION
# 68502           DAYLIGHT  SIDESWIPE SAME DIRECTION
#
#                   TRAFFICWAY_TYPE LANE_CNT           ALIGNMENT  \
# 0      DIVIDED - W/MEDIAN BARRIER      NaN  STRAIGHT AND LEVEL
# 1      DIVIDED - W/MEDIAN BARRIER      NaN  STRAIGHT AND LEVEL
# 2                     NOT DIVIDED        2  STRAIGHT AND LEVEL
# 3                     NOT DIVIDED        2  STRAIGHT AND LEVEL
# 4                     PARKING LOT      NaN  STRAIGHT AND LEVEL
# ...                           ...      ...                 ...
# 68498                       ALLEY      NaN   STRAIGHT ON GRADE
# 68499                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 68500                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 68501                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 68502                 NOT DIVIDED      NaN  STRAIGHT AND LEVEL
#
#       ROADWAY_SURFACE_COND ROAD_DEFECT                 REPORT_TYPE  \
# 0                      DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 1                      DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 2                      WET  NO DEFECTS                    ON SCENE
# 3                      WET  NO DEFECTS                    ON SCENE
# 4                      DRY  NO DEFECTS                    ON SCENE
# ...                    ...         ...                         ...
# 68498                  DRY  NO DEFECTS                    ON SCENE
# 68499                  DRY  NO DEFECTS                    ON SCENE
# 68500                  DRY  NO DEFECTS                    ON SCENE
# 68501                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 68502                  DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
#
#                              CRASH_TYPE INTERSECTION_RELATED_I  \
# 0                NO INJURY / DRIVE AWAY                      Y
# 1                NO INJURY / DRIVE AWAY                      Y
# 2                NO INJURY / DRIVE AWAY                    NaN
# 3                NO INJURY / DRIVE AWAY                    NaN
# 4      INJURY AND / OR TOW DUE TO CRASH                    NaN
# ...                                 ...                    ...
# 68498            NO INJURY / DRIVE AWAY                    NaN
# 68499            NO INJURY / DRIVE AWAY                    NaN
# 68500            NO INJURY / DRIVE AWAY                    NaN
# 68501            NO INJURY / DRIVE AWAY                      Y
# 68502            NO INJURY / DRIVE AWAY                      Y
#
#       NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I         DAMAGE DATE_POLICE_NOTIFIED  \
# 0                    NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
# 1                    NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
# 2                    NaN           NaN    OVER $1,500  2018-05-09 11:35:00
# 3                    NaN           NaN    OVER $1,500  2018-05-09 11:35:00
# 4                    NaN           NaN    OVER $1,500  2018-05-02 12:53:00
# ...                  ...           ...            ...                  ...
# 68498                NaN           NaN  $501 - $1,500  2020-07-29 17:53:00
# 68499                NaN           NaN    OVER $1,500  2020-07-29 17:21:00
# 68500                NaN           NaN    OVER $1,500  2020-07-29 17:21:00
# 68501                NaN           NaN    OVER $1,500  2020-07-29 13:05:00
# 68502                NaN           NaN    OVER $1,500  2020-07-29 13:05:00
#
#              PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_NO  \
# 0                UNABLE TO DETERMINE         NOT APPLICABLE        50
# 1                UNABLE TO DETERMINE         NOT APPLICABLE        50
# 2      FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      9511
# 3      FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      9511
# 4                UNABLE TO DETERMINE    UNABLE TO DETERMINE      1320
# ...                              ...                    ...       ...
# 68498            UNABLE TO DETERMINE    UNABLE TO DETERMINE      4632
# 68499  FAILING TO YIELD RIGHT-OF-WAY         NOT APPLICABLE      1035
# 68500  FAILING TO YIELD RIGHT-OF-WAY         NOT APPLICABLE      1035
# 68501  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5210
# 68502  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5210
#
#       STREET_DIRECTION    STREET_NAME BEAT_OF_OCCURRENCE PHOTOS_TAKEN_I  \
# 0                    E  GARFIELD BLVD                225            NaN
# 1                    E  GARFIELD BLVD                225            NaN
# 2                    S  WENTWORTH AVE                511            NaN
# 3                    S  WENTWORTH AVE                511            NaN
# 4                    E        47TH ST                222            NaN
# ...                ...            ...                ...            ...
# 68498                S  WASHTENAW AVE                922            NaN
# 68499                S    AUSTIN BLVD               1513            NaN
# 68500                S    AUSTIN BLVD               1513            NaN
# 68501                N    LINCOLN AVE               2011            NaN
# 68502                N    LINCOLN AVE               2011            NaN
#
#       STATEMENTS_TAKEN_I DOORING_I WORK_ZONE_I WORK_ZONE_TYPE  \
# 0                    NaN       NaN         NaN            NaN
# 1                    NaN       NaN         NaN            NaN
# 2                    NaN       NaN         NaN            NaN
# 3                    NaN       NaN         NaN            NaN
# 4                    NaN       NaN         NaN            NaN
# ...                  ...       ...         ...            ...
# 68498                NaN       NaN         NaN            NaN
# 68499                NaN       NaN         NaN            NaN
# 68500                NaN       NaN         NaN            NaN
# 68501                NaN       NaN         NaN            NaN
# 68502                NaN       NaN         NaN            NaN
#
#       WORKERS_PRESENT_I NUM_UNITS        MOST_SEVERE_INJURY INJURIES_TOTAL  \
# 0                   NaN         2   NO INDICATION OF INJURY              0
# 1                   NaN         2   NO INDICATION OF INJURY              0
# 2                   NaN         2   NO INDICATION OF INJURY              0
# 3                   NaN         2   NO INDICATION OF INJURY              0
# 4                   NaN         1  NONINCAPACITATING INJURY              1
# ...                 ...       ...                       ...            ...
# 68498               NaN         1   NO INDICATION OF INJURY              0
# 68499               NaN         2   NO INDICATION OF INJURY              0
# 68500               NaN         2   NO INDICATION OF INJURY              0
# 68501               NaN         2   NO INDICATION OF INJURY              0
# 68502               NaN         2   NO INDICATION OF INJURY              0
#
#       INJURIES_FATAL INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 0                  0                       0                           0
# 1                  0                       0                           0
# 2                  0                       0                           0
# 3                  0                       0                           0
# 4                  0                       0                           1
# ...              ...                     ...                         ...
# 68498              0                       0                           0
# 68499              0                       0                           0
# 68500              0                       0                           0
# 68501              0                       0                           0
# 68502              0                       0                           0
#
#       INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                                 0                      3                0
# 1                                 0                      3                0
# 2                                 0                      2                0
# 3                                 0                      2                0
# 4                                 0                      0                0
# ...                             ...                    ...              ...
# 68498                             0                      2                0
# 68499                             0                      2                0
# 68500                             0                      2                0
# 68501                             0                      3                0
# 68502                             0                      3                0
#
#       CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH      LATITUDE      LONGITUDE  \
# 0              8                 3           6  41.794778764  -87.623828038
# 1              8                 3           6  41.794778764  -87.623828038
# 2             11                 4           5   41.72128957  -87.628509594
# 3             11                 4           5   41.72128957  -87.628509594
# 4             12                 4           5  41.809781151  -87.594212812
# ...          ...               ...         ...           ...            ...
# 68498         17                 4           7  41.809131202  -87.691934211
# 68499         17                 4           7  41.868063122  -87.774077299
# 68500         17                 4           7  41.868063122  -87.774077299
# 68501         12                 4           7  41.976225187  -87.692503665
# 68502         12                 4           7  41.976225187  -87.692503665
#
#                                        LOCATION CRASH_UNIT_ID UNIT_NO  \
# 0      POINT (-87.623828038036 41.794778764028)        667550       1
# 1      POINT (-87.623828038036 41.794778764028)        667551       2
# 2       POINT (-87.628509593966 41.72128957001)        381841       1
# 3       POINT (-87.628509593966 41.72128957001)        381842       2
# 4      POINT (-87.594212812011 41.809781151018)        376624       1
# ...                                         ...           ...     ...
# 68498  POINT (-87.691934210819 41.809131202018)        927884       1
# 68499  POINT (-87.774077298863 41.868063121814)        927948       1
# 68500  POINT (-87.774077298863 41.868063121814)        927949       2
# 68501  POINT (-87.692503665448 41.976225186967)        927624       1
# 68502  POINT (-87.692503665448 41.976225186967)        927625       2
#
#       UNIT_TYPE NUM_PASSENGERS VEHICLE_ID CMRC_VEH_I  \
# 0        DRIVER            NaN     635502        NaN
# 1        DRIVER              1     635496        NaN
# 2        DRIVER            NaN     367786        NaN
# 3        DRIVER            NaN     367788        NaN
# 4        DRIVER            NaN     362862        NaN
# ...         ...            ...        ...        ...
# 68498    DRIVER              1     879694        NaN
# 68499    DRIVER            NaN     879756        NaN
# 68500    DRIVER            NaN     879766        NaN
# 68501    DRIVER            NaN     879442        NaN
# 68502    DRIVER              1     879449        NaN
#
#                                    MAKE  \
# 0                             CHEVROLET
# 1                             CHEVROLET
# 2                                NISSAN
# 3            TOYOTA MOTOR COMPANY, LTD.
# 4                                 HONDA
# ...                                 ...
# 68498  GENERAL MOTORS CORPORATION (GMC)
# 68499                            TOYOTA
# 68500                             DODGE
# 68501                            NISSAN
# 68502                            SUBARU
#
#                                         MODEL LIC_PLATE_STATE VEHICLE_YEAR  \
# 0                                     EQUINOX              IL         2017
# 1                                   SILVERADO              IL         2016
# 2      SENTRA (DATSUN AND NISSAN HAVE MERGED)              IL         1997
# 3                                       YARIS              IL         2015
# 4                                       CIVIC              IL         2015
# ...                                       ...             ...          ...
# 68498                                SAVANNAH              AZ         2011
# 68499                                  AVALON             NaN         1999
# 68500                              CHALLENGER              IL         2016
# 68501                                    JUKE              IL         2011
# 68502                                FORESTER              IL         2009
#
#       VEHICLE_DEFECT                 VEHICLE_TYPE VEHICLE_USE  \
# 0            UNKNOWN  SPORT UTILITY VEHICLE (SUV)  UNKNOWN/NA
# 1               NONE                       PICKUP    PERSONAL
# 2               NONE                    PASSENGER    PERSONAL
# 3               NONE                    PASSENGER    PERSONAL
# 4               NONE                    PASSENGER    PERSONAL
# ...              ...                          ...         ...
# 68498           NONE          TRUCK - SINGLE UNIT       OTHER
# 68499           NONE                    PASSENGER    PERSONAL
# 68500           NONE                    PASSENGER    PERSONAL
# 68501           NONE                    PASSENGER    PERSONAL
# 68502           NONE                    PASSENGER    PERSONAL
#
#       TRAVEL_DIRECTION             MANEUVER TOWED_I FIRE_I OCCUPANT_CNT  \
# 0                    W       STRAIGHT AHEAD     NaN    NaN            1
# 1                    W  STARTING IN TRAFFIC     NaN    NaN            2
# 2                    W       STRAIGHT AHEAD     NaN    NaN            1
# 3                    N       STRAIGHT AHEAD     NaN    NaN            1
# 4                    N       STRAIGHT AHEAD     NaN    NaN            1
# ...                ...                  ...     ...    ...          ...
# 68498                N           UNKNOWN/NA     NaN    NaN            2
# 68499                S               U-TURN     NaN    NaN            1
# 68500                N       STRAIGHT AHEAD     NaN    NaN            1
# 68501                S       CHANGING LANES     NaN    NaN            1
# 68502                S       STRAIGHT AHEAD     NaN    NaN            2
#
#       EXCEED_SPEED_LIMIT_I TOWED_BY TOWED_TO AREA_00_I AREA_01_I AREA_02_I  \
# 0                      NaN      NaN      NaN       NaN       NaN       NaN
# 1                      NaN      NaN      NaN       NaN       NaN       NaN
# 2                      NaN      NaN      NaN       NaN         Y         Y
# 3                      NaN      NaN      NaN       NaN         Y         Y
# 4                      NaN      NaN      NaN       NaN         Y         Y
# ...                    ...      ...      ...       ...       ...       ...
# 68498                  NaN      NaN      NaN       NaN       NaN       NaN
# 68499                  NaN      NaN      NaN       NaN         Y       NaN
# 68500                  NaN      NaN      NaN       NaN       NaN       NaN
# 68501                  NaN      NaN      NaN       NaN       NaN       NaN
# 68502                  NaN      NaN      NaN       NaN       NaN         Y
#
#       AREA_03_I AREA_04_I AREA_05_I AREA_06_I AREA_07_I AREA_08_I AREA_09_I  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN         Y       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN         Y       NaN
# 3           NaN       NaN       NaN       NaN       NaN         Y       NaN
# 4           NaN       NaN       NaN       NaN       NaN         Y       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 68498       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 68499       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 68500       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 68501       NaN       NaN       NaN       NaN       NaN         Y         Y
# 68502         Y       NaN       NaN       NaN       NaN       NaN       NaN
#
#       AREA_10_I AREA_11_I AREA_12_I AREA_99_I FIRST_CONTACT_POINT CMV_ID  \
# 0           NaN       NaN         Y       NaN               OTHER    NaN
# 1           NaN       NaN       NaN       NaN           REAR-LEFT    NaN
# 2           NaN       NaN       NaN       NaN          FRONT-LEFT    NaN
# 3           NaN       NaN       NaN       NaN         FRONT-RIGHT    NaN
# 4           NaN       NaN       NaN       NaN               FRONT    NaN
# ...         ...       ...       ...       ...                 ...    ...
# 68498       NaN       NaN       NaN         Y             UNKNOWN    NaN
# 68499       NaN       NaN         N       NaN               FRONT    NaN
# 68500       NaN       NaN         Y       NaN               OTHER    NaN
# 68501       NaN       NaN       NaN       NaN          FRONT-LEFT    NaN
# 68502       NaN       NaN       NaN       NaN               FRONT    NaN
#
#       USDOT_NO CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR CARRIER_NAME CARRIER_STATE  \
# 0          NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 1          NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 2          NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 3          NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 4          NaN     NaN     NaN            NaN  NaN          NaN           NaN
# ...        ...     ...     ...            ...  ...          ...           ...
# 68498      NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 68499      NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 68500      NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 68501      NaN     NaN     NaN            NaN  NaN          NaN           NaN
# 68502      NaN     NaN     NaN            NaN  NaN          NaN           NaN
#
#       CARRIER_CITY HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO HAZMAT_PRESENT_I  \
# 0              NaN               NaN         NaN   NaN              NaN
# 1              NaN               NaN         NaN   NaN              NaN
# 2              NaN               NaN         NaN   NaN              NaN
# 3              NaN               NaN         NaN   NaN              NaN
# 4              NaN               NaN         NaN   NaN              NaN
# ...            ...               ...         ...   ...              ...
# 68498          NaN               NaN         NaN   NaN              NaN
# 68499          NaN               NaN         NaN   NaN              NaN
# 68500          NaN               NaN         NaN   NaN              NaN
# 68501          NaN               NaN         NaN   NaN              NaN
# 68502          NaN               NaN         NaN   NaN              NaN
#
#       HAZMAT_REPORT_I HAZMAT_REPORT_NO MCS_REPORT_I MCS_REPORT_NO  \
# 0                 NaN              NaN          NaN           NaN
# 1                 NaN              NaN          NaN           NaN
# 2                 NaN              NaN          NaN           NaN
# 3                 NaN              NaN          NaN           NaN
# 4                 NaN              NaN          NaN           NaN
# ...               ...              ...          ...           ...
# 68498             NaN              NaN          NaN           NaN
# 68499             NaN              NaN          NaN           NaN
# 68500             NaN              NaN          NaN           NaN
# 68501             NaN              NaN          NaN           NaN
# 68502             NaN              NaN          NaN           NaN
#
#       HAZMAT_VIO_CAUSE_CRASH_I MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO  \
# 0                          NaN                   NaN            NaN
# 1                          NaN                   NaN            NaN
# 2                          NaN                   NaN            NaN
# 3                          NaN                   NaN            NaN
# 4                          NaN                   NaN            NaN
# ...                        ...                   ...            ...
# 68498                      NaN                   NaN            NaN
# 68499                      NaN                   NaN            NaN
# 68500                      NaN                   NaN            NaN
# 68501                      NaN                   NaN            NaN
# 68502                      NaN                   NaN            NaN
#
#       WIDE_LOAD_I TRAILER1_WIDTH TRAILER2_WIDTH TRAILER1_LENGTH  \
# 0             NaN            NaN            NaN             NaN
# 1             NaN            NaN            NaN             NaN
# 2             NaN            NaN            NaN             NaN
# 3             NaN            NaN            NaN             NaN
# 4             NaN            NaN            NaN             NaN
# ...           ...            ...            ...             ...
# 68498         NaN            NaN            NaN             NaN
# 68499         NaN            NaN            NaN             NaN
# 68500         NaN            NaN            NaN             NaN
# 68501         NaN            NaN            NaN             NaN
# 68502         NaN            NaN            NaN             NaN
#
#       TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH AXLE_CNT VEHICLE_CONFIG  \
# 0                 NaN                  NaN      NaN            NaN
# 1                 NaN                  NaN      NaN            NaN
# 2                 NaN                  NaN      NaN            NaN
# 3                 NaN                  NaN      NaN            NaN
# 4                 NaN                  NaN      NaN            NaN
# ...               ...                  ...      ...            ...
# 68498             NaN                  NaN      NaN            NaN
# 68499             NaN                  NaN      NaN            NaN
# 68500             NaN                  NaN      NaN            NaN
# 68501             NaN                  NaN      NaN            NaN
# 68502             NaN                  NaN      NaN            NaN
#
#       CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I MCS_OUT_OF_SERVICE_I  \
# 0                 NaN       NaN                     NaN                  NaN
# 1                 NaN       NaN                     NaN                  NaN
# 2                 NaN       NaN                     NaN                  NaN
# 3                 NaN       NaN                     NaN                  NaN
# 4                 NaN       NaN                     NaN                  NaN
# ...               ...       ...                     ...                  ...
# 68498             NaN       NaN                     NaN                  NaN
# 68499             NaN       NaN                     NaN                  NaN
# 68500             NaN       NaN                     NaN                  NaN
# 68501             NaN       NaN                     NaN                  NaN
# 68502             NaN       NaN                     NaN                  NaN
#
#       HAZMAT_CLASS PERSON_ID PERSON_TYPE SEAT_NO          CITY STATE ZIPCODE  \
# 0              NaN   O667550      DRIVER     NaN      HOMEWOOD    IL   60430
# 1              NaN   O667551      DRIVER     NaN   PALOS HILLS    IL   60465
# 2              NaN   O381841      DRIVER     NaN       CHICAGO    IL   60620
# 3              NaN   O381842      DRIVER     NaN       CHICAGO    IL   60628
# 4              NaN   O376624      DRIVER     NaN       CHICAGO    IL     NaN
# ...            ...       ...         ...     ...           ...   ...     ...
# 68498          NaN   O927884      DRIVER     NaN       CHICAGO    IL     NaN
# 68499          NaN   O927948      DRIVER     NaN       CHICAGO    IL   60644
# 68500          NaN   O927949      DRIVER     NaN  ELMWOOD PARK    IL   60706
# 68501          NaN   O927624      DRIVER     NaN  LINCOLNSHIRE    IL   60069
# 68502          NaN   O927625      DRIVER     NaN       CHICAGO    IL   60640
#
#       SEX AGE DRIVERS_LICENSE_STATE DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT  \
# 0       F  56                    IL                     D     USAGE UNKNOWN
# 1       M  51                    IL                     D  SAFETY BELT USED
# 2       F  45                    IL                    DM  SAFETY BELT USED
# 3       F  35                    IL                     D  SAFETY BELT USED
# 4       F  83                    IL                     D  SAFETY BELT USED
# ...    ..  ..                   ...                   ...               ...
# 68498   M  38                    IL                     D     USAGE UNKNOWN
# 68499   M  25                    IL                     D     USAGE UNKNOWN
# 68500   M  51                    IL                    BM     USAGE UNKNOWN
# 68501   F  68                    IL                     D  SAFETY BELT USED
# 68502   F  71                    IL                     D  SAFETY BELT USED
#
#        AIRBAG_DEPLOYED EJECTION     INJURY_CLASSIFICATION  \
# 0       DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 1       DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 2       DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 3       DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 4      DEPLOYED, FRONT     NONE  NONINCAPACITATING INJURY
# ...                ...      ...                       ...
# 68498   DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 68499   DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 68500   NOT APPLICABLE     NONE   NO INDICATION OF INJURY
# 68501   DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
# 68502   DID NOT DEPLOY     NONE   NO INDICATION OF INJURY
#
#                     HOSPITAL EMS_AGENCY EMS_RUN_NO         DRIVER_ACTION  \
# 0                        NaN        NaN        NaN               UNKNOWN
# 1                        NaN        NaN        NaN                  NONE
# 2                        NaN        NaN        NaN       FAILED TO YIELD
# 3                        NaN        NaN        NaN                  NONE
# 4      UNIVERSITY OF CHICAGO    CFD #35        NaN               UNKNOWN
# ...                      ...        ...        ...                   ...
# 68498                    NaN        NaN        NaN               UNKNOWN
# 68499                REFUSED        NaN        NaN       FAILED TO YIELD
# 68500                REFUSED        NaN        NaN                  NONE
# 68501                    NaN        NaN        NaN  IMPROPER LANE CHANGE
# 68502                    NaN        NaN        NaN                  NONE
#
#          DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION PEDPEDAL_VISIBILITY  \
# 0              UNKNOWN             NORMAL             NaN                 NaN
# 1         NOT OBSCURED             NORMAL             NaN                 NaN
# 2      PARKED VEHICLES             NORMAL             NaN                 NaN
# 3         NOT OBSCURED             NORMAL             NaN                 NaN
# 4         NOT OBSCURED             NORMAL             NaN                 NaN
# ...                ...                ...             ...                 ...
# 68498          UNKNOWN            UNKNOWN             NaN                 NaN
# 68499          UNKNOWN             NORMAL             NaN                 NaN
# 68500     NOT OBSCURED             NORMAL             NaN                 NaN
# 68501     NOT OBSCURED             NORMAL             NaN                 NaN
# 68502     NOT OBSCURED             NORMAL             NaN                 NaN
#
#       PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE CELL_PHONE_USE
# 0                   NaN  TEST NOT OFFERED              NaN            NaN
# 1                   NaN  TEST NOT OFFERED              NaN            NaN
# 2                   NaN  TEST NOT OFFERED              NaN            NaN
# 3                   NaN  TEST NOT OFFERED              NaN            NaN
# 4                   NaN  TEST NOT OFFERED              NaN            NaN
# ...                 ...               ...              ...            ...
# 68498               NaN      TEST REFUSED              NaN            NaN
# 68499               NaN  TEST NOT OFFERED              NaN            NaN
# 68500               NaN  TEST NOT OFFERED              NaN            NaN
# 68501               NaN  TEST NOT OFFERED              NaN            NaN
# 68502               NaN  TEST NOT OFFERED              NaN            NaN
#
# [68292 rows x 144 columns]

# %% [markdown]
# **Inspection 2**

# %%
merged_data[merged_data.RD_NO.eq('JC301403')] #Wrong joins could result in 6 rows
# Out:
#                                      CRASH_RECORD_ID     RD_NO  \
# 0  0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
# 1  0211e1f766f3940dfa87375661d25b716655e908c320cc...  JC301403
#
#   CRASH_DATE_EST_I          CRASH_DATE POSTED_SPEED_LIMIT  \
# 0              NaN 2019-06-11 08:40:00                 30
# 1              NaN 2019-06-11 08:40:00                 30
#
#   TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 0         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 1         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
#
#   LIGHTING_CONDITION FIRST_CRASH_TYPE             TRAFFICWAY_TYPE LANE_CNT  \
# 0           DAYLIGHT         REAR END  DIVIDED - W/MEDIAN BARRIER      NaN
# 1           DAYLIGHT         REAR END  DIVIDED - W/MEDIAN BARRIER      NaN
#
#             ALIGNMENT ROADWAY_SURFACE_COND ROAD_DEFECT  \
# 0  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
# 1  STRAIGHT AND LEVEL                  DRY  NO DEFECTS
#
#                   REPORT_TYPE              CRASH_TYPE INTERSECTION_RELATED_I  \
# 0  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                      Y
# 1  NOT ON SCENE (DESK REPORT)  NO INJURY / DRIVE AWAY                      Y
#
#   NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I         DAMAGE DATE_POLICE_NOTIFIED  \
# 0                NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
# 1                NaN           NaN  $501 - $1,500  2019-06-11 09:05:00
#
#   PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_NO STREET_DIRECTION  \
# 0     UNABLE TO DETERMINE         NOT APPLICABLE        50                E
# 1     UNABLE TO DETERMINE         NOT APPLICABLE        50                E
#
#      STREET_NAME BEAT_OF_OCCURRENCE PHOTOS_TAKEN_I STATEMENTS_TAKEN_I  \
# 0  GARFIELD BLVD                225            NaN                NaN
# 1  GARFIELD BLVD                225            NaN                NaN
#
#   DOORING_I WORK_ZONE_I WORK_ZONE_TYPE WORKERS_PRESENT_I NUM_UNITS  \
# 0       NaN         NaN            NaN               NaN         2
# 1       NaN         NaN            NaN               NaN         2
#
#         MOST_SEVERE_INJURY INJURIES_TOTAL INJURIES_FATAL  \
# 0  NO INDICATION OF INJURY              0              0
# 1  NO INDICATION OF INJURY              0              0
#
#   INJURIES_INCAPACITATING INJURIES_NON_INCAPACITATING  \
# 0                       0                           0
# 1                       0                           0
#
#   INJURIES_REPORTED_NOT_EVIDENT INJURIES_NO_INDICATION INJURIES_UNKNOWN  \
# 0                             0                      3                0
# 1                             0                      3                0
#
#   CRASH_HOUR CRASH_DAY_OF_WEEK CRASH_MONTH      LATITUDE      LONGITUDE  \
# 0          8                 3           6  41.794778764  -87.623828038
# 1          8                 3           6  41.794778764  -87.623828038
#
#                                    LOCATION CRASH_UNIT_ID UNIT_NO UNIT_TYPE  \
# 0  POINT (-87.623828038036 41.794778764028)        667550       1    DRIVER
# 1  POINT (-87.623828038036 41.794778764028)        667551       2    DRIVER
#
#   NUM_PASSENGERS VEHICLE_ID CMRC_VEH_I       MAKE      MODEL LIC_PLATE_STATE  \
# 0            NaN     635502        NaN  CHEVROLET    EQUINOX              IL
# 1              1     635496        NaN  CHEVROLET  SILVERADO              IL
#
#   VEHICLE_YEAR VEHICLE_DEFECT                 VEHICLE_TYPE VEHICLE_USE  \
# 0         2017        UNKNOWN  SPORT UTILITY VEHICLE (SUV)  UNKNOWN/NA
# 1         2016           NONE                       PICKUP    PERSONAL
#
#   TRAVEL_DIRECTION             MANEUVER TOWED_I FIRE_I OCCUPANT_CNT  \
# 0                W       STRAIGHT AHEAD     NaN    NaN            1
# 1                W  STARTING IN TRAFFIC     NaN    NaN            2
#
#   EXCEED_SPEED_LIMIT_I TOWED_BY TOWED_TO AREA_00_I AREA_01_I AREA_02_I  \
# 0                  NaN      NaN      NaN       NaN       NaN       NaN
# 1                  NaN      NaN      NaN       NaN       NaN       NaN
#
#   AREA_03_I AREA_04_I AREA_05_I AREA_06_I AREA_07_I AREA_08_I AREA_09_I  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN         Y       NaN       NaN       NaN
#
#   AREA_10_I AREA_11_I AREA_12_I AREA_99_I FIRST_CONTACT_POINT CMV_ID USDOT_NO  \
# 0       NaN       NaN         Y       NaN               OTHER    NaN      NaN
# 1       NaN       NaN       NaN       NaN           REAR-LEFT    NaN      NaN
#
#   CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR CARRIER_NAME CARRIER_STATE CARRIER_CITY  \
# 0     NaN     NaN            NaN  NaN          NaN           NaN          NaN
# 1     NaN     NaN            NaN  NaN          NaN           NaN          NaN
#
#   HAZMAT_PLACARDS_I HAZMAT_NAME UN_NO HAZMAT_PRESENT_I HAZMAT_REPORT_I  \
# 0               NaN         NaN   NaN              NaN             NaN
# 1               NaN         NaN   NaN              NaN             NaN
#
#   HAZMAT_REPORT_NO MCS_REPORT_I MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I  \
# 0              NaN          NaN           NaN                      NaN
# 1              NaN          NaN           NaN                      NaN
#
#   MCS_VIO_CAUSE_CRASH_I IDOT_PERMIT_NO WIDE_LOAD_I TRAILER1_WIDTH  \
# 0                   NaN            NaN         NaN            NaN
# 1                   NaN            NaN         NaN            NaN
#
#   TRAILER2_WIDTH TRAILER1_LENGTH TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH  \
# 0            NaN             NaN             NaN                  NaN
# 1            NaN             NaN             NaN                  NaN
#
#   AXLE_CNT VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I  \
# 0      NaN            NaN             NaN       NaN                     NaN
# 1      NaN            NaN             NaN       NaN                     NaN
#
#   MCS_OUT_OF_SERVICE_I HAZMAT_CLASS PERSON_ID PERSON_TYPE SEAT_NO  \
# 0                  NaN          NaN   O667550      DRIVER     NaN
# 1                  NaN          NaN   O667551      DRIVER     NaN
#
#           CITY STATE ZIPCODE SEX AGE DRIVERS_LICENSE_STATE  \
# 0     HOMEWOOD    IL   60430   F  56                    IL
# 1  PALOS HILLS    IL   60465   M  51                    IL
#
#   DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT AIRBAG_DEPLOYED EJECTION  \
# 0                     D     USAGE UNKNOWN  DID NOT DEPLOY     NONE
# 1                     D  SAFETY BELT USED  DID NOT DEPLOY     NONE
#
#      INJURY_CLASSIFICATION HOSPITAL EMS_AGENCY EMS_RUN_NO DRIVER_ACTION  \
# 0  NO INDICATION OF INJURY      NaN        NaN        NaN       UNKNOWN
# 1  NO INDICATION OF INJURY      NaN        NaN        NaN          NONE
#
#   DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION PEDPEDAL_VISIBILITY  \
# 0       UNKNOWN             NORMAL             NaN                 NaN
# 1  NOT OBSCURED             NORMAL             NaN                 NaN
#
#   PEDPEDAL_LOCATION        BAC_RESULT BAC_RESULT VALUE CELL_PHONE_USE
# 0               NaN  TEST NOT OFFERED              NaN            NaN
# 1               NaN  TEST NOT OFFERED              NaN            NaN

# %% [markdown]
# ## Splitting the data

# %%
# Alternative: X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
raw_train, raw_test = train_test_split(merged_data, test_size=0.33, random_state=42, shuffle=True)

# %%
print(raw_train.shape)
print(raw_test.shape)
# Out:
# (45897, 144)
# (22606, 144)

# %% [markdown]
# **Write datasets as csv**

# %%
# save the train and test file
#train.to_csv('~/repos/vision_zero_chicago_project/sprint 2/raw_train.csv')
#test.to_csv('~/repos/vision_zero_chicago_project/sprint 2/raw_test.csv')

# %% [markdown]
# # Feature Reduction

# %% [markdown]
# ## Remove Features with Missing Values

# %% [markdown]
# ### Remove Dummy Features
#
# Removing **49** dummy features that are **heavily missing** and/or **have no explanation** in the data dictionary provided by City of Chicago.
# - 47 features are from `AREA_00_I` to `HAZMAT_CLASS` except `FIRST_CONTACT_POINT`.
# - `CMRC_VEH_I` and `FIRE_I`.

# %%
# Get indicies and inspect these columns
for c in 'AREA_00_I', 'FIRST_CONTACT_POINT', 'HAZMAT_CLASS':
    print(raw_train.columns.get_loc(c))

raw_train.iloc[:, 70:118]
# Out:
# 70
# 84
# 117
#       AREA_00_I AREA_01_I AREA_02_I AREA_03_I AREA_04_I AREA_05_I AREA_06_I  \
# 15125       NaN         Y       NaN       NaN       NaN       NaN       NaN
# 57881       NaN         Y       NaN       NaN       NaN       NaN       NaN
# 2428        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 53511       NaN       NaN       NaN       NaN       NaN         Y       NaN
# 17961       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 37194         Y       NaN       NaN         Y       NaN       NaN       NaN
# 6265        NaN         Y         Y       NaN       NaN       NaN       NaN
# 54886       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 860         NaN         Y       NaN       NaN       NaN       NaN       NaN
# 15795       NaN         Y       NaN       NaN       NaN       NaN       NaN
#
#       AREA_07_I AREA_08_I AREA_09_I AREA_10_I AREA_11_I AREA_12_I AREA_99_I  \
# 15125       NaN       NaN       NaN       NaN         Y         Y       NaN
# 57881       NaN         Y       NaN       NaN       NaN       NaN       NaN
# 2428        NaN       NaN       NaN       NaN         Y       NaN       NaN
# 53511       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 17961       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 37194       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6265        NaN       NaN       NaN         Y         Y         Y       NaN
# 54886       NaN       NaN         Y         Y         Y       NaN       NaN
# 860         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 15795       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#       FIRST_CONTACT_POINT CMV_ID USDOT_NO CCMC_NO ILCC_NO COMMERCIAL_SRC GVWR  \
# 15125               OTHER    NaN      NaN     NaN     NaN            NaN  NaN
# 57881          FRONT-LEFT    NaN      NaN     NaN     NaN            NaN  NaN
# 2428    TOTAL (ALL AREAS)    NaN      NaN     NaN     NaN            NaN  NaN
# 53511                REAR    NaN      NaN     NaN     NaN            NaN  NaN
# 17961                 NaN    NaN      NaN     NaN     NaN            NaN  NaN
# ...                   ...    ...      ...     ...     ...            ...  ...
# 37194          SIDE-RIGHT    NaN      NaN     NaN     NaN            NaN  NaN
# 6265              UNKNOWN    NaN      NaN     NaN     NaN            NaN  NaN
# 54886   TOTAL (ALL AREAS)    NaN      NaN     NaN     NaN            NaN  NaN
# 860                 FRONT    NaN      NaN     NaN     NaN            NaN  NaN
# 15795               FRONT    NaN      NaN     NaN     NaN            NaN  NaN
#
#       CARRIER_NAME CARRIER_STATE CARRIER_CITY HAZMAT_PLACARDS_I HAZMAT_NAME  \
# 15125          NaN           NaN          NaN               NaN         NaN
# 57881          NaN           NaN          NaN               NaN         NaN
# 2428           NaN           NaN          NaN               NaN         NaN
# 53511          NaN           NaN          NaN               NaN         NaN
# 17961          NaN           NaN          NaN               NaN         NaN
# ...            ...           ...          ...               ...         ...
# 37194          NaN           NaN          NaN               NaN         NaN
# 6265           NaN           NaN          NaN               NaN         NaN
# 54886          NaN           NaN          NaN               NaN         NaN
# 860            NaN           NaN          NaN               NaN         NaN
# 15795          NaN           NaN          NaN               NaN         NaN
#
#       UN_NO HAZMAT_PRESENT_I HAZMAT_REPORT_I HAZMAT_REPORT_NO MCS_REPORT_I  \
# 15125   NaN              NaN             NaN              NaN          NaN
# 57881   NaN              NaN             NaN              NaN          NaN
# 2428    NaN              NaN             NaN              NaN          NaN
# 53511   NaN              NaN             NaN              NaN          NaN
# 17961   NaN              NaN             NaN              NaN          NaN
# ...     ...              ...             ...              ...          ...
# 37194   NaN              NaN             NaN              NaN          NaN
# 6265    NaN              NaN             NaN              NaN          NaN
# 54886   NaN              NaN             NaN              NaN          NaN
# 860     NaN              NaN             NaN              NaN          NaN
# 15795   NaN              NaN             NaN              NaN          NaN
#
#       MCS_REPORT_NO HAZMAT_VIO_CAUSE_CRASH_I MCS_VIO_CAUSE_CRASH_I  \
# 15125           NaN                      NaN                   NaN
# 57881           NaN                      NaN                   NaN
# 2428            NaN                      NaN                   NaN
# 53511           NaN                      NaN                   NaN
# 17961           NaN                      NaN                   NaN
# ...             ...                      ...                   ...
# 37194           NaN                      NaN                   NaN
# 6265            NaN                      NaN                   NaN
# 54886           NaN                      NaN                   NaN
# 860             NaN                      NaN                   NaN
# 15795           NaN                      NaN                   NaN
#
#       IDOT_PERMIT_NO WIDE_LOAD_I TRAILER1_WIDTH TRAILER2_WIDTH  \
# 15125            NaN         NaN            NaN            NaN
# 57881            NaN         NaN            NaN            NaN
# 2428             NaN         NaN            NaN            NaN
# 53511            NaN         NaN            NaN            NaN
# 17961            NaN         NaN            NaN            NaN
# ...              ...         ...            ...            ...
# 37194            NaN         NaN            NaN            NaN
# 6265             NaN         NaN            NaN            NaN
# 54886            NaN         NaN            NaN            NaN
# 860              NaN         NaN            NaN            NaN
# 15795            NaN         NaN            NaN            NaN
#
#       TRAILER1_LENGTH TRAILER2_LENGTH TOTAL_VEHICLE_LENGTH AXLE_CNT  \
# 15125             NaN             NaN                  NaN      NaN
# 57881             NaN             NaN                  NaN      NaN
# 2428              NaN             NaN                  NaN      NaN
# 53511             NaN             NaN                  NaN      NaN
# 17961             NaN             NaN                  NaN      NaN
# ...               ...             ...                  ...      ...
# 37194             NaN             NaN                  NaN      NaN
# 6265              NaN             NaN                  NaN      NaN
# 54886             NaN             NaN                  NaN      NaN
# 860               NaN             NaN                  NaN      NaN
# 15795             NaN             NaN                  NaN      NaN
#
#       VEHICLE_CONFIG CARGO_BODY_TYPE LOAD_TYPE HAZMAT_OUT_OF_SERVICE_I  \
# 15125            NaN             NaN       NaN                     NaN
# 57881            NaN             NaN       NaN                     NaN
# 2428             NaN             NaN       NaN                     NaN
# 53511            NaN             NaN       NaN                     NaN
# 17961            NaN             NaN       NaN                     NaN
# ...              ...             ...       ...                     ...
# 37194            NaN             NaN       NaN                     NaN
# 6265             NaN             NaN       NaN                     NaN
# 54886            NaN             NaN       NaN                     NaN
# 860              NaN             NaN       NaN                     NaN
# 15795            NaN             NaN       NaN                     NaN
#
#       MCS_OUT_OF_SERVICE_I HAZMAT_CLASS
# 15125                  NaN          NaN
# 57881                  NaN          NaN
# 2428                   NaN          NaN
# 53511                  NaN          NaN
# 17961                  NaN          NaN
# ...                    ...          ...
# 37194                  NaN          NaN
# 6265                   NaN          NaN
# 54886                  NaN          NaN
# 860                    NaN          NaN
# 15795                  NaN          NaN
#
# [45897 rows x 48 columns]

# %% [markdown]
# 95 features are remained after removing 49 features above.

# %%
# Drop those features except 'FIRST_CONTACT_POINT'
raw_train = raw_train.drop(raw_train.loc[:,'AREA_00_I':'AREA_99_I'], axis=1)
raw_train = raw_train.drop(raw_train.loc[:, 'CMV_ID':'HAZMAT_CLASS'], axis=1)
raw_train = raw_train.drop(raw_train.loc[:, ['CMRC_VEH_I', 'FIRE_I']], axis=1)
raw_train.shape

# %% [markdown]
# ### Remove Completely Missing Features
#
# Removing additional two features that are completely missing.

# %%
print(sum(raw_train.isnull().mean() == 1))
print(raw_train.columns[raw_train.isnull().mean() == 1].tolist())
# Out:
# 2
# ['SEAT_NO', 'EMS_RUN_NO']

# %% [markdown]
# 93 features are remained.

# %%
raw_train = raw_train.drop(raw_train.loc[:, ['SEAT_NO', 'EMS_RUN_NO']], axis=1)
raw_train.shape
# Out:
# (45897, 93)

# %% [markdown]
# ### Inspect Features Missing > 50%
#
# Still, there are 23 features that have missing values more than 50%!

# %%
# Subset the data to include the columns only with nulls in the output
raw_null_above50 = raw_train[raw_train.columns[raw_train.isnull().mean().round(2) > 0.5].tolist()]
print('\033[1m', 'These', len(raw_null_above50.columns),
      'columns have missing values more than 50%!', '\033[0m')
raw_null_above50.isnull().mean().round(3)
# Out:
#  These 23 columns have missing values more than 50%!
# CRASH_DATE_EST_I          0.930
# LANE_CNT                  0.670
# INTERSECTION_RELATED_I    0.756
# NOT_RIGHT_OF_WAY_I        0.959
# HIT_AND_RUN_I             0.702
# PHOTOS_TAKEN_I            0.987
# STATEMENTS_TAKEN_I        0.977
# DOORING_I                 0.997
# WORK_ZONE_I               0.994
# WORK_ZONE_TYPE            0.996
# WORKERS_PRESENT_I         0.999
# NUM_PASSENGERS            0.845
# TOWED_I                   0.870
# EXCEED_SPEED_LIMIT_I      0.997
# TOWED_BY                  0.905
# TOWED_TO                  0.940
# HOSPITAL                  0.837
# EMS_AGENCY                0.899
# PEDPEDAL_ACTION           0.976
# PEDPEDAL_VISIBILITY       0.976
# PEDPEDAL_LOCATION         0.976
# BAC_RESULT VALUE          0.998
# CELL_PHONE_USE            0.999
# dtype: float64

# %% [markdown]
# <a id='2.1.3.1'></a>
# #### Features that can be imputed/encoded

# %% [markdown]
# **Features that can be imputed with No**
#
# *Jump to [3.3.1](#3.3.1) for their imputation*
#
# 1. `CRASH_DATE_EST_I`: Crash date estimated by desk officer or reporting party (only used in cases where crash is reported at police station days after the crash).
#
#
# 2. `INTERSECTION_RELATED_I`: A field observation by the police officer whether an intersection played a role in the crash. Does not represent whether or not the crash occurred within the intersection.
#
#
# 3. `NOT_RIGHT_OF_WAY_I`: Whether the crash begun or first contact was made outside of the public right-of-way.
#
#
# 4. `HIT_AND_RUN_I`: Crash did/did not involve a driver who caused the crash and fled the scene without exchanging information and/or rendering aid.
#
#
# 5. `CELL_PHONE_USE`: Whether person was/was not using cellphone at the time of the crash, as determined by the reporting officer.
#
#
# 6. `EXCEED_SPEED_LIMIT_I`: Indicator of whether the unit was speeding, as determined by the reporting officer.
#
#
# 7. `DOORING_I`: Whether crash involved a motor vehicle occupant opening a door into the travel path of a bicyclist, causing a crash.
#
#
# 8. `WORK_ZONE_I`: Whether the crash occurred in an active work zone.
#
#
# 9. `WORKERS_PRESENT_I`: Whether construction workers were present in an active work zone at crash location.
#
#
# 10. `BAC_RESULT VALUE`: Driver’s blood alcohol concentration test result (fatal crashes may include pedestrian or cyclist results). This feature can be engineered as **`alcohol_consumption` = yes/no**.

# %%
print(raw_train.CRASH_DATE_EST_I.value_counts())
print()
print(raw_train.INTERSECTION_RELATED_I.value_counts())
print()
print(raw_train.NOT_RIGHT_OF_WAY_I.value_counts())
print()
print(raw_train.HIT_AND_RUN_I.value_counts())
print()
print(raw_train.CELL_PHONE_USE.value_counts())
print()
print(raw_train.EXCEED_SPEED_LIMIT_I.value_counts())
print()
print(raw_train.DOORING_I.value_counts())
print()
print(raw_train.WORK_ZONE_I.value_counts())
print()
print(raw_train.WORKERS_PRESENT_I.value_counts())
print()
print(raw_train['BAC_RESULT VALUE'].value_counts())
# Out:
# Y    2730
# N     469
# Name: CRASH_DATE_EST_I, dtype: int64
#
# Y    10659
# N      520
# Name: INTERSECTION_RELATED_I, dtype: int64
#
# Y    1725
# N     175
# Name: NOT_RIGHT_OF_WAY_I, dtype: int64
#
# Y    13063
# N      592
# Name: HIT_AND_RUN_I, dtype: int64
#
# Y    36
# N    13
# Name: CELL_PHONE_USE, dtype: int64
#
# Y    108
# N     32
# Name: EXCEED_SPEED_LIMIT_I, dtype: int64
#
# Y    105
# N     55
# Name: DOORING_I, dtype: int64
#
# Y    205
# N     60
# Name: WORK_ZONE_I, dtype: int64
#
# Y    55
# N     3
# Name: WORKERS_PRESENT_I, dtype: int64
#
# 0.2100    10
# 0.0000     8
# 0.1400     8
# 0.2000     7
# 0.1100     7
# 0.1700     7
# 0.1500     5
# 0.1200     5
# 0.1900     5
# 0.2200     3
# 0.1000     3
# 0.1800     3
# 0.1300     3
# 0.2700     2
# 0.1600     2
# 0.2300     2
# 0.2500     2
# 0.4400     1
# 0.3300     1
# 0.3100     1
# 0.2800     1
# 0.2400     1
# 0.3000     1
# 0.3200     1
# 0.0300     1
# 0.2600     1
# 0.3500     1
# 0.0100     1
# Name: BAC_RESULT VALUE, dtype: int64

# %% [markdown]
# **Features can be imputed with 0**
#
# 11. `NUM_PASSENGERS`: Number of passengers in the vehicle. The driver **is not** included. More information on passengers is in the People dataset.

# %%
print(raw_train.NUM_PASSENGERS.value_counts())
# Out:
# 1     4964
# 2     1353
# 3      535
# 4      162
# 5       55
# 6       20
# 7        6
# 8        4
# 10       3
# 9        3
# 38       1
# 12       1
# 16       1
# 19       1
# Name: NUM_PASSENGERS, dtype: int64

# %% [markdown]
# #### Features that are not meaningful
#
# 7 non-meaningful features below are removed. 86 features are remained.
#
# 12. `PHOTOS_TAKEN_I`: Whether the Chicago Police Department took photos at the location of the crash.
# 13. `STATEMENTS_TAKEN_I`: Whether statements were taken from unit(s) involved in crash.
# 14. `TOWED_I`: Indicator of whether the vehicle was towed.
# 15. `TOWED_BY`: Entity that towed the unit, if relevant.
# 16. `TOWED_TO`: Location to which the unit was towed, if relevant.
# 17. `EMS_AGENCY`: EMS agency who transported person injured in crash to the hospital.
# 18. `WORK_ZONE_TYPE`: The type of work zone, if any.

# %%
raw_train = raw_train.drop(raw_train.loc[:, [
    'PHOTOS_TAKEN_I','STATEMENTS_TAKEN_I','TOWED_I','TOWED_BY','TOWED_TO','EMS_AGENCY','WORK_ZONE_TYPE'
]], 
                           axis=1)
raw_train.shape
# Out:
# (45897, 86)

# %% [markdown]
# #### Features that waits a decision
#
# 19. `LANE_CNT`: Total number of through lanes in either direction, excluding turn lanes, as determined by reporting officer (0 = intersection).
# 20. `HOSPITAL`: Hospital to which person injured in the crash was taken.
# 21. `PEDPEDAL_ACTION`: Action of pedestrian or cyclist at the time of crash.
# 22. `PEDPEDAL_VISIBILITY`: Visibility of pedestrian of cyclist safety equipment in use at time of crash.
# 23. `PEDPEDAL_LOCATION`: Location of pedestrian or cyclist at the time of crash.

# %%
raw_train.head()
# Out:
#                                          CRASH_RECORD_ID     RD_NO  \
# 15125  23ad95c12c156fb65161003179600144c3a4756fc53215...  JD268602
# 57881  d3e15b2edf3c052ccd3baecd774b8828a05cb304628de8...  JC185553
# 2428   b25aee5a038a0f9e5da4748b1ed592b228718b6ed744d3...  JD335607
# 53511  c14bbcab3cdf958304f35ba3f19f23613259124a8fba08...  JB124218
# 17961  2f41d62debc032baca2e16c66444112babe87bd4713177...  JD176845
#
#       CRASH_DATE_EST_I          CRASH_DATE POSTED_SPEED_LIMIT  \
# 15125              NaN 2020-06-18 22:06:00                 30
# 57881              NaN 2019-03-14 17:14:00                 25
# 2428               NaN 2020-08-17 13:00:00                 30
# 53511              NaN 2018-01-21 13:45:00                 30
# 17961              NaN 2020-03-07 00:01:00                 15
#
#       TRAFFIC_CONTROL_DEVICE      DEVICE_CONDITION WEATHER_CONDITION  \
# 15125         TRAFFIC SIGNAL  FUNCTIONING PROPERLY             CLEAR
# 57881         TRAFFIC SIGNAL  FUNCTIONING PROPERLY   CLOUDY/OVERCAST
# 2428             NO CONTROLS           NO CONTROLS             CLEAR
# 53511         TRAFFIC SIGNAL  FUNCTIONING PROPERLY              SNOW
# 17961            NO CONTROLS           NO CONTROLS             CLEAR
#
#            LIGHTING_CONDITION FIRST_CRASH_TYPE  \
# 15125  DARKNESS, LIGHTED ROAD          TURNING
# 57881                    DAWN            ANGLE
# 2428                 DAYLIGHT            ANGLE
# 53511                DAYLIGHT         REAR END
# 17961  DARKNESS, LIGHTED ROAD     FIXED OBJECT
#
#                        TRAFFICWAY_TYPE LANE_CNT           ALIGNMENT  \
# 15125                      NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 57881  DIVIDED - W/MEDIAN (NOT RAISED)        4  STRAIGHT AND LEVEL
# 2428                       NOT DIVIDED      NaN  STRAIGHT AND LEVEL
# 53511  DIVIDED - W/MEDIAN (NOT RAISED)        3  STRAIGHT AND LEVEL
# 17961                            ALLEY      NaN  STRAIGHT AND LEVEL
#
#       ROADWAY_SURFACE_COND ROAD_DEFECT                 REPORT_TYPE  \
# 15125                  DRY     UNKNOWN  NOT ON SCENE (DESK REPORT)
# 57881                  DRY  NO DEFECTS                    ON SCENE
# 2428                   DRY  NO DEFECTS  NOT ON SCENE (DESK REPORT)
# 53511                  WET  NO DEFECTS                    ON SCENE
# 17961                  DRY  RUT, HOLES  NOT ON SCENE (DESK REPORT)
#
#                              CRASH_TYPE INTERSECTION_RELATED_I  \
# 15125  INJURY AND / OR TOW DUE TO CRASH                      Y
# 57881  INJURY AND / OR TOW DUE TO CRASH                    NaN
# 2428             NO INJURY / DRIVE AWAY                    NaN
# 53511            NO INJURY / DRIVE AWAY                    NaN
# 17961            NO INJURY / DRIVE AWAY                    NaN
#
#       NOT_RIGHT_OF_WAY_I HIT_AND_RUN_I       DAMAGE DATE_POLICE_NOTIFIED  \
# 15125                NaN           NaN  OVER $1,500  2020-06-18 22:30:00
# 57881                NaN           NaN  OVER $1,500  2019-03-14 17:16:00
# 2428                 NaN           NaN  OVER $1,500  2020-08-17 14:50:00
# 53511                NaN           NaN  OVER $1,500  2018-01-21 13:50:00
# 17961                NaN           NaN  OVER $1,500  2020-03-07 00:05:00
#
#              PRIM_CONTRIBUTORY_CAUSE SEC_CONTRIBUTORY_CAUSE STREET_NO  \
# 15125  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      1200
# 57881  FAILING TO YIELD RIGHT-OF-WAY    UNABLE TO DETERMINE      5200
# 2428             UNABLE TO DETERMINE    UNABLE TO DETERMINE       799
# 53511          FOLLOWING TOO CLOSELY         NOT APPLICABLE         6
# 17961                 NOT APPLICABLE         NOT APPLICABLE      3801
#
#       STREET_DIRECTION     STREET_NAME BEAT_OF_OCCURRENCE DOORING_I  \
# 15125                N  CALIFORNIA AVE               1423       NaN
# 57881                S   LAKE PARK AVE                234       NaN
# 2428                 N     SEDGWICK ST               1831       NaN
# 53511                E         95TH ST                634       NaN
# 17961                W     CHICAGO AVE               1112       NaN
#
#       WORK_ZONE_I WORKERS_PRESENT_I NUM_UNITS        MOST_SEVERE_INJURY  \
# 15125         NaN               NaN         2     REPORTED, NOT EVIDENT
# 57881         NaN               NaN         2  NONINCAPACITATING INJURY
# 2428          NaN               NaN         2   NO INDICATION OF INJURY
# 53511         NaN               NaN         3   NO INDICATION OF INJURY
# 17961         NaN               NaN         1   NO INDICATION OF INJURY
#
#       INJURIES_TOTAL INJURIES_FATAL INJURIES_INCAPACITATING  \
# 15125              5              0                       0
# 57881              2              0                       0
# 2428               0              0                       0
# 53511              0              0                       0
# 17961              0              0                       0
#
#       INJURIES_NON_INCAPACITATING INJURIES_REPORTED_NOT_EVIDENT  \
# 15125                           0                             5
# 57881                           2                             0
# 2428                            0                             0
# 53511                           0                             0
# 17961                           0                             0
#
#       INJURIES_NO_INDICATION INJURIES_UNKNOWN CRASH_HOUR CRASH_DAY_OF_WEEK  \
# 15125                      0                0         22                 5
# 57881                      1                0         17                 5
# 2428                       2                0         13                 2
# 53511                      3                0         13                 1
# 17961                      2                0          0                 7
#
#       CRASH_MONTH      LATITUDE      LONGITUDE  \
# 15125           6  41.902969953  -87.697027812
# 57881           3  41.800941976  -87.587636792
# 2428            8  41.896501897  -87.638466532
# 53511           1  41.721826895  -87.623490186
# 17961           3  41.895302735  -87.721251067
#
#                                        LOCATION CRASH_UNIT_ID UNIT_NO  \
# 15125  POINT (-87.697027812314 41.902969952568)        902018       2
# 57881  POINT (-87.587636792157 41.800941975966)        603327       1
# 2428   POINT (-87.638466531596 41.896501896875)        940304       2
# 53511  POINT (-87.623490186326 41.721826895385)        308648       3
# 17961   POINT (-87.721251067046 41.89530273536)        856938       1
#
#       UNIT_TYPE NUM_PASSENGERS VEHICLE_ID                             MAKE  \
# 15125    DRIVER              2     855303                           TOYOTA
# 57881    DRIVER            NaN     575025                         INFINITI
# 2428     DRIVER            NaN     891380                            TESLA
# 53511    DRIVER            NaN     298847  AVION (MFD. BY FLEETWOOD ENTP.)
# 17961    DRIVER              1     813149                             FORD
#
#                                  MODEL LIC_PLATE_STATE VEHICLE_YEAR  \
# 15125                          4RUNNER              IL         1996
# 57881                             FX35              IL         2012
# 2428      OTHER (EXPLAIN IN NARRATIVE)              IL         2020
# 53511  AVION (MFD. BY FLEETWOOD ENTP.)              IL         2000
# 17961                         EXPLORER              IL         2018
#
#       VEHICLE_DEFECT       VEHICLE_TYPE VEHICLE_USE TRAVEL_DIRECTION  \
# 15125        UNKNOWN          PASSENGER    PERSONAL                W
# 57881           NONE          PASSENGER    PERSONAL               SE
# 2428            NONE          PASSENGER    PERSONAL                W
# 53511           NONE  BUS OVER 15 PASS.         CTA                W
# 17961           NONE              OTHER      POLICE                W
#
#                                  MANEUVER OCCUPANT_CNT EXCEED_SPEED_LIMIT_I  \
# 15125                      STRAIGHT AHEAD            3                  NaN
# 57881  ENTERING TRAFFIC LANE FROM PARKING            1                  NaN
# 2428                       STRAIGHT AHEAD            1                  NaN
# 53511                      STRAIGHT AHEAD            1                  NaN
# 17961                      STRAIGHT AHEAD            2                  NaN
#
#       FIRST_CONTACT_POINT PERSON_ID PERSON_TYPE     CITY STATE ZIPCODE SEX  \
# 15125               OTHER   O902018      DRIVER  CHICAGO    IL   60651   F
# 57881          FRONT-LEFT   O603327      DRIVER  CHICAGO    IL   60615   F
# 2428    TOTAL (ALL AREAS)   O940304      DRIVER  CHICAGO    IL   60654   M
# 53511                REAR   O308648      DRIVER  CHICAGO    IL     NaN   M
# 17961                 NaN   O856938      DRIVER  CHICAGO    IL   60612   M
#
#       AGE DRIVERS_LICENSE_STATE DRIVERS_LICENSE_CLASS  SAFETY_EQUIPMENT  \
# 15125  53                    IL                     D     USAGE UNKNOWN
# 57881  37                    IL                    DM      NONE PRESENT
# 2428   36                    IL                     D  SAFETY BELT USED
# 53511  55                    IL                     B  SAFETY BELT USED
# 17961  26                    IL                     C  SAFETY BELT USED
#
#       AIRBAG_DEPLOYED EJECTION    INJURY_CLASSIFICATION HOSPITAL  \
# 15125  NOT APPLICABLE     NONE    REPORTED, NOT EVIDENT      NaN
# 57881  DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN
# 2428   DID NOT DEPLOY     NONE  NO INDICATION OF INJURY      NaN
# 53511  NOT APPLICABLE     NONE  NO INDICATION OF INJURY  REFUSED
# 17961  NOT APPLICABLE     NONE  NO INDICATION OF INJURY      NaN
#
#          DRIVER_ACTION    DRIVER_VISION PHYSICAL_CONDITION PEDPEDAL_ACTION  \
# 15125          UNKNOWN          UNKNOWN            UNKNOWN             NaN
# 57881  FAILED TO YIELD  PARKED VEHICLES             NORMAL             NaN
# 2428              NONE     NOT OBSCURED             NORMAL             NaN
# 53511             NONE     NOT OBSCURED             NORMAL             NaN
# 17961            OTHER     NOT OBSCURED             NORMAL             NaN
#
#       PEDPEDAL_VISIBILITY PEDPEDAL_LOCATION        BAC_RESULT  \
# 15125                 NaN               NaN  TEST NOT OFFERED
# 57881                 NaN               NaN  TEST NOT OFFERED
# 2428                  NaN               NaN  TEST NOT OFFERED
# 53511                 NaN               NaN  TEST NOT OFFERED
# 17961                 NaN               NaN  TEST NOT OFFERED
#
#       BAC_RESULT VALUE CELL_PHONE_USE
# 15125              NaN            NaN
# 57881              NaN            NaN
# 2428               NaN            NaN
# 53511              NaN            NaN
# 17961              NaN            NaN

# %% [markdown]
# ## Remove Features with Low Variance
#
# Remove all features whose variance do not meet some threshold. By default `feature_selection.VarianceThreshold()` removes features with zero variance or features that have the same value for all samples.

# %%
# Numeric data
raw_train.select_dtypes('number').columns

# Remove features with zero variance
sel = feature_selection.VarianceThreshold()
train_variance = sel.fit_transform(numeric_set)
train_variance.shape

# %% [markdown]
# ## Remove Highly Correlated Features
#
# Check and fix collinearity to prevent over-fitting.
#
# Two options
# - **Variation Inflation Factor** that checks for estimated coefficients that are inflated when multicollinearity exists.
# - Check numerical correlation (after encoding)?

# %% [markdown]
# **Variation Inflation Factor (VIF)**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor    

def calculate_vif_(X, thresh=100):
cols = X.columns
variables = np.arange(X.shape[1])
dropped=True
while dropped:
    dropped=False
    c = X[cols[variables]].values
    vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

    maxloc = vif.index(max(vif))
    if max(vif) > thresh:
        print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
        variables = np.delete(variables, maxloc)
        dropped=True

print('Remaining variables:')
print(X.columns[variables])
return X[cols[variables]]

# %% [markdown]
# **Checking numerical correlation**
#
# After encoding ?

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# Drop features
df.drop(df[to_drop], axis=1)

# %% [markdown]
# # Feature Transformation

# %% [markdown]
# ## Feature Types
#
# Decide the correct data type for each feature.

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# ### Categorical Outliers

# %% [markdown]
# Example 1: A, B, C, X.
#
# Example 2: Apple, Orange, Pear or Blueberry, Raspberry, Strawberry, Grape.
#
# "*The fact is **no outlier** exists in the examples above, for an outlier to exist there must be **a measure of distance**. This is intrinsic to numeric data types because there is a Euclidean distance between numbers.*"
#
# **Categorical Outliers don’t exist without a context.**
#
# > "*Techniques like **string indexing** or **one-hot encoding** on a categorical value to convert it from a string value to a numeric value and then use k-means clustering to find outliers.*"
#
# > "*the numeric vector assigned to the String value during the one hot encoding practice still lacks **the domain context**. It does satisfy the input constraint of the k-means model and the model will produce an output. However the output will not select the appropriate outlier, as the input **was not truly valid**.*"
#
# > "*There is an alternative. **K-modes** is designed to handle categorical values without the need for String Indexing or One Hot Encoding.*"

# %% [markdown]
# ### Numerical Outliers

# %% [markdown]
# Numerical features to consider
# - `POSTED_SPEED_LIMIT`
# - `LANE_CNT`
# - `BEAT_OF_OCCURRENCE`
# - `NUM_UNITS`
# - `INJURIES_TOTAL`
# - `INJURIES_FATAL`
# - `INJURIES_INCAPACITATING` and other injuries.
# - `CRASH_HOUR`
# - `CRASH_DAY_OF_WEEK`
# - `CRASH_MONTH`
# - `LATITUDE`
# - `LONGITUDE`
# - `UNIT_NO`
# - `NUM_PASSENGERS`
# - `VEHICLE_YEAR`
# - `OCCUPANT_CNT`
# - `AGE`

# %%
numericals=['POSTED_SPEED_LIMIT', 'LANE_CNT', 'BEAT_OF_OCCURRENCE', 'NUM_UNITS', 'INJURIES_TOTAL', 
            'INJURIES_FATAL', 'INJURIES_INCAPACITATING', 'CRASH_HOUR', 'CRASH_DAY_OF_WEEK', 'CRASH_MONTH', 
            'LATITUDE', 'LONGITUDE', 'UNIT_NO', 'NUM_PASSENGERS', 'VEHICLE_YEAR', 'OCCUPANT_CNT', 'AGE']

for col in numericals:
    print(raw_train[col].value_counts())
    print()
# Out:
# 30    33929
# 35     3390
# 25     2917
# 20     1753
# 15     1459
# 10      856
# 0       505
# 40      468
# 5       312
# 45      225
# 55       42
# 50       10
# 3         7
# 1         6
# 9         4
# 60        3
# 33        2
# 11        2
# 2         2
# 4         1
# 65        1
# 70        1
# 39        1
# 24        1
# Name: POSTED_SPEED_LIMIT, dtype: int64
#
# 2     7135
# 4     3686
# 1     2503
# 3      675
# 0      459
# 6      343
# 5      177
# 8      119
# 7       14
# 10      13
# 12       4
# 9        3
# 99       2
# 11       1
# Name: LANE_CNT, dtype: int64
#
# 1834    535
# 114     490
# 815     468
# 813     462
# 1831    445
#        ...
# 422      34
# 1125     30
# 1653     18
# 1652     14
# 1655     11
# Name: BEAT_OF_OCCURRENCE, Length: 274, dtype: int64
#
# 2     38841
# 3      4072
# 1      1358
# 4      1114
# 5       264
# 6       121
# 7        76
# 8        21
# 10        9
# 12        8
# 9         7
# 11        6
# Name: NUM_UNITS, dtype: int64
#
# 0    38689
# 1     5231
# 2     1227
# 3      391
# 4      149
# 5       68
# 7       21
# 6       20
# 8        4
# Name: INJURIES_TOTAL, dtype: int64
#
# 0    45744
# 1       53
# 2        3
# Name: INJURIES_FATAL, dtype: int64
#
# 0    44825
# 1      818
# 2       97
# 3       37
# 5       15
# 4        8
# Name: INJURIES_INCAPACITATING, dtype: int64
#
# 17    3472
# 16    3425
# 15    3378
# 14    3100
# 12    2798
# 13    2787
# 18    2764
# 8     2411
# 11    2293
# 9     2157
# 7     2093
# 19    2083
# 10    2047
# 20    1616
# 21    1526
# 22    1374
# 23    1187
# 6     1051
# 0      988
# 1      814
# 2      731
# 5      668
# 3      593
# 4      541
# Name: CRASH_HOUR, dtype: int64
#
# 6    7437
# 7    6802
# 4    6629
# 5    6560
# 2    6390
# 3    6362
# 1    5717
# Name: CRASH_DAY_OF_WEEK, dtype: int64
#
# 10    4389
# 7     4145
# 6     4050
# 12    4022
# 8     3943
# 5     3893
# 9     3826
# 11    3748
# 1     3676
# 2     3572
# 3     3520
# 4     3113
# Name: CRASH_MONTH, dtype: int64
#
# 41.976201139    53
# 41.751460603    25
# 41.73616511     24
# 41.714118868    22
# 41.900958919    22
#                 ..
# 41.96814948      1
# 41.762367415     1
# 41.807546709     1
# 41.949577875     1
# 41.921006351     1
# Name: LATITUDE, Length: 24230, dtype: int64
#
# -87.905309125    53
# -87.585971993    25
# -87.625587569    24
# -87.643145408    22
# -87.619928174    22
#                  ..
# -87.69354148      1
# -87.631213444     1
# -87.710446231     1
# -87.683675761     1
# -87.704697732     1
# Name: LONGITUDE, Length: 24231, dtype: int64
#
# 1     22567
# 2     21144
# 3      1664
# 4       360
# 5        92
# 6        40
# 7        18
# 9         4
# 8         2
# 10        2
# 0         2
# 11        2
# Name: UNIT_NO, dtype: int64
#
# 1     4964
# 2     1353
# 3      535
# 4      162
# 5       55
# 6       20
# 7        6
# 8        4
# 10       3
# 9        3
# 38       1
# 12       1
# 16       1
# 19       1
# Name: NUM_PASSENGERS, dtype: int64
#
# 2015    3075
# 2016    2917
# 2017    2856
# 2014    2648
# 2013    2340
#         ...
# 3007       1
# 2101       1
# 1974       1
# 2204       1
# 1900       1
# Name: VEHICLE_YEAR, Length: 71, dtype: int64
#
# 1     32125
# 0      5795
# 2      4712
# 3      1289
# 4       507
# 5       155
# 6        55
# 7        14
# 8         6
# 9         5
# 10        3
# 11        3
# 20        1
# 13        1
# 39        1
# Name: OCCUPANT_CNT, dtype: int64
#
# 27     880
# 25     877
# 29     854
# 26     854
# 24     847
#       ...
# 98       1
# 96       1
# 92       1
# 101      1
# 94       1
# Name: AGE, Length: 99, dtype: int64

# %% [markdown]
# **`POSTED_SPEED_LIMIT`**
#
# **ACTION!!!: Replace anything below 15 with 15???**
#
# [Automated Speed Enforcement FAQ](https://www.chicago.gov/city/en/depts/cdot/supp_info/children_s_safetyzoneporgramautomaticspeedenforcement/automated_speed_enforcementfrequentlyaskedquestions.html)
#
# What are the Safety Zone times and speed limits?
#
# **School Zones:**
#
# School days, Monday through Friday
# - 7 am to 4 pm: **20 mph** speed limit when children are present in the safety zone.
#
# - 7 am to 7:00 pm: The posted speed limit, **normally 30 mph**. Each Child Safety Zone has the posted speed limit clearly displayed. Motorists’ should always follow the posted speed limit in each Child Safety Zone.
#
# **Park Zones:**
#
# 365 Days a Year
# - Times are variable. Visit www.chicago.gov for more information on specific parks. Generally, Park Zones will be enforced from 6 a.m. to 11 p.m.: enforcing the posted speed limit, **normally 30 mph**.

# %% [markdown]
# **`LANE_CNT`**
#
# - 3 rows of 9
# - 13 rows of 10
# - 1 row of 11
# - 4 rows of 12
# - 2 rows of 99

# %% [markdown]
# ##  Handling Missing Values

# %% [markdown]
# <a id='3.3.1'></a>
#
# ###  Imputation of binary features in 2.1.3.1
#
# *[Back to 2.1.3.1](#2.1.3.1)*

# %%
binary_columns = ['CRASH_DATE_EST_I', 'INTERSECTION_RELATED_I', 'NOT_RIGHT_OF_WAY_I', 'HIT_AND_RUN_I', 
                  'CELL_PHONE_USE', 'EXCEED_SPEED_LIMIT_I', 'DOORING_I', 'WORK_ZONE_I', 'WORKERS_PRESENT_I']
for col in binary_columns:
    raw_train[col] = raw_train[col].fillna('N')

# %%
raw_train[binary_columns].isna().any()

# %%
#raw_train['BAC_RESULT VALUE']
#**`alcohol_consumption` = yes/no**.

# %% [markdown]
# ###  Remove rows with missing data

# %%
# Subset the data to include the columns only with nulls in the output
raw_null_below50 = raw_train[raw_train.columns[raw_train.isnull().mean().round(2) < 0.5].tolist()]
print('\033[1m', 'These', len(raw_null_above50.columns),
      'columns have missing values less than 50%!', '\033[0m')
raw_null_below50.isnull().mean().round(3)b

# %% [markdown]
# ###  Scikit-learn's Imputer Class

# %% [markdown]
# ## Encoding Categorical Features

# %% [markdown]
# Number of unique values per column.

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)

unique_counts = raw_train.from_records(
    [(col, raw_train[col].nunique()) for col in raw_train.columns],
    columns=['column_name', 'num_unique']).sort_values(by=['num_unique'])

#unique_counts[Numm_]

# %% [markdown]
# ## Feature Transformation
#
# - Log, Box-cox transformation etc.

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# ## Handling Time-Date & Mixed Variables

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# [Source](https://en.wikipedia.org/wiki/Feature_engineering)
#
# The feature engineering process is:
# - **Brainstorming** or **testing** features;
# - **Deciding** what features to create;
# - **Creating** features;
# - **Checking** how the features work with your model;
# - **Improving** your features if needed;
# - **Go back** to brainstorming/creating more features until the work is done.

# %% [markdown]
# ## Target Features

# %% [markdown]
# Pick **`INJURIES_TOTAL`** as a numerical target and/or encode **`INJURIES_FATAL`** as a categorical target.
#
# - `INJURIES_TOTAL`: Total persons sustaining **fatal, incapacitating, non-incapacitating, and possible injuries** as determined by the reporting officer.
#
#
# - `INJURIES_FATAL`: Total persons sustaining fatal injuries in the crash.
#
#
# - `INJURIES_INCAPACITATING`: Total persons sustaining **incapacitating/serious injuries** in the crash as determined by the reporting officer. Any injury other than fatal injury, which prevents the injured person from walking, driving, or normally continuing the activities they were capable of performing before the injury occurred. <u>Includes severe lacerations, broken limbs, skull or chest injuries, and abdominal injuries</u>.
#
#
# - `INJURIES_NON_INCAPACITATING`: Total persons sustaining non-incapacitating injuries in the crash as determined by the reporting officer. Any injury, **other than fatal or incapacitating injury**, which is evident to observers at the scene of the crash. <u>Includes lump on head, abrasions, bruises, and minor lacerations</u>.
#
#
# - `INJURIES_REPORTED_NOT_EVIDENT`: Total persons sustaining **possible injuries** in the crash as determined by the reporting officer. <u>Includes momentary unconsciousness, claims of injuries not evident, limping, complaint of pain, nausea, and hysteria</u>.
#
#
# - ~`INJURIES_NO_INDICATION`: Total persons sustaining **no injuries** in the crash as determined by the reporting officer.~
#
#
# - ~`INJURIES_UNKNOWN`: Total persons for whom injuries sustained, if any, are unknown.~

# %%
target_features = ['INJURIES_TOTAL', 'INJURIES_FATAL', 'INJURIES_INCAPACITATING', 'INJURIES_NON_INCAPACITATING', 
                   'INJURIES_REPORTED_NOT_EVIDENT', 'INJURIES_NO_INDICATION', 'INJURIES_UNKNOWN']

for col in target_features:
    print(raw_train[col].value_counts())
    print()
# Out:
# 0    38689
# 1     5231
# 2     1227
# 3      391
# 4      149
# 5       68
# 7       21
# 6       20
# 8        4
# Name: INJURIES_TOTAL, dtype: int64
#
# 0    45744
# 1       53
# 2        3
# Name: INJURIES_FATAL, dtype: int64
#
# 0    44825
# 1      818
# 2       97
# 3       37
# 5       15
# 4        8
# Name: INJURIES_INCAPACITATING, dtype: int64
#
# 0    41635
# 1     3184
# 2      667
# 3      214
# 4       73
# 5       14
# 6        8
# 7        3
# 8        2
# Name: INJURIES_NON_INCAPACITATING, dtype: int64
#
# 0    43412
# 1     1856
# 2      366
# 3       99
# 4       33
# 5       27
# 6        4
# 7        3
# Name: INJURIES_REPORTED_NOT_EVIDENT, dtype: int64
#
# 2     20636
# 1     13529
# 3      6488
# 4      2398
# 5      1045
# 0       872
# 6       470
# 7       176
# 8        91
# 9        34
# 10       25
# 11       12
# 12        5
# 13        5
# 15        4
# 18        2
# 40        2
# 14        2
# 21        2
# 31        1
# 46        1
# Name: INJURIES_NO_INDICATION, dtype: int64
#
# 0    45800
# Name: INJURIES_UNKNOWN, dtype: int64

# %% [markdown]
# ## Predictors Features

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## Univariate Feature Selection
#
# Uses univariate statistical tests to select features having the highest correlation to the target.

# %%
#from sklearn.feature_selection import SelectKBest, f_classif

# Select 50 features
k_best = SelectKBest(score_func=f_classif, k=50)

# Fit on train set
fit = k_best.fit(X_train, y_train)

# Transform train set
univariate_features = fit.transform(X_train)

# %% [markdown]
# ## Recursive Feature Elimination
#
# Eliminate features recursively by importance until the specified number of features is reached. It can be used with any model that assigns weights to features, either through `coef_` or `feature_importances_`.

# %%
#from sklearn.feature_selection import RFE

# Select 50 features
rfe = RFE(rfc, n_features_to_select=50)

# Fit on train set
fit = rfe.fit(X_train, y_train)

# Transform train set
recursive_features = fit.transform(X_train)

# %% [markdown]
# ## Dimensionality Reduction
#
# Dimensionality reduction on any feature if necessary by
# - transform features into a lower dimension (PCA),
# - simple arithmetics and KPIs,
# - other methods.

# %% [markdown]
# # Baseline Models

# %% [markdown]
# ## Baseline Models
#
#
# Fundamentally, a baseline is a model that is both simple to set up and has a reasonable chance of providing decent results.
#
# Decision tree models perform well on imbalanced data.

# %% [markdown]
# **Model 1**

# %%
# prepare for modeling
X_train_df = train.drop(['id', 'target'], axis=1)
y_train = train['target']

# scaling data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train_df)
lr = LogisticRegression(solver='liblinear')
lr_scores = cross_val_score(lr,
                            X_train,
                            y_train,
                            cv=5,
                            scoring='roc_auc')
print('LR Scores: ', lr_scores)

# %% [markdown]
# **Model 2**

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)

# predict
rfc_predict = rfc.predict(x_test)# check performance

print('ROCAUC score:',roc_auc_score(y_test, rfc_predict))
print('Accuracy score:',accuracy_score(y_test, rfc_predict))
print('F1 score:',f1_score(y_test, rfc_predict))

# %% [markdown]
# ## Success Measures
#
# [Confusion Matrix](https://en.wikipedia.org/wiki/Confusion_matrix)
#
# Accuracy is not suitable to use with imbalanced data.
#
# - **Precision:** the number of true positives divided by all positive predictions. Precision is also called Positive Predictive Value. It is a measure of a classifier’s exactness. Low precision indicates a high number of false positives.
#
#
# - **Recall:** the number of true positives divided by the number of positive values in the test data. The recall is also called **Sensitivity** or the **True Positive Rate (TPR)**. It is a measure of a classifier’s completeness. Low recall indicates a high number of false negatives.
#
#
# - **F1:** Score: the weighted <u>average of precision and recall</u>.
#
#
# - **Area Under ROC Curve**

# %% [markdown]
# ## Next Steps

# %% [markdown]
# [Source](https://blog.insightdatascience.com/always-start-with-a-stupid-model-no-exceptions-3a22314b9aaa)
#
# Get a quick performance benchmark with baseline model, then inspect what this model is struggling with (errors) can help you choose a next approach.
# - A baseline helps you understand your data
# - A baseline helps you understand your task

# %% [markdown]
# ### Handling Class Imbalance
#
# - Resampling techniques (Sub-sampling)
# - Penalize algorithms (Cost-Sensitive Training)
# - Change performance metric
# - Change algorithms
